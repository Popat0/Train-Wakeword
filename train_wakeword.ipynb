# %% [markdown]
# # Custom wake-word trainer — bulletproof Colab notebook (2026 edition)
#
# Train your own openWakeWord model in ~75-90 minutes on Colab Pro. **Run all → walk away → download `.onnx`** at the end.
#
# ## Why this notebook exists
#
# openWakeWord's official Colab notebook bit-rotted hard against Python 3.12 (no piper-phonemize wheels), against torchaudio 2.x (`set_audio_backend` removed), against newer Colab images (HF Hub timeouts, namespace-package edge cases), and against its own internal config schema (4 keys silently moved to required-or-`KeyError` over the past year).
#
# This notebook is patched against all of that. Every cell is **self-healing** — checks its own outputs, re-creates what's missing. There's a hard pre-flight gate (cell 4) that catches every dep/file issue before any of the slow downloads start.
#
# It also **replaces openwakeword's `auto_train` with a faithful hand-rolled PyTorch loop** that mirrors auto_train's curriculum exactly: 3-stage learning rate (1e-4 → 1e-5 → 1e-6), negative-weight ramp 1→1500, hard-negative mining, FP-per-hour validation against an ACAV100M continuous-audio slice, 90/90/10 percentile checkpoint ensemble averaging. The upstream `auto_train` path keeps surfacing bugs against `mmap_batch_generator` shape handling on current openwakeword `master`; the hand-rolled trainer in cell 14 is small enough to read in one sitting and debug if anything ever changes.
#
# ## Run order
#
# 1. **Runtime → Change runtime type → L4 GPU + High RAM** (Colab Pro, $10/mo). Free T4 also works but is ~2× slower.
# 2. **Cell 10 — edit `TARGET_PHRASE` and `MODEL_NAME`** for your wake word. (Default = `mr graves`, the example we trained with.)
# 3. **Runtime → Run all**
# 4. Walk away ~75-90 min. Last cell downloads `<MODEL_NAME>.onnx`.
#
# ## Validated example (Mr Graves, 2026-05-09)
#
# 13 real-world utterances on a Pixel — every utterance fired:
#
# ```
# WAKE — score=0.99664426
# WAKE — score=0.59243464
# WAKE — score=0.65439160
# WAKE — score=0.77693284
# WAKE — score=0.85433600
# WAKE — score=0.64701974
# WAKE — score=0.80747485
# WAKE — score=0.95243360
# WAKE — score=0.99938180
# WAKE — score=0.90104705
# WAKE — score=0.99639570
# WAKE — score=0.98879445
# WAKE — score=0.51673140
# ```
#
# 13/13 fires, scores 0.52-0.999, **zero phantom fires** during 30 min of normal phone use (TV, music, conversation, kitchen noise). Matches openwakeword's pretrained Hey Jarvis baseline (0.984/0.989) on clear utterances.
#
# For deeper context on what auto_train actually does and why every part of the curriculum matters, the comments in cell 14 walk through each piece.

# %% [markdown]
# ## 1. Comprehensive install â€” apt + pip + verify
#
# Every dep + transitive we've discovered. `piper-tts` goes LAST via `--no-deps` so no later install can clobber it (piper-tts pulls regular `piper-phonemize` which has no Py 3.12 wheel; `piper-phonemize-cross` provides the same module name and is installed first).

# %%
# !pip install piper-phonemize-fix
# Out:
# Requirement already satisfied: piper-phonemize-fix in /usr/local/lib/python3.13/dist-packages (1.2.2)
# Requirement already satisfied: setuptools>=75.8.0 in /usr/local/lib/python3.13/dist-packages (from piper-phonemize-fix) (81.0.0)
# Requirement already satisfied: wheel>=0.45.1 in /usr/local/lib/python3.13/dist-packages (from piper-phonemize-fix) (0.48.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.13/dist-packages (from wheel>=0.45.1->piper-phonemize-fix) (26.3)

# %%
# Native deps
# !apt-get install -y -qq cmake espeak-ng espeak-ng-data libespeak-ng-dev libsndfile1 pkg-config build-essential ffmpeg unzip 2>&1 | tail -3

# Python deps â€” installed in this exact order:
#   (a) piper-phonemize-cross FIRST (Py3.12-compatible fork; same module name as piper-phonemize)
#   (b) Everything openwakeword.train / data.py / utils.py touch (ALL transitives, not just direct)
#   (c) piper-tts LAST via --no-deps (so nothing later can downgrade/clobber it)
# !pip install -q piper-phonemize-cross
# !pip install -q \
    webrtcvad \
    mutagen==1.47.0 \
    torchinfo \
    torchmetrics \
    pyyaml \
    tqdm \
    datasets \
    soundfile \
    audiomentations \
    torch_audiomentations \
    pronouncing \
    onnxruntime \
    onnx \
    speechbrain \
    acoustics \
    scipy \
    requests \
    huggingface_hub
# !pip install -q --no-deps piper-tts

# Verify imports â€” every module openwakeword's train.py, data.py and utils.py
# touch. If anything's missing this surfaces NOW, before any 75-min run.
import sys
print('Python:', sys.version)
import torch, torchinfo, torchmetrics, scipy, numpy
print(f'  torch: {torch.__version__}  cuda: {torch.cuda.is_available()}')
from tqdm import tqdm
import yaml, mutagen, pronouncing
import torchaudio, audiomentations, torch_audiomentations
import speechbrain, acoustics
import onnx, onnxruntime, soundfile, requests
from piper_phonemize import phonemize_espeak
from piper import PiperVoice, SynthesisConfig
print('  All openwakeword deps (incl. piper-tts) import cleanly.')
# Out:
# ERROR: Could not find a version that satisfies the requirement piper-phonemize-cross (from versions: none)
# ERROR: No matching distribution found for piper-phonemize-cross
# Python: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
#   torch: 2.11.0+cu128  cuda: True
#   All openwakeword deps (incl. piper-tts) import cleanly.

# %% [markdown]
# ## 2. Clone repos + download model (self-healing)
#
# Each piece (piper-sample-generator clone, libritts .pt model, openwakeword clone) is checked individually and re-created if missing or partial. Pin piper-sample-generator to commit `1a8c49bd^` â€” the parent of "Move to package", which is the last revision with flat-layout `generate_samples.py` at the root that openwakeword's train.py expects to import.

# %%
import os, sys
os.chdir('/content')

# â”€â”€ piper-sample-generator (pinned to flat-layout commit) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
PSG_DIR = '/content/piper-sample-generator'
PSG_PIN = '1a8c49bd29b3a132721086ee88f2253f788594a8^'
PSG_GS  = f'{PSG_DIR}/generate_samples.py'
if not os.path.exists(PSG_GS):
    print('  piper-sample-generator missing or broken â€” re-cloning')
    # !rm -rf {PSG_DIR}
    # !git clone -q https://github.com/rhasspy/piper-sample-generator {PSG_DIR}
# !cd {PSG_DIR} && git fetch -q --all && git checkout -q {PSG_PIN}
assert os.path.exists(PSG_GS), 'piper-sample-generator pin did not yield generate_samples.py'
print(f'  âœ“ piper-sample-generator pinned: {PSG_GS} ({os.path.getsize(PSG_GS)} bytes)')

# â”€â”€ libritts model (~200 MB) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
PIPER_MODEL = f'{PSG_DIR}/models/en_US-libritts_r-medium.pt'
PIPER_MODEL_URL = 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
if not os.path.exists(PIPER_MODEL) or os.path.getsize(PIPER_MODEL) < 100_000_000:
    print(f'  libritts model missing/partial â€” downloading (~200 MB)')
    # !mkdir -p {PSG_DIR}/models
    # !wget -q --tries=5 --timeout=300 -O {PIPER_MODEL} {PIPER_MODEL_URL}
assert os.path.getsize(PIPER_MODEL) > 100_000_000, f'libritts model only {os.path.getsize(PIPER_MODEL)} bytes â€” download failed'
print(f'  âœ“ libritts model: {os.path.getsize(PIPER_MODEL)/1e6:.0f} MB')

# â”€â”€ openwakeword (master) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
OWW_DIR = '/content/openwakeword'
OWW_TRAIN = f'{OWW_DIR}/openwakeword/train.py'
if not os.path.exists(OWW_TRAIN):
    print('  openwakeword missing or gutted â€” re-cloning')
    # !rm -rf {OWW_DIR}
    # !git clone -q https://github.com/dscripka/openwakeword {OWW_DIR}
    # !pip install -q -e {OWW_DIR}
assert os.path.exists(OWW_TRAIN), 'openwakeword train.py missing after clone'
print(f'  âœ“ openwakeword: {OWW_TRAIN} ({os.path.getsize(OWW_TRAIN)/1e3:.0f} KB)')

# â”€â”€ Make sure openwakeword's PARENT dir is on sys.path so the package
# resolves correctly. /content is also on sys.path by default in Colab,
# which would resolve `import openwakeword` to /content/openwakeword/
# (the editable-install ROOT, no __init__.py) instead of the package
# at /content/openwakeword/openwakeword/. That would treat openwakeword
# as a namespace package and submodule imports (.data, .utils) would fail.
if OWW_DIR not in sys.path:
    sys.path.insert(0, OWW_DIR)
# Wipe any stale namespace-package state in sys.modules
for _m in list(sys.modules):
    if _m.startswith('openwakeword'):
        del sys.modules[_m]
import openwakeword
assert openwakeword.__file__ is not None, (
    f'openwakeword still loaded as namespace package â€” '
    f'__file__ is None, __path__={openwakeword.__path__}. '
    f'Check sys.path for stray /content entries.'
)
print(f'  âœ“ openwakeword importable: {openwakeword.__file__}')
# Out:
#   âœ“ piper-sample-generator pinned: /content/piper-sample-generator/generate_samples.py (21646 bytes)
#   âœ“ libritts model: 204 MB
#   âœ“ openwakeword: /content/openwakeword/openwakeword/train.py (46 KB)
#   âœ“ openwakeword importable: /content/openwakeword/openwakeword/__init__.py

# %% [markdown]
# ## 3. Apply runtime patches (idempotent)
#
# Six patches. Each is a string check + targeted modification â€” re-running this cell after a partial install reapplies cleanly without double-patching.

# %%
import os, glob

# Patch A: torch_audiomentations 0.11 calls torchaudio.set_audio_backend
# which torchaudio 2.x removed. sed-replace the bad line with no-op.
for path in glob.glob('/usr/local/lib/python*/dist-packages/torch_audiomentations/utils/io.py'):
    # !sed -i 's|torchaudio.set_audio_backend("soundfile")|pass  # patched|' "{path}"
    print(f'  Patch A (set_audio_backend): {path}')

# Patch B: copy generate_samples.py into openwakeword's package dir.
src = '/content/piper-sample-generator/generate_samples.py'
dst = '/content/openwakeword/openwakeword/generate_samples.py'
assert os.path.exists(src), 'piper-sample-generator/generate_samples.py missing â€” cell 2 failed'
if (not os.path.exists(dst)) or os.path.getsize(dst) != os.path.getsize(src):
    # !cp "{src}" "{dst}"
print(f'  Patch B (generate_samples copy): {dst}')

# Patch C: HF Hub default 10s timeouts â†’ 120s
os.environ['HF_HUB_ETAG_TIMEOUT'] = '120'
os.environ['HF_HUB_DOWNLOAD_TIMEOUT'] = '120'
import huggingface_hub.constants as hfc
for attr in ['DEFAULT_ETAG_TIMEOUT', 'DEFAULT_DOWNLOAD_TIMEOUT',
             'HF_HUB_ETAG_TIMEOUT', 'HF_HUB_DOWNLOAD_TIMEOUT']:
    if hasattr(hfc, attr): setattr(hfc, attr, 120)
print('  Patch C (HF Hub timeouts â†’ 120s)')

# Patch D: torchaudio.info shim (removed in torchaudio 2.x)
import torchaudio
init_path = torchaudio.__file__
SHIM_MARKER = '# â”€â”€ PATCH: info() shim for torchaudio 2.x â”€â”€'
with open(init_path) as f:
    content = f.read()
if SHIM_MARKER not in content:
    shim = (f'\n\n{SHIM_MARKER}\n'
            'def info(file_path, *args, **kwargs):\n'
            '    import soundfile as _sf\n'
            '    si = _sf.info(str(file_path))\n'
            '    return type("_TorchaudioInfo", (), {\n'
            '        "num_frames": si.frames, "sample_rate": si.samplerate,\n'
            '        "num_channels": si.channels, "bits_per_sample": 16,\n'
            '        "encoding": "PCM_S",\n'
            '    })()\n')
    with open(init_path, 'a') as f: f.write(shim)
    import importlib; importlib.reload(torchaudio)
print(f'  Patch D (torchaudio.info shim): {hasattr(torchaudio, "info")}')

# Patch E: openwakeword's generate_samples requires `model` arg but train.py
# doesn't pass it â€” default to the libritts model we already downloaded.
TARGET = '/content/piper-sample-generator/generate_samples.py'
# !sed -i 's|model: Union\[str, Path\],|model: Union[str, Path] = "/content/piper-sample-generator/models/en_US-libritts_r-medium.pt",|' "{TARGET}"
# !cp "{TARGET}" /content/openwakeword/openwakeword/generate_samples.py
print('  Patch E (generate_samples model arg default)')

# Patch F: train.py val dtype cast (line ~519 + ~547)
TRAIN_PY = '/content/openwakeword/openwakeword/train.py'
# !sed -i 's|val_predictions = self.model(x_val)$|val_predictions = self.model(x_val.float())|' "{TRAIN_PY}"
print('  Patch F (train.py val dtype cast)')
print()
print('All 6 patches applied (idempotent).')
# Out:
#   Patch A (set_audio_backend): /usr/local/lib/python3.13/dist-packages/torch_audiomentations/utils/io.py
#   Patch B (generate_samples copy): /content/openwakeword/openwakeword/generate_samples.py
#   Patch C (HF Hub timeouts â†’ 120s)
#   Patch D (torchaudio.info shim): True
#   Patch E (generate_samples model arg default)
#   Patch F (train.py val dtype cast)
#
# All 6 patches applied (idempotent).

# %% [markdown]
# ## 4. Pre-flight â€” every dep imports + every external file exists
#
# Hard-fails if anything's wrong. This is the gate before slow downloads start. Catches new failure modes future Colab updates introduce.

# %%
import os, importlib

# Files
expected = {
    'piper-sample-generator/generate_samples.py': '/content/piper-sample-generator/generate_samples.py',
    'openwakeword/generate_samples.py':            '/content/openwakeword/openwakeword/generate_samples.py',
    'libritts model':                              '/content/piper-sample-generator/models/en_US-libritts_r-medium.pt',
    'openwakeword/train.py':                       '/content/openwakeword/openwakeword/train.py',
    'openwakeword/data.py':                        '/content/openwakeword/openwakeword/data.py',
    'openwakeword/utils.py':                       '/content/openwakeword/openwakeword/utils.py',
}
missing_files = []
for name, p in expected.items():
    if os.path.exists(p):
        size = os.path.getsize(p)
        unit = 'MB' if size > 1e6 else 'KB'
        denom = 1e6 if unit == 'MB' else 1e3
        print(f'  âœ“ {name}: {size/denom:.1f} {unit}')
    else:
        missing_files.append((name, p))
        print(f'  âœ— MISSING: {name} ({p})')

# Imports
missing_mods = []
for mod in ['torch', 'torchinfo', 'torchmetrics', 'scipy', 'numpy', 'tqdm',
            'yaml', 'mutagen', 'pronouncing', 'torchaudio', 'audiomentations',
            'torch_audiomentations', 'speechbrain', 'acoustics', 'onnx',
            'onnxruntime', 'soundfile', 'requests', 'huggingface_hub',
            'piper_phonemize', 'piper', 'openwakeword']:
    try:
        importlib.import_module(mod)
    except Exception as e:
        missing_mods.append((mod, str(e)))
        print(f'  âœ— IMPORT FAIL: {mod} ({type(e).__name__}: {e})')

# Dry-run openwakeword.data + utils â€” catches weird internal import bugs
try:
    from openwakeword.data import generate_adversarial_texts, augment_clips, mmap_batch_generator
    from openwakeword.utils import compute_features_from_generator, AudioFeatures
    print('  âœ“ openwakeword.data + .utils dry-import OK')
except Exception as e:
    print(f'  âœ— openwakeword internal import: {type(e).__name__}: {e}')
    missing_mods.append(('openwakeword.data/utils', str(e)))

import torch
print(f'\n  CUDA: {torch.cuda.is_available()}, GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "-"}')
if missing_files or missing_mods:
    raise RuntimeError(f'Pre-flight failed â€” {len(missing_files)} missing files, {len(missing_mods)} import errors. Re-run cells 1-3.')
print('\n  Pre-flight PASSED. Safe to proceed with downloads + training.')
# Out:
#   âœ“ piper-sample-generator/generate_samples.py: 21.6 KB
#   âœ“ openwakeword/generate_samples.py: 21.6 KB
#   âœ“ libritts model: 204.1 MB
#   âœ“ openwakeword/train.py: 46.3 KB
#   âœ“ openwakeword/data.py: 46.6 KB
#   âœ“ openwakeword/utils.py: 33.1 KB
#   âœ“ openwakeword.data + .utils dry-import OK
#
#   CUDA: True, GPU: Tesla T4
#
#   Pre-flight PASSED. Safe to proceed with downloads + training.

# %% [markdown]
# ## 5. Download openwakeword shared models (mel + embedding)
#
# Required by augment_clips' feature-extraction step. Idempotent â€” skips files already cached.

# %%
import os
models_dir = '/content/openwakeword/openwakeword/resources/models'
os.makedirs(models_dir, exist_ok=True)
BASE = 'https://github.com/dscripka/openWakeWord/releases/download/v0.5.1'
for fname in ['embedding_model.onnx', 'embedding_model.tflite',
              'melspectrogram.onnx', 'melspectrogram.tflite']:
    out = f'{models_dir}/{fname}'
    if os.path.exists(out) and os.path.getsize(out) > 1000:
        print(f'  cached: {fname} ({os.path.getsize(out)/1e3:.0f} KB)')
    else:
        # !wget -q --tries=5 --timeout=120 "{BASE}/{fname}" -O "{out}"
        print(f'  âœ“ downloaded: {fname} ({os.path.getsize(out)/1e3:.0f} KB)')
# Out:
#   cached: embedding_model.onnx (1327 KB)
#   cached: embedding_model.tflite (1330 KB)
#   cached: melspectrogram.onnx (1088 KB)
#   cached: melspectrogram.tflite (1093 KB)

# %% [markdown]
# ## 6. MIT impulse responses â†’ 16-kHz WAVs (~1 min)
#
# Caches the HF dataset, then converts to WAV. Both halves idempotent.

# %%
import os, time, numpy as np
import scipy.io.wavfile as wavfile
from huggingface_hub import snapshot_download
import datasets

output_dir = '/content/mit_rirs'
os.makedirs(output_dir, exist_ok=True)
if len([f for f in os.listdir(output_dir) if f.endswith('.wav')]) >= 250:
    print(f'  cached: {len(os.listdir(output_dir))} MIT IR WAVs')
else:
    # Pre-cache via snapshot_download (more reliable than load_dataset's internal
    # 10s timeout on 270 file metadata calls).
    for i in range(6):
        try:
            snapshot_download(repo_id='davidscripka/MIT_environmental_impulse_responses',
                              repo_type='dataset', etag_timeout=120, max_workers=4)
            break
        except Exception as e:
            wait = 15 * (i+1)
            print(f'  snapshot_download attempt {i+1}/6: {type(e).__name__}: {str(e)[:80]} â€” sleep {wait}s')
            time.sleep(wait)
    # Load + convert
    for attempt in range(4):
        try:
            rir_dataset = datasets.load_dataset('davidscripka/MIT_environmental_impulse_responses',
                                                split='train', streaming=False)
            break
        except Exception as e:
            print(f'  load_dataset attempt {attempt+1}: {type(e).__name__}: {str(e)[:120]}')
            time.sleep(20 * (attempt + 1))
    else:
        raise RuntimeError('load_dataset failed for MIT IRs')
    n = 0
    for i, row in enumerate(rir_dataset):
        out = f'{output_dir}/{i:04d}.wav'
        if os.path.exists(out): continue
        audio = row['audio']
        sr = audio['sampling_rate']
        arr = np.asarray(audio['array'])
        if sr != 16000:
            from scipy.signal import resample_poly
            arr = resample_poly(arr, 16000, sr)
        arr = (arr * 32767).clip(-32768, 32767).astype(np.int16)
        wavfile.write(out, 16000, arr); n += 1
    print(f'  âœ“ wrote {n} new WAVs (total {len(os.listdir(output_dir))})')
# Out:
#   cached: 270 MIT IR WAVs

# %% [markdown]
# ## 7. Download FMA + ACAV features (~10-15 min)
#
# FMA = ~8 GB zip of MP3s for background-noise mixing. ACAV = ~17 GB .npy of pre-computed features (becomes negative training corpus). Both use stream + resume so a session restart picks up where it left off.

# %%
import os, requests, zipfile
from tqdm.auto import tqdm
os.chdir('/content')

# â”€â”€ ACAV features (17 GB) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
ACAV_FULL = '/content/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
ACAV_URL = 'https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
if os.path.exists(ACAV_FULL) and os.path.getsize(ACAV_FULL) > 16_000_000_000:
    print(f'  cached: ACAV {os.path.getsize(ACAV_FULL)/1e9:.1f} GB')
else:
    resume_byte = os.path.getsize(ACAV_FULL) if os.path.exists(ACAV_FULL) else 0
    headers = {'Range': f'bytes={resume_byte}-'} if resume_byte else {}
    mode = 'ab' if resume_byte else 'wb'
    print(f'  ACAV: {"resuming from" if resume_byte else "fetching"} {resume_byte/1e9:.1f} GB')
    with requests.get(ACAV_URL, stream=True, headers=headers, timeout=120) as r:
        r.raise_for_status()
        total = int(r.headers.get('content-length', 0)) + resume_byte
        with open(ACAV_FULL, mode) as f, tqdm(total=total, initial=resume_byte,
                                              unit='B', unit_scale=True, unit_divisor=1024,
                                              desc='ACAV') as pbar:
            for chunk in r.iter_content(chunk_size=4*1024*1024):
                if chunk: f.write(chunk); pbar.update(len(chunk))
    print(f'  âœ“ ACAV: {os.path.getsize(ACAV_FULL)/1e9:.1f} GB')

# â”€â”€ FMA small (~8 GB zip) with resume + extract â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
FMA_DIR = '/content/fma'
FMA_ZIP = '/content/fma_small.zip'
os.makedirs(FMA_DIR, exist_ok=True)
if os.path.isdir(FMA_DIR) and len(os.listdir(FMA_DIR)) > 100:
    print(f'  cached: FMA {len(os.listdir(FMA_DIR))} entries')
else:
    fma_url = 'https://os.unil.cloud.switch.ch/fma/fma_small.zip'
    resume_byte = os.path.getsize(FMA_ZIP) if os.path.exists(FMA_ZIP) else 0
    headers = {'Range': f'bytes={resume_byte}-'} if resume_byte else {}
    mode = 'ab' if resume_byte else 'wb'
    print(f'  FMA: {"resuming from" if resume_byte else "fetching"} {resume_byte/1e9:.1f} GB')
    with requests.get(fma_url, stream=True, headers=headers, timeout=120) as r:
        r.raise_for_status()
        total = int(r.headers.get('content-length', 0)) + resume_byte
        with open(FMA_ZIP, mode) as f, tqdm(total=total, initial=resume_byte,
                                            unit='B', unit_scale=True, unit_divisor=1024,
                                            desc='FMA') as pbar:
            for chunk in r.iter_content(chunk_size=4*1024*1024):
                if chunk: f.write(chunk); pbar.update(len(chunk))
    print(f'  extracting FMA...')
    with zipfile.ZipFile(FMA_ZIP) as zf:
        for name in tqdm(zf.namelist(), desc='extract', unit='f'):
            zf.extract(name, FMA_DIR)
    os.remove(FMA_ZIP)
    print(f'  âœ“ FMA extracted: {len(os.listdir(FMA_DIR))} entries')
# Out:
#   ACAV: fetching 0.0 GB
# ACAV:   0%|          | 0.00/16.1G [00:00<?, ?B/s]
#   âœ“ ACAV: 17.3 GB
#   FMA: fetching 0.0 GB
# FMA:   0%|          | 0.00/7.15G [00:00<?, ?B/s]
#   extracting FMA...
# extract:   0%|          | 0/8002 [00:00<?, ?f/s]
#   âœ“ FMA extracted: 1 entries

# %% [markdown]
# ## 8. FMA MP3s â†’ 16-kHz mono WAVs (~5 min)
#
# audiomentations needs WAV. 1500 conversions = plenty of background-noise variety.

# %%
import os, glob, subprocess
from tqdm.auto import tqdm
out_dir = '/content/fma_wav'
os.makedirs(out_dir, exist_ok=True)
n_existing = len(os.listdir(out_dir))
if n_existing >= 1500:
    print(f'  cached: {n_existing} FMA WAVs')
else:
    mp3s = glob.glob('/content/fma/**/*.mp3', recursive=True)
    if len(mp3s) < 100:
        raise RuntimeError(f'FMA download incomplete â€” only {len(mp3s)} MP3s found')
    existing = set(os.listdir(out_dir))
    n_target = min(1500, len(mp3s))
    to_convert = [(i, mp3s[i]) for i in range(n_target) if f'{i:05d}.wav' not in existing]
    print(f'  Converting {len(to_convert)} MP3s â†’ 16kHz mono WAVs (skipping {n_target - len(to_convert)} cached)')
    for i, mp3 in tqdm(to_convert):
        out = f'{out_dir}/{i:05d}.wav'
        subprocess.run(['ffmpeg', '-y', '-loglevel', 'error', '-i', mp3,
                        '-ac', '1', '-ar', '16000', out], check=False)
    print(f'  âœ“ {len(os.listdir(out_dir))} FMA WAVs ready')
# Out:
#   cached: 1500 FMA WAVs

# %%
# !wget -O /content/piper-sample-generator/models/fr_FR-mls-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/fr_FR-mls-medium.pt'
# !sed -i 's/torch.load(model_path)/torch.load(model_path, weights_only=False)/' /content/piper-sample-generator/generate_samples.py
# Out:
# --2026-08-28 20:29:38--  https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/fr_FR-mls-medium.pt
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/62cd11e6-77c8-4af7-9c10-63454dae5675?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-08-28T21%3A03%3A59Z&rscd=attachment%3B+filename%3Dfr_FR-mls-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-08-28T20%3A03%3A00Z&ske=2026-08-28T21%3A03%3A59Z&sks=b&skv=2018-11-09&sig=ToCOSSVTHURZmpUsgPLzI3VMe2muqw1w5kcG4kMEP2k%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4Nzk1MjU3OCwibmJmIjoxNzg3OTQ4OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yimDg60zHq80pQvLEBnIzU3yb6SuY7v2TsuOIb2PHD4&response-content-disposition=attachment%3B%20filename%3Dfr_FR-mls-medium.pt&response-content-type=application%2Foctet-stream [following]
# --2026-08-28 20:29:38--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/62cd11e6-77c8-4af7-9c10-63454dae5675?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-08-28T21%3A03%3A59Z&rscd=attachment%3B+filename%3Dfr_FR-mls-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-08-28T20%3A03%3A00Z&ske=2026-08-28T21%3A03%3A59Z&sks=b&skv=2018-11-09&sig=ToCOSSVTHURZmpUsgPLzI3VMe2muqw1w5kcG4kMEP2k%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4Nzk1MjU3OCwibmJmIjoxNzg3OTQ4OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yimDg60zHq80pQvLEBnIzU3yb6SuY7v2TsuOIb2PHD4&response-content-disposition=attachment%3B%20filename%3Dfr_FR-mls-medium.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202452523 (193M) [application/octet-stream]
# Saving to: ‘/content/piper-sample-generator/models/fr_FR-mls-medium.pt’
#
# /content/piper-samp 100%[===================>] 193.07M   257MB/s    in 0.8s
#
# 2026-08-28 20:29:39 (257 MB/s) - ‘/content/piper-sample-generator/models/fr_FR-mls-medium.pt’ saved [202452523/202452523]

# %% [markdown]
# ## 9. Subsample ACAV â€” 1.7 GB train + 170 MB val
#
# Full 17 GB would OOM training pass. **Validation slice stays as raw `(M, 96)`** â€” the hand-rolled trainer slides a 16-frame window over it itself.

# %%
import numpy as np, os
SRC = '/content/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
TRAIN_DST = '/content/acav_train_subset.npy'
VAL_DST   = '/content/acav_val_subset.npy'
if os.path.exists(TRAIN_DST) and os.path.exists(VAL_DST):
    train_arr = np.load(TRAIN_DST, mmap_mode='r')
    val_arr = np.load(VAL_DST, mmap_mode='r')
    print(f'  cached: train={train_arr.shape} ({train_arr.nbytes/1e9:.2f} GB), val={val_arr.shape} ({val_arr.nbytes/1e6:.0f} MB)')
else:
    if not os.path.exists(SRC):
        raise RuntimeError(f'ACAV source missing: {SRC} â€” re-run cell 7')
    arr = np.load(SRC, mmap_mode='r')
    print(f'  source: {arr.shape}, dtype={arr.dtype}')
    n_total = len(arr)
    n_train = n_total // 10
    n_val_rows = n_total // 100
    print(f'  slicing: train=[:{n_train}] (3-D), val=[{n_train}:{n_train+n_val_rows}] (flattened to 2-D)')
    train_chunk = np.array(arr[:n_train])
    np.save(TRAIN_DST, train_chunk)
    print(f'  âœ“ train: {train_chunk.shape} ({train_chunk.nbytes/1e9:.2f} GB)')
    del train_chunk
    val_chunk = np.array(arr[n_train:n_train+n_val_rows])
    val_flat = val_chunk.reshape(-1, val_chunk.shape[-1])
    np.save(VAL_DST, val_flat)
    print(f'  âœ“ val: {val_flat.shape} ({val_flat.nbytes/1e6:.0f} MB)')
    del val_chunk, val_flat
    os.remove(SRC)
    print('  removed 17 GB original')
# Out:
#   cached: train=(562500, 16, 96) (1.73 GB), val=(900000, 96) (173 MB)

# %% [markdown]
# ## 10. Build training config (no example-yaml dependency)
#
# Self-contained â€” every field set explicitly. Doesn't depend on upstream's `examples/` directory which has been renamed/removed across openwakeword versions.

# %%
import yaml, os

# ╔═══════════════════════════════════════════════════════════════════╗
# ║                   ★  EDIT THESE TWO LINES  ★                      ║
# ║                                                                   ║
# ║  TARGET_PHRASE: list of strings — what the model wakes on.        ║
# ║                 Multiple variants OK (e.g. "mr graves" plus       ║
# ║                 "mister graves") — they all map to the same       ║
# ║                 binary classifier output.                         ║
# ║                                                                   ║
# ║  MODEL_NAME:    short string — used for output filename + dirs.   ║
# ║                 No spaces, lowercase, snake_case.                 ║
# ╚═══════════════════════════════════════════════════════════════════╝
TARGET_PHRASE = ['hey vicky', 'ok vicky', 'okay vicky', 'dis vicky']
MODEL_NAME    = 'vicky'
# ── (you can leave everything else below alone) ──────────────────────

# Self-contained config — every field upstream train.py reads, set explicitly.
# Doesn't depend on any example yaml from the openwakeword repo (which has been
# renamed/removed across versions). Keys derived from grepping
# `config["..."]` in upstream train.py @ master 2026-05-09.
config = {
    # ── Wake-word ───────────────────────────────────────────────────────
    'target_phrase':   TARGET_PHRASE,
    'model_name':      MODEL_NAME,
    # Empty list → only auto-generated adversarial phonemes used as negatives.
    # Upstream code (line 707/730) does:
    #   adversarial_texts = config["custom_negative_phrases"]
    #   adversarial_texts.extend(generate_adversarial_texts(...))
    # — so the key MUST exist as a mutable list (KeyError otherwise) but
    # `[]` is fine; auto-generated negatives still get appended.
    'custom_negative_phrases': [],

    # ── Synthetic clip generation ───────────────────────────────────────
    'n_samples':       5000,    # bump for harder phrases / longer training
    'n_samples_val':   1000,
    'tts_batch_size':  50,
    'piper_sample_generator_path': '/content/piper-sample-generator',

    # ── Augmentation ────────────────────────────────────────────────────
    'augmentation_rounds':    1,
    # Upstream comment in custom_model.yml: "not too large to ensure variety
    # in augmentation". Upstream default = 16.
    'augmentation_batch_size': 16,

    # ── Training (read by hand-rolled trainer in cell 14) ──────────────
    'steps':           20000,
    'max_negative_weight': 3000,    # bump to 3000 if FP rate too high after stage 1
    'target_accuracy': 0.7,
    'target_recall':   0.5,
    'target_false_positives_per_hour': 0.5,
    'batch_size':      128,
    'learning_rate':   1e-4,

    # ── Model arch (matches openwakeword's DNN exactly) ────────────────
    'model_type':      'dnn',
    'layer_dim':       128,
    # Upstream's --train_model path (line 826) reads `layer_size` not layer_dim.
    'layer_size':      128,
    'n_blocks':        1,
    'model_input_shape': [16, 96],
    'n_classes':       1,
    'batch_n_per_class': {
        'ACAV100M_sample':       1024,
        'adversarial_negative':    50,
        'positive':                50,
    },

    # ── Data paths ──────────────────────────────────────────────────────
    'background_paths': ['/content/fma_wav'],
    'background_paths_duplication_rate': [1],
    'rir_paths':        ['/content/mit_rirs'],
    'false_positive_validation_data_path': '/content/acav_val_subset.npy',
    'feature_data_files': {'ACAV100M_sample': '/content/acav_train_subset.npy'},
    'output_dir':       f'/content/{MODEL_NAME}_output',
    'tflite_export':    False,
    'onnx_export':      True,

    # ── Clip dirs (used by hand-rolled trainer) ────────────────────────
    'positive_clips_train_dir': f'/content/{MODEL_NAME}_output/{MODEL_NAME}/positive_train',
    'positive_clips_test_dir':  f'/content/{MODEL_NAME}_output/{MODEL_NAME}/positive_test',
    'negative_clips_train_dir': f'/content/{MODEL_NAME}_output/{MODEL_NAME}/negative_train',
    'negative_clips_test_dir':  f'/content/{MODEL_NAME}_output/{MODEL_NAME}/negative_test',
    'feature_save_dir':         f'/content/{MODEL_NAME}_output/{MODEL_NAME}',
}
os.makedirs(config['output_dir'], exist_ok=True)
with open('/content/my_model.yaml', 'w') as f:
    yaml.dump(config, f, sort_keys=False)
print(f'  target_phrase: {config["target_phrase"]}')
print(f'  model_name:    {config["model_name"]}')
print(f'  steps:         {config["steps"]}')
print(f'  max_neg_w:     {config["max_negative_weight"]}')
print(f'  target_recall: {config["target_recall"]}')
print(f'  target_fp/hr:  {config["target_false_positives_per_hour"]}')
# Out:
#   target_phrase: ['hey vicky', 'ok vicky', 'okay vicky', 'dis vicky']
#   model_name:    vicky
#   steps:         20000
#   max_neg_w:     3000
#   target_recall: 0.5
#   target_fp/hr:  0.5

# %% [markdown]
# ## 11. Generate Piper TTS clips (~10-15 min)
#
# Uses openwakeword's --generate_clips runner which reads from my_model.yaml. Idempotent â€” re-running finds existing clips and skips.

# %%
# !pip install -e /content/openwakeword --no-deps
# Out:
# Obtaining file:///content/openwakeword
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: openwakeword
#   Building editable for openwakeword (pyproject.toml) ... done
#   Created wheel for openwakeword: filename=openwakeword-0.6.0-0.editable-py3-none-any.whl size=17481 sha256=758f626c8477470830e5a5d4df35546e9e37a24d02f445a769343d909b3caf10
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tu55i1fg/wheels/ab/c1/1e/c1da6751c7c7c120456c5bb1ff850c19b0893c1a0c516fd292
# Successfully built openwakeword
# Installing collected packages: openwakeword
#   Attempting uninstall: openwakeword
#     Found existing installation: openwakeword 0.6.0
#     Uninstalling openwakeword-0.6.0:
#       Successfully uninstalled openwakeword-0.6.0
# Successfully installed openwakeword-0.6.0

# %%
# !python3 -c "import openwakeword; print('OK subprocess')"
# Out:
# OK subprocess

# %%
import sys, os, yaml
# Idempotent: check ALL FOUR clip dirs and skip the generate_clips invocation
# only if every dir is fully populated. Upstream's `n_current_samples <= 0.95
# *n_samples` checks at lines 675/692/706/729 in train.py also skip cached
# dirs internally, so re-running is safe even if some dirs are partial.
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
dirs = {
    'positive_train': (cfg['positive_clips_train_dir'], int(cfg['n_samples'] * 0.75)),
    'positive_test':  (cfg['positive_clips_test_dir'],  int(cfg['n_samples_val'] * 0.75)),
    'negative_train': (cfg['negative_clips_train_dir'], int(cfg['n_samples'] * 0.75)),
    'negative_test':  (cfg['negative_clips_test_dir'],  int(cfg['n_samples_val'] * 0.75)),
}
status = []
for name, (path, expected) in dirs.items():
    n = len(os.listdir(path)) if os.path.isdir(path) else 0
    status.append((name, n, expected, n >= expected))
all_full = all(ok for _, _, _, ok in status)
for name, n, expected, ok in status:
    print(f'  {"PASS" if ok else "MISS"} {name}: {n} clips (expect >={expected})')
if all_full:
    print('\n  cached: all 4 clip dirs already populated')
else:
    print('\n  -> running generate_clips (upstream skips cached dirs internally)')
    # !{sys.executable} /content/openwakeword/openwakeword/train.py \
        --training_config /content/my_model.yaml \
        --generate_clips
    for name, (path, expected) in dirs.items():
        n = len(os.listdir(path)) if os.path.isdir(path) else 0
        assert n >= expected, f'generate_clips left {name} with only {n} clips (expected >={expected})'
    print('\n  PASS all 4 clip dirs now populated')
# Out:
#   MISS positive_train: 0 clips (expect >=3750)
#   MISS positive_test: 0 clips (expect >=750)
#   MISS negative_train: 0 clips (expect >=3750)
#   MISS negative_test: 0 clips (expect >=750)
#
#   -> running generate_clips (upstream skips cached dirs internally)
# INFO:root:##################################################
# Generating positive clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/100 complete
# DEBUG:generate_samples:Batch 2/100 complete
# DEBUG:generate_samples:Batch 3/100 complete
# DEBUG:generate_samples:Batch 4/100 complete
# DEBUG:generate_samples:Batch 5/100 complete
# DEBUG:generate_samples:Batch 6/100 complete
# DEBUG:generate_samples:Batch 7/100 complete
# DEBUG:generate_samples:Batch 8/100 complete
# DEBUG:generate_samples:Batch 9/100 complete
# DEBUG:generate_samples:Batch 10/100 complete
# DEBUG:generate_samples:Batch 11/100 complete
# DEBUG:generate_samples:Batch 12/100 complete
# DEBUG:generate_samples:Batch 13/100 complete
# DEBUG:generate_samples:Batch 14/100 complete
# DEBUG:generate_samples:Batch 15/100 complete
# DEBUG:generate_samples:Batch 16/100 complete
# DEBUG:generate_samples:Batch 17/100 complete
# DEBUG:generate_samples:Batch 18/100 complete
# DEBUG:generate_samples:Batch 19/100 complete
# DEBUG:generate_samples:Batch 20/100 complete
# DEBUG:generate_samples:Batch 21/100 complete
# DEBUG:generate_samples:Batch 22/100 complete
# DEBUG:generate_samples:Batch 23/100 complete
# DEBUG:generate_samples:Batch 24/100 complete
# DEBUG:generate_samples:Batch 25/100 complete
# DEBUG:generate_samples:Batch 26/100 complete
# DEBUG:generate_samples:Batch 27/100 complete
# DEBUG:generate_samples:Batch 28/100 complete
# DEBUG:generate_samples:Batch 29/100 complete
# DEBUG:generate_samples:Batch 30/100 complete
# DEBUG:generate_samples:Batch 31/100 complete
# DEBUG:generate_samples:Batch 32/100 complete
# DEBUG:generate_samples:Batch 33/100 complete
# DEBUG:generate_samples:Batch 34/100 complete
# DEBUG:generate_samples:Batch 35/100 complete
# DEBUG:generate_samples:Batch 36/100 complete
# DEBUG:generate_samples:Batch 37/100 complete
# DEBUG:generate_samples:Batch 38/100 complete
# DEBUG:generate_samples:Batch 39/100 complete
# DEBUG:generate_samples:Batch 40/100 complete
# DEBUG:generate_samples:Batch 41/100 complete
# DEBUG:generate_samples:Batch 42/100 complete
# DEBUG:generate_samples:Batch 43/100 complete
# DEBUG:generate_samples:Batch 44/100 complete
# DEBUG:generate_samples:Batch 45/100 complete
# DEBUG:generate_samples:Batch 46/100 complete
# DEBUG:generate_samples:Batch 47/100 complete
# DEBUG:generate_samples:Batch 48/100 complete
# DEBUG:generate_samples:Batch 49/100 complete
# DEBUG:generate_samples:Batch 50/100 complete
# DEBUG:generate_samples:Batch 51/100 complete
# DEBUG:generate_samples:Batch 52/100 complete
# DEBUG:generate_samples:Batch 53/100 complete
# DEBUG:generate_samples:Batch 54/100 complete
# DEBUG:generate_samples:Batch 55/100 complete
# DEBUG:generate_samples:Batch 56/100 complete
# DEBUG:generate_samples:Batch 57/100 complete
# DEBUG:generate_samples:Batch 58/100 complete
# DEBUG:generate_samples:Batch 59/100 complete
# DEBUG:generate_samples:Batch 60/100 complete
# DEBUG:generate_samples:Batch 61/100 complete
# DEBUG:generate_samples:Batch 62/100 complete
# DEBUG:generate_samples:Batch 63/100 complete
# DEBUG:generate_samples:Batch 64/100 complete
# DEBUG:generate_samples:Batch 65/100 complete
# DEBUG:generate_samples:Batch 66/100 complete
# DEBUG:generate_samples:Batch 67/100 complete
# DEBUG:generate_samples:Batch 68/100 complete
# DEBUG:generate_samples:Batch 69/100 complete
# DEBUG:generate_samples:Batch 70/100 complete
# DEBUG:generate_samples:Batch 71/100 complete
# DEBUG:generate_samples:Batch 72/100 complete
# DEBUG:generate_samples:Batch 73/100 complete
# DEBUG:generate_samples:Batch 74/100 complete
# DEBUG:generate_samples:Batch 75/100 complete
# DEBUG:generate_samples:Batch 76/100 complete
# DEBUG:generate_samples:Batch 77/100 complete
# DEBUG:generate_samples:Batch 78/100 complete
# DEBUG:generate_samples:Batch 79/100 complete
# DEBUG:generate_samples:Batch 80/100 complete
# DEBUG:generate_samples:Batch 81/100 complete
# DEBUG:generate_samples:Batch 82/100 complete
# DEBUG:generate_samples:Batch 83/100 complete
# DEBUG:generate_samples:Batch 84/100 complete
# DEBUG:generate_samples:Batch 85/100 complete
# DEBUG:generate_samples:Batch 86/100 complete
# DEBUG:generate_samples:Batch 87/100 complete
# DEBUG:generate_samples:Batch 88/100 complete
# DEBUG:generate_samples:Batch 89/100 complete
# DEBUG:generate_samples:Batch 90/100 complete
# DEBUG:generate_samples:Batch 91/100 complete
# DEBUG:generate_samples:Batch 92/100 complete
# DEBUG:generate_samples:Batch 93/100 complete
# DEBUG:generate_samples:Batch 94/100 complete
# DEBUG:generate_samples:Batch 95/100 complete
# DEBUG:generate_samples:Batch 96/100 complete
# DEBUG:generate_samples:Batch 97/100 complete
# DEBUG:generate_samples:Batch 98/100 complete
# DEBUG:generate_samples:Batch 99/100 complete
# DEBUG:generate_samples:Batch 100/100 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating positive clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/20 complete
# DEBUG:generate_samples:Batch 2/20 complete
# DEBUG:generate_samples:Batch 3/20 complete
# DEBUG:generate_samples:Batch 4/20 complete
# DEBUG:generate_samples:Batch 5/20 complete
# DEBUG:generate_samples:Batch 6/20 complete
# DEBUG:generate_samples:Batch 7/20 complete
# DEBUG:generate_samples:Batch 8/20 complete
# DEBUG:generate_samples:Batch 9/20 complete
# DEBUG:generate_samples:Batch 10/20 complete
# DEBUG:generate_samples:Batch 11/20 complete
# DEBUG:generate_samples:Batch 12/20 complete
# DEBUG:generate_samples:Batch 13/20 complete
# DEBUG:generate_samples:Batch 14/20 complete
# DEBUG:generate_samples:Batch 15/20 complete
# DEBUG:generate_samples:Batch 16/20 complete
# DEBUG:generate_samples:Batch 17/20 complete
# DEBUG:generate_samples:Batch 18/20 complete
# DEBUG:generate_samples:Batch 19/20 complete
# DEBUG:generate_samples:Batch 20/20 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/714 complete
# DEBUG:generate_samples:Batch 2/714 complete
# DEBUG:generate_samples:Batch 3/714 complete
# DEBUG:generate_samples:Batch 4/714 complete
# DEBUG:generate_samples:Batch 5/714 complete
# DEBUG:generate_samples:Batch 6/714 complete
# DEBUG:generate_samples:Batch 7/714 complete
# DEBUG:generate_samples:Batch 8/714 complete
# DEBUG:generate_samples:Batch 9/714 complete
# DEBUG:generate_samples:Batch 10/714 complete
# DEBUG:generate_samples:Batch 11/714 complete
# DEBUG:generate_samples:Batch 12/714 complete
# DEBUG:generate_samples:Batch 13/714 complete
# DEBUG:generate_samples:Batch 14/714 complete
# DEBUG:generate_samples:Batch 15/714 complete
# DEBUG:generate_samples:Batch 16/714 complete
# DEBUG:generate_samples:Batch 17/714 complete
# DEBUG:generate_samples:Batch 18/714 complete
# DEBUG:generate_samples:Batch 19/714 complete
# DEBUG:generate_samples:Batch 20/714 complete
# DEBUG:generate_samples:Batch 21/714 complete
# DEBUG:generate_samples:Batch 22/714 complete
# DEBUG:generate_samples:Batch 23/714 complete
# DEBUG:generate_samples:Batch 24/714 complete
# DEBUG:generate_samples:Batch 25/714 complete
# DEBUG:generate_samples:Batch 26/714 complete
# DEBUG:generate_samples:Batch 27/714 complete
# DEBUG:generate_samples:Batch 28/714 complete
# DEBUG:generate_samples:Batch 29/714 complete
# DEBUG:generate_samples:Batch 30/714 complete
# DEBUG:generate_samples:Batch 31/714 complete
# DEBUG:generate_samples:Batch 32/714 complete
# DEBUG:generate_samples:Batch 33/714 complete
# DEBUG:generate_samples:Batch 34/714 complete
# DEBUG:generate_samples:Batch 35/714 complete
# DEBUG:generate_samples:Batch 36/714 complete
# DEBUG:generate_samples:Batch 37/714 complete
# DEBUG:generate_samples:Batch 38/714 complete
# DEBUG:generate_samples:Batch 39/714 complete
# DEBUG:generate_samples:Batch 40/714 complete
# DEBUG:generate_samples:Batch 41/714 complete
# DEBUG:generate_samples:Batch 42/714 complete
# DEBUG:generate_samples:Batch 43/714 complete
# DEBUG:generate_samples:Batch 44/714 complete
# DEBUG:generate_samples:Batch 45/714 complete
# DEBUG:generate_samples:Batch 46/714 complete
# DEBUG:generate_samples:Batch 47/714 complete
# DEBUG:generate_samples:Batch 48/714 complete
# DEBUG:generate_samples:Batch 49/714 complete
# DEBUG:generate_samples:Batch 50/714 complete
# DEBUG:generate_samples:Batch 51/714 complete
# DEBUG:generate_samples:Batch 52/714 complete
# DEBUG:generate_samples:Batch 53/714 complete
# DEBUG:generate_samples:Batch 54/714 complete
# DEBUG:generate_samples:Batch 55/714 complete
# DEBUG:generate_samples:Batch 56/714 complete
# DEBUG:generate_samples:Batch 57/714 complete
# DEBUG:generate_samples:Batch 58/714 complete
# DEBUG:generate_samples:Batch 59/714 complete
# DEBUG:generate_samples:Batch 60/714 complete
# DEBUG:generate_samples:Batch 61/714 complete
# DEBUG:generate_samples:Batch 62/714 complete
# DEBUG:generate_samples:Batch 63/714 complete
# DEBUG:generate_samples:Batch 64/714 complete
# DEBUG:generate_samples:Batch 65/714 complete
# DEBUG:generate_samples:Batch 66/714 complete
# DEBUG:generate_samples:Batch 67/714 complete
# DEBUG:generate_samples:Batch 68/714 complete
# DEBUG:generate_samples:Batch 69/714 complete
# DEBUG:generate_samples:Batch 70/714 complete
# DEBUG:generate_samples:Batch 71/714 complete
# DEBUG:generate_samples:Batch 72/714 complete
# DEBUG:generate_samples:Batch 73/714 complete
# DEBUG:generate_samples:Batch 74/714 complete
# DEBUG:generate_samples:Batch 75/714 complete
# DEBUG:generate_samples:Batch 76/714 complete
# DEBUG:generate_samples:Batch 77/714 complete
# DEBUG:generate_samples:Batch 78/714 complete
# DEBUG:generate_samples:Batch 79/714 complete
# DEBUG:generate_samples:Batch 80/714 complete
# DEBUG:generate_samples:Batch 81/714 complete
# DEBUG:generate_samples:Batch 82/714 complete
# DEBUG:generate_samples:Batch 83/714 complete
# DEBUG:generate_samples:Batch 84/714 complete
# DEBUG:generate_samples:Batch 85/714 complete
# DEBUG:generate_samples:Batch 86/714 complete
# DEBUG:generate_samples:Batch 87/714 complete
# DEBUG:generate_samples:Batch 88/714 complete
# DEBUG:generate_samples:Batch 89/714 complete
# DEBUG:generate_samples:Batch 90/714 complete
# DEBUG:generate_samples:Batch 91/714 complete
# DEBUG:generate_samples:Batch 92/714 complete
# DEBUG:generate_samples:Batch 93/714 complete
# DEBUG:generate_samples:Batch 94/714 complete
# DEBUG:generate_samples:Batch 95/714 complete
# DEBUG:generate_samples:Batch 96/714 complete
# DEBUG:generate_samples:Batch 97/714 complete
# DEBUG:generate_samples:Batch 98/714 complete
# DEBUG:generate_samples:Batch 99/714 complete
# DEBUG:generate_samples:Batch 100/714 complete
# DEBUG:generate_samples:Batch 101/714 complete
# DEBUG:generate_samples:Batch 102/714 complete
# DEBUG:generate_samples:Batch 103/714 complete
# DEBUG:generate_samples:Batch 104/714 complete
# DEBUG:generate_samples:Batch 105/714 complete
# DEBUG:generate_samples:Batch 106/714 complete
# DEBUG:generate_samples:Batch 107/714 complete
# DEBUG:generate_samples:Batch 108/714 complete
# DEBUG:generate_samples:Batch 109/714 complete
# DEBUG:generate_samples:Batch 110/714 complete
# DEBUG:generate_samples:Batch 111/714 complete
# DEBUG:generate_samples:Batch 112/714 complete
# DEBUG:generate_samples:Batch 113/714 complete
# DEBUG:generate_samples:Batch 114/714 complete
# DEBUG:generate_samples:Batch 115/714 complete
# DEBUG:generate_samples:Batch 116/714 complete
# DEBUG:generate_samples:Batch 117/714 complete
# DEBUG:generate_samples:Batch 118/714 complete
# DEBUG:generate_samples:Batch 119/714 complete
# DEBUG:generate_samples:Batch 120/714 complete
# DEBUG:generate_samples:Batch 121/714 complete
# DEBUG:generate_samples:Batch 122/714 complete
# DEBUG:generate_samples:Batch 123/714 complete
# DEBUG:generate_samples:Batch 124/714 complete
# DEBUG:generate_samples:Batch 125/714 complete
# DEBUG:generate_samples:Batch 126/714 complete
# DEBUG:generate_samples:Batch 127/714 complete
# DEBUG:generate_samples:Batch 128/714 complete
# DEBUG:generate_samples:Batch 129/714 complete
# DEBUG:generate_samples:Batch 130/714 complete
# DEBUG:generate_samples:Batch 131/714 complete
# DEBUG:generate_samples:Batch 132/714 complete
# DEBUG:generate_samples:Batch 133/714 complete
# DEBUG:generate_samples:Batch 134/714 complete
# DEBUG:generate_samples:Batch 135/714 complete
# DEBUG:generate_samples:Batch 136/714 complete
# DEBUG:generate_samples:Batch 137/714 complete
# DEBUG:generate_samples:Batch 138/714 complete
# DEBUG:generate_samples:Batch 139/714 complete
# DEBUG:generate_samples:Batch 140/714 complete
# DEBUG:generate_samples:Batch 141/714 complete
# DEBUG:generate_samples:Batch 142/714 complete
# DEBUG:generate_samples:Batch 143/714 complete
# DEBUG:generate_samples:Batch 144/714 complete
# DEBUG:generate_samples:Batch 145/714 complete
# DEBUG:generate_samples:Batch 146/714 complete
# DEBUG:generate_samples:Batch 147/714 complete
# DEBUG:generate_samples:Batch 148/714 complete
# DEBUG:generate_samples:Batch 149/714 complete
# DEBUG:generate_samples:Batch 150/714 complete
# DEBUG:generate_samples:Batch 151/714 complete
# DEBUG:generate_samples:Batch 152/714 complete
# DEBUG:generate_samples:Batch 153/714 complete
# DEBUG:generate_samples:Batch 154/714 complete
# DEBUG:generate_samples:Batch 155/714 complete
# DEBUG:generate_samples:Batch 156/714 complete
# DEBUG:generate_samples:Batch 157/714 complete
# DEBUG:generate_samples:Batch 158/714 complete
# DEBUG:generate_samples:Batch 159/714 complete
# DEBUG:generate_samples:Batch 160/714 complete
# DEBUG:generate_samples:Batch 161/714 complete
# DEBUG:generate_samples:Batch 162/714 complete
# DEBUG:generate_samples:Batch 163/714 complete
# DEBUG:generate_samples:Batch 164/714 complete
# DEBUG:generate_samples:Batch 165/714 complete
# DEBUG:generate_samples:Batch 166/714 complete
# DEBUG:generate_samples:Batch 167/714 complete
# DEBUG:generate_samples:Batch 168/714 complete
# DEBUG:generate_samples:Batch 169/714 complete
# DEBUG:generate_samples:Batch 170/714 complete
# DEBUG:generate_samples:Batch 171/714 complete
# DEBUG:generate_samples:Batch 172/714 complete
# DEBUG:generate_samples:Batch 173/714 complete
# DEBUG:generate_samples:Batch 174/714 complete
# DEBUG:generate_samples:Batch 175/714 complete
# DEBUG:generate_samples:Batch 176/714 complete
# DEBUG:generate_samples:Batch 177/714 complete
# DEBUG:generate_samples:Batch 178/714 complete
# DEBUG:generate_samples:Batch 179/714 complete
# DEBUG:generate_samples:Batch 180/714 complete
# DEBUG:generate_samples:Batch 181/714 complete
# DEBUG:generate_samples:Batch 182/714 complete
# DEBUG:generate_samples:Batch 183/714 complete
# DEBUG:generate_samples:Batch 184/714 complete
# DEBUG:generate_samples:Batch 185/714 complete
# DEBUG:generate_samples:Batch 186/714 complete
# DEBUG:generate_samples:Batch 187/714 complete
# DEBUG:generate_samples:Batch 188/714 complete
# DEBUG:generate_samples:Batch 189/714 complete
# DEBUG:generate_samples:Batch 190/714 complete
# DEBUG:generate_samples:Batch 191/714 complete
# DEBUG:generate_samples:Batch 192/714 complete
# DEBUG:generate_samples:Batch 193/714 complete
# DEBUG:generate_samples:Batch 194/714 complete
# DEBUG:generate_samples:Batch 195/714 complete
# DEBUG:generate_samples:Batch 196/714 complete
# DEBUG:generate_samples:Batch 197/714 complete
# DEBUG:generate_samples:Batch 198/714 complete
# DEBUG:generate_samples:Batch 199/714 complete
# DEBUG:generate_samples:Batch 200/714 complete
# DEBUG:generate_samples:Batch 201/714 complete
# DEBUG:generate_samples:Batch 202/714 complete
# DEBUG:generate_samples:Batch 203/714 complete
# DEBUG:generate_samples:Batch 204/714 complete
# DEBUG:generate_samples:Batch 205/714 complete
# DEBUG:generate_samples:Batch 206/714 complete
# DEBUG:generate_samples:Batch 207/714 complete
# DEBUG:generate_samples:Batch 208/714 complete
# DEBUG:generate_samples:Batch 209/714 complete
# DEBUG:generate_samples:Batch 210/714 complete
# DEBUG:generate_samples:Batch 211/714 complete
# DEBUG:generate_samples:Batch 212/714 complete
# DEBUG:generate_samples:Batch 213/714 complete
# DEBUG:generate_samples:Batch 214/714 complete
# DEBUG:generate_samples:Batch 215/714 complete
# DEBUG:generate_samples:Batch 216/714 complete
# DEBUG:generate_samples:Batch 217/714 complete
# DEBUG:generate_samples:Batch 218/714 complete
# DEBUG:generate_samples:Batch 219/714 complete
# DEBUG:generate_samples:Batch 220/714 complete
# DEBUG:generate_samples:Batch 221/714 complete
# DEBUG:generate_samples:Batch 222/714 complete
# DEBUG:generate_samples:Batch 223/714 complete
# DEBUG:generate_samples:Batch 224/714 complete
# DEBUG:generate_samples:Batch 225/714 complete
# DEBUG:generate_samples:Batch 226/714 complete
# DEBUG:generate_samples:Batch 227/714 complete
# DEBUG:generate_samples:Batch 228/714 complete
# DEBUG:generate_samples:Batch 229/714 complete
# DEBUG:generate_samples:Batch 230/714 complete
# DEBUG:generate_samples:Batch 231/714 complete
# DEBUG:generate_samples:Batch 232/714 complete
# DEBUG:generate_samples:Batch 233/714 complete
# DEBUG:generate_samples:Batch 234/714 complete
# DEBUG:generate_samples:Batch 235/714 complete
# DEBUG:generate_samples:Batch 236/714 complete
# DEBUG:generate_samples:Batch 237/714 complete
# DEBUG:generate_samples:Batch 238/714 complete
# DEBUG:generate_samples:Batch 239/714 complete
# DEBUG:generate_samples:Batch 240/714 complete
# DEBUG:generate_samples:Batch 241/714 complete
# DEBUG:generate_samples:Batch 242/714 complete
# DEBUG:generate_samples:Batch 243/714 complete
# DEBUG:generate_samples:Batch 244/714 complete
# DEBUG:generate_samples:Batch 245/714 complete
# DEBUG:generate_samples:Batch 246/714 complete
# DEBUG:generate_samples:Batch 247/714 complete
# DEBUG:generate_samples:Batch 248/714 complete
# DEBUG:generate_samples:Batch 249/714 complete
# DEBUG:generate_samples:Batch 250/714 complete
# DEBUG:generate_samples:Batch 251/714 complete
# DEBUG:generate_samples:Batch 252/714 complete
# DEBUG:generate_samples:Batch 253/714 complete
# DEBUG:generate_samples:Batch 254/714 complete
# DEBUG:generate_samples:Batch 255/714 complete
# DEBUG:generate_samples:Batch 256/714 complete
# DEBUG:generate_samples:Batch 257/714 complete
# DEBUG:generate_samples:Batch 258/714 complete
# DEBUG:generate_samples:Batch 259/714 complete
# DEBUG:generate_samples:Batch 260/714 complete
# DEBUG:generate_samples:Batch 261/714 complete
# DEBUG:generate_samples:Batch 262/714 complete
# DEBUG:generate_samples:Batch 263/714 complete
# DEBUG:generate_samples:Batch 264/714 complete
# DEBUG:generate_samples:Batch 265/714 complete
# DEBUG:generate_samples:Batch 266/714 complete
# DEBUG:generate_samples:Batch 267/714 complete
# DEBUG:generate_samples:Batch 268/714 complete
# DEBUG:generate_samples:Batch 269/714 complete
# DEBUG:generate_samples:Batch 270/714 complete
# DEBUG:generate_samples:Batch 271/714 complete
# DEBUG:generate_samples:Batch 272/714 complete
# DEBUG:generate_samples:Batch 273/714 complete
# DEBUG:generate_samples:Batch 274/714 complete
# DEBUG:generate_samples:Batch 275/714 complete
# DEBUG:generate_samples:Batch 276/714 complete
# DEBUG:generate_samples:Batch 277/714 complete
# DEBUG:generate_samples:Batch 278/714 complete
# DEBUG:generate_samples:Batch 279/714 complete
# DEBUG:generate_samples:Batch 280/714 complete
# DEBUG:generate_samples:Batch 281/714 complete
# DEBUG:generate_samples:Batch 282/714 complete
# DEBUG:generate_samples:Batch 283/714 complete
# DEBUG:generate_samples:Batch 284/714 complete
# DEBUG:generate_samples:Batch 285/714 complete
# DEBUG:generate_samples:Batch 286/714 complete
# DEBUG:generate_samples:Batch 287/714 complete
# DEBUG:generate_samples:Batch 288/714 complete
# DEBUG:generate_samples:Batch 289/714 complete
# DEBUG:generate_samples:Batch 290/714 complete
# DEBUG:generate_samples:Batch 291/714 complete
# DEBUG:generate_samples:Batch 292/714 complete
# DEBUG:generate_samples:Batch 293/714 complete
# DEBUG:generate_samples:Batch 294/714 complete
# DEBUG:generate_samples:Batch 295/714 complete
# DEBUG:generate_samples:Batch 296/714 complete
# DEBUG:generate_samples:Batch 297/714 complete
# DEBUG:generate_samples:Batch 298/714 complete
# DEBUG:generate_samples:Batch 299/714 complete
# DEBUG:generate_samples:Batch 300/714 complete
# DEBUG:generate_samples:Batch 301/714 complete
# DEBUG:generate_samples:Batch 302/714 complete
# DEBUG:generate_samples:Batch 303/714 complete
# DEBUG:generate_samples:Batch 304/714 complete
# DEBUG:generate_samples:Batch 305/714 complete
# DEBUG:generate_samples:Batch 306/714 complete
# DEBUG:generate_samples:Batch 307/714 complete
# DEBUG:generate_samples:Batch 308/714 complete
# DEBUG:generate_samples:Batch 309/714 complete
# DEBUG:generate_samples:Batch 310/714 complete
# DEBUG:generate_samples:Batch 311/714 complete
# DEBUG:generate_samples:Batch 312/714 complete
# DEBUG:generate_samples:Batch 313/714 complete
# DEBUG:generate_samples:Batch 314/714 complete
# DEBUG:generate_samples:Batch 315/714 complete
# DEBUG:generate_samples:Batch 316/714 complete
# DEBUG:generate_samples:Batch 317/714 complete
# DEBUG:generate_samples:Batch 318/714 complete
# DEBUG:generate_samples:Batch 319/714 complete
# DEBUG:generate_samples:Batch 320/714 complete
# DEBUG:generate_samples:Batch 321/714 complete
# DEBUG:generate_samples:Batch 322/714 complete
# DEBUG:generate_samples:Batch 323/714 complete
# DEBUG:generate_samples:Batch 324/714 complete
# DEBUG:generate_samples:Batch 325/714 complete
# DEBUG:generate_samples:Batch 326/714 complete
# DEBUG:generate_samples:Batch 327/714 complete
# DEBUG:generate_samples:Batch 328/714 complete
# DEBUG:generate_samples:Batch 329/714 complete
# DEBUG:generate_samples:Batch 330/714 complete
# DEBUG:generate_samples:Batch 331/714 complete
# DEBUG:generate_samples:Batch 332/714 complete
# DEBUG:generate_samples:Batch 333/714 complete
# DEBUG:generate_samples:Batch 334/714 complete
# DEBUG:generate_samples:Batch 335/714 complete
# DEBUG:generate_samples:Batch 336/714 complete
# DEBUG:generate_samples:Batch 337/714 complete
# DEBUG:generate_samples:Batch 338/714 complete
# DEBUG:generate_samples:Batch 339/714 complete
# DEBUG:generate_samples:Batch 340/714 complete
# DEBUG:generate_samples:Batch 341/714 complete
# DEBUG:generate_samples:Batch 342/714 complete
# DEBUG:generate_samples:Batch 343/714 complete
# DEBUG:generate_samples:Batch 344/714 complete
# DEBUG:generate_samples:Batch 345/714 complete
# DEBUG:generate_samples:Batch 346/714 complete
# DEBUG:generate_samples:Batch 347/714 complete
# DEBUG:generate_samples:Batch 348/714 complete
# DEBUG:generate_samples:Batch 349/714 complete
# DEBUG:generate_samples:Batch 350/714 complete
# DEBUG:generate_samples:Batch 351/714 complete
# DEBUG:generate_samples:Batch 352/714 complete
# DEBUG:generate_samples:Batch 353/714 complete
# DEBUG:generate_samples:Batch 354/714 complete
# DEBUG:generate_samples:Batch 355/714 complete
# DEBUG:generate_samples:Batch 356/714 complete
# DEBUG:generate_samples:Batch 357/714 complete
# DEBUG:generate_samples:Batch 358/714 complete
# DEBUG:generate_samples:Batch 359/714 complete
# DEBUG:generate_samples:Batch 360/714 complete
# DEBUG:generate_samples:Batch 361/714 complete
# DEBUG:generate_samples:Batch 362/714 complete
# DEBUG:generate_samples:Batch 363/714 complete
# DEBUG:generate_samples:Batch 364/714 complete
# DEBUG:generate_samples:Batch 365/714 complete
# DEBUG:generate_samples:Batch 366/714 complete
# DEBUG:generate_samples:Batch 367/714 complete
# DEBUG:generate_samples:Batch 368/714 complete
# DEBUG:generate_samples:Batch 369/714 complete
# DEBUG:generate_samples:Batch 370/714 complete
# DEBUG:generate_samples:Batch 371/714 complete
# DEBUG:generate_samples:Batch 372/714 complete
# DEBUG:generate_samples:Batch 373/714 complete
# DEBUG:generate_samples:Batch 374/714 complete
# DEBUG:generate_samples:Batch 375/714 complete
# DEBUG:generate_samples:Batch 376/714 complete
# DEBUG:generate_samples:Batch 377/714 complete
# DEBUG:generate_samples:Batch 378/714 complete
# DEBUG:generate_samples:Batch 379/714 complete
# DEBUG:generate_samples:Batch 380/714 complete
# DEBUG:generate_samples:Batch 381/714 complete
# DEBUG:generate_samples:Batch 382/714 complete
# DEBUG:generate_samples:Batch 383/714 complete
# DEBUG:generate_samples:Batch 384/714 complete
# DEBUG:generate_samples:Batch 385/714 complete
# DEBUG:generate_samples:Batch 386/714 complete
# DEBUG:generate_samples:Batch 387/714 complete
# DEBUG:generate_samples:Batch 388/714 complete
# DEBUG:generate_samples:Batch 389/714 complete
# DEBUG:generate_samples:Batch 390/714 complete
# DEBUG:generate_samples:Batch 391/714 complete
# DEBUG:generate_samples:Batch 392/714 complete
# DEBUG:generate_samples:Batch 393/714 complete
# DEBUG:generate_samples:Batch 394/714 complete
# DEBUG:generate_samples:Batch 395/714 complete
# DEBUG:generate_samples:Batch 396/714 complete
# DEBUG:generate_samples:Batch 397/714 complete
# DEBUG:generate_samples:Batch 398/714 complete
# DEBUG:generate_samples:Batch 399/714 complete
# DEBUG:generate_samples:Batch 400/714 complete
# DEBUG:generate_samples:Batch 401/714 complete
# DEBUG:generate_samples:Batch 402/714 complete
# DEBUG:generate_samples:Batch 403/714 complete
# DEBUG:generate_samples:Batch 404/714 complete
# DEBUG:generate_samples:Batch 405/714 complete
# DEBUG:generate_samples:Batch 406/714 complete
# DEBUG:generate_samples:Batch 407/714 complete
# DEBUG:generate_samples:Batch 408/714 complete
# DEBUG:generate_samples:Batch 409/714 complete
# DEBUG:generate_samples:Batch 410/714 complete
# DEBUG:generate_samples:Batch 411/714 complete
# DEBUG:generate_samples:Batch 412/714 complete
# DEBUG:generate_samples:Batch 413/714 complete
# DEBUG:generate_samples:Batch 414/714 complete
# DEBUG:generate_samples:Batch 415/714 complete
# DEBUG:generate_samples:Batch 416/714 complete
# DEBUG:generate_samples:Batch 417/714 complete
# DEBUG:generate_samples:Batch 418/714 complete
# DEBUG:generate_samples:Batch 419/714 complete
# DEBUG:generate_samples:Batch 420/714 complete
# DEBUG:generate_samples:Batch 421/714 complete
# DEBUG:generate_samples:Batch 422/714 complete
# DEBUG:generate_samples:Batch 423/714 complete
# DEBUG:generate_samples:Batch 424/714 complete
# DEBUG:generate_samples:Batch 425/714 complete
# DEBUG:generate_samples:Batch 426/714 complete
# DEBUG:generate_samples:Batch 427/714 complete
# DEBUG:generate_samples:Batch 428/714 complete
# DEBUG:generate_samples:Batch 429/714 complete
# DEBUG:generate_samples:Batch 430/714 complete
# DEBUG:generate_samples:Batch 431/714 complete
# DEBUG:generate_samples:Batch 432/714 complete
# DEBUG:generate_samples:Batch 433/714 complete
# DEBUG:generate_samples:Batch 434/714 complete
# DEBUG:generate_samples:Batch 435/714 complete
# DEBUG:generate_samples:Batch 436/714 complete
# DEBUG:generate_samples:Batch 437/714 complete
# DEBUG:generate_samples:Batch 438/714 complete
# DEBUG:generate_samples:Batch 439/714 complete
# DEBUG:generate_samples:Batch 440/714 complete
# DEBUG:generate_samples:Batch 441/714 complete
# DEBUG:generate_samples:Batch 442/714 complete
# DEBUG:generate_samples:Batch 443/714 complete
# DEBUG:generate_samples:Batch 444/714 complete
# DEBUG:generate_samples:Batch 445/714 complete
# DEBUG:generate_samples:Batch 446/714 complete
# DEBUG:generate_samples:Batch 447/714 complete
# DEBUG:generate_samples:Batch 448/714 complete
# DEBUG:generate_samples:Batch 449/714 complete
# DEBUG:generate_samples:Batch 450/714 complete
# DEBUG:generate_samples:Batch 451/714 complete
# DEBUG:generate_samples:Batch 452/714 complete
# DEBUG:generate_samples:Batch 453/714 complete
# DEBUG:generate_samples:Batch 454/714 complete
# DEBUG:generate_samples:Batch 455/714 complete
# DEBUG:generate_samples:Batch 456/714 complete
# DEBUG:generate_samples:Batch 457/714 complete
# DEBUG:generate_samples:Batch 458/714 complete
# DEBUG:generate_samples:Batch 459/714 complete
# DEBUG:generate_samples:Batch 460/714 complete
# DEBUG:generate_samples:Batch 461/714 complete
# DEBUG:generate_samples:Batch 462/714 complete
# DEBUG:generate_samples:Batch 463/714 complete
# DEBUG:generate_samples:Batch 464/714 complete
# DEBUG:generate_samples:Batch 465/714 complete
# DEBUG:generate_samples:Batch 466/714 complete
# DEBUG:generate_samples:Batch 467/714 complete
# DEBUG:generate_samples:Batch 468/714 complete
# DEBUG:generate_samples:Batch 469/714 complete
# DEBUG:generate_samples:Batch 470/714 complete
# DEBUG:generate_samples:Batch 471/714 complete
# DEBUG:generate_samples:Batch 472/714 complete
# DEBUG:generate_samples:Batch 473/714 complete
# DEBUG:generate_samples:Batch 474/714 complete
# DEBUG:generate_samples:Batch 475/714 complete
# DEBUG:generate_samples:Batch 476/714 complete
# DEBUG:generate_samples:Batch 477/714 complete
# DEBUG:generate_samples:Batch 478/714 complete
# DEBUG:generate_samples:Batch 479/714 complete
# DEBUG:generate_samples:Batch 480/714 complete
# DEBUG:generate_samples:Batch 481/714 complete
# DEBUG:generate_samples:Batch 482/714 complete
# DEBUG:generate_samples:Batch 483/714 complete
# DEBUG:generate_samples:Batch 484/714 complete
# DEBUG:generate_samples:Batch 485/714 complete
# DEBUG:generate_samples:Batch 486/714 complete
# DEBUG:generate_samples:Batch 487/714 complete
# DEBUG:generate_samples:Batch 488/714 complete
# DEBUG:generate_samples:Batch 489/714 complete
# DEBUG:generate_samples:Batch 490/714 complete
# DEBUG:generate_samples:Batch 491/714 complete
# DEBUG:generate_samples:Batch 492/714 complete
# DEBUG:generate_samples:Batch 493/714 complete
# DEBUG:generate_samples:Batch 494/714 complete
# DEBUG:generate_samples:Batch 495/714 complete
# DEBUG:generate_samples:Batch 496/714 complete
# DEBUG:generate_samples:Batch 497/714 complete
# DEBUG:generate_samples:Batch 498/714 complete
# DEBUG:generate_samples:Batch 499/714 complete
# DEBUG:generate_samples:Batch 500/714 complete
# DEBUG:generate_samples:Batch 501/714 complete
# DEBUG:generate_samples:Batch 502/714 complete
# DEBUG:generate_samples:Batch 503/714 complete
# DEBUG:generate_samples:Batch 504/714 complete
# DEBUG:generate_samples:Batch 505/714 complete
# DEBUG:generate_samples:Batch 506/714 complete
# DEBUG:generate_samples:Batch 507/714 complete
# DEBUG:generate_samples:Batch 508/714 complete
# DEBUG:generate_samples:Batch 509/714 complete
# DEBUG:generate_samples:Batch 510/714 complete
# DEBUG:generate_samples:Batch 511/714 complete
# DEBUG:generate_samples:Batch 512/714 complete
# DEBUG:generate_samples:Batch 513/714 complete
# DEBUG:generate_samples:Batch 514/714 complete
# DEBUG:generate_samples:Batch 515/714 complete
# DEBUG:generate_samples:Batch 516/714 complete
# DEBUG:generate_samples:Batch 517/714 complete
# DEBUG:generate_samples:Batch 518/714 complete
# DEBUG:generate_samples:Batch 519/714 complete
# DEBUG:generate_samples:Batch 520/714 complete
# DEBUG:generate_samples:Batch 521/714 complete
# DEBUG:generate_samples:Batch 522/714 complete
# DEBUG:generate_samples:Batch 523/714 complete
# DEBUG:generate_samples:Batch 524/714 complete
# DEBUG:generate_samples:Batch 525/714 complete
# DEBUG:generate_samples:Batch 526/714 complete
# DEBUG:generate_samples:Batch 527/714 complete
# DEBUG:generate_samples:Batch 528/714 complete
# DEBUG:generate_samples:Batch 529/714 complete
# DEBUG:generate_samples:Batch 530/714 complete
# DEBUG:generate_samples:Batch 531/714 complete
# DEBUG:generate_samples:Batch 532/714 complete
# DEBUG:generate_samples:Batch 533/714 complete
# DEBUG:generate_samples:Batch 534/714 complete
# DEBUG:generate_samples:Batch 535/714 complete
# DEBUG:generate_samples:Batch 536/714 complete
# DEBUG:generate_samples:Batch 537/714 complete
# DEBUG:generate_samples:Batch 538/714 complete
# DEBUG:generate_samples:Batch 539/714 complete
# DEBUG:generate_samples:Batch 540/714 complete
# DEBUG:generate_samples:Batch 541/714 complete
# DEBUG:generate_samples:Batch 542/714 complete
# DEBUG:generate_samples:Batch 543/714 complete
# DEBUG:generate_samples:Batch 544/714 complete
# DEBUG:generate_samples:Batch 545/714 complete
# DEBUG:generate_samples:Batch 546/714 complete
# DEBUG:generate_samples:Batch 547/714 complete
# DEBUG:generate_samples:Batch 548/714 complete
# DEBUG:generate_samples:Batch 549/714 complete
# DEBUG:generate_samples:Batch 550/714 complete
# DEBUG:generate_samples:Batch 551/714 complete
# DEBUG:generate_samples:Batch 552/714 complete
# DEBUG:generate_samples:Batch 553/714 complete
# DEBUG:generate_samples:Batch 554/714 complete
# DEBUG:generate_samples:Batch 555/714 complete
# DEBUG:generate_samples:Batch 556/714 complete
# DEBUG:generate_samples:Batch 557/714 complete
# DEBUG:generate_samples:Batch 558/714 complete
# DEBUG:generate_samples:Batch 559/714 complete
# DEBUG:generate_samples:Batch 560/714 complete
# DEBUG:generate_samples:Batch 561/714 complete
# DEBUG:generate_samples:Batch 562/714 complete
# DEBUG:generate_samples:Batch 563/714 complete
# DEBUG:generate_samples:Batch 564/714 complete
# DEBUG:generate_samples:Batch 565/714 complete
# DEBUG:generate_samples:Batch 566/714 complete
# DEBUG:generate_samples:Batch 567/714 complete
# DEBUG:generate_samples:Batch 568/714 complete
# DEBUG:generate_samples:Batch 569/714 complete
# DEBUG:generate_samples:Batch 570/714 complete
# DEBUG:generate_samples:Batch 571/714 complete
# DEBUG:generate_samples:Batch 572/714 complete
# DEBUG:generate_samples:Batch 573/714 complete
# DEBUG:generate_samples:Batch 574/714 complete
# DEBUG:generate_samples:Batch 575/714 complete
# DEBUG:generate_samples:Batch 576/714 complete
# DEBUG:generate_samples:Batch 577/714 complete
# DEBUG:generate_samples:Batch 578/714 complete
# DEBUG:generate_samples:Batch 579/714 complete
# DEBUG:generate_samples:Batch 580/714 complete
# DEBUG:generate_samples:Batch 581/714 complete
# DEBUG:generate_samples:Batch 582/714 complete
# DEBUG:generate_samples:Batch 583/714 complete
# DEBUG:generate_samples:Batch 584/714 complete
# DEBUG:generate_samples:Batch 585/714 complete
# DEBUG:generate_samples:Batch 586/714 complete
# DEBUG:generate_samples:Batch 587/714 complete
# DEBUG:generate_samples:Batch 588/714 complete
# DEBUG:generate_samples:Batch 589/714 complete
# DEBUG:generate_samples:Batch 590/714 complete
# DEBUG:generate_samples:Batch 591/714 complete
# DEBUG:generate_samples:Batch 592/714 complete
# DEBUG:generate_samples:Batch 593/714 complete
# DEBUG:generate_samples:Batch 594/714 complete
# DEBUG:generate_samples:Batch 595/714 complete
# DEBUG:generate_samples:Batch 596/714 complete
# DEBUG:generate_samples:Batch 597/714 complete
# DEBUG:generate_samples:Batch 598/714 complete
# DEBUG:generate_samples:Batch 599/714 complete
# DEBUG:generate_samples:Batch 600/714 complete
# DEBUG:generate_samples:Batch 601/714 complete
# DEBUG:generate_samples:Batch 602/714 complete
# DEBUG:generate_samples:Batch 603/714 complete
# DEBUG:generate_samples:Batch 604/714 complete
# DEBUG:generate_samples:Batch 605/714 complete
# DEBUG:generate_samples:Batch 606/714 complete
# DEBUG:generate_samples:Batch 607/714 complete
# DEBUG:generate_samples:Batch 608/714 complete
# DEBUG:generate_samples:Batch 609/714 complete
# DEBUG:generate_samples:Batch 610/714 complete
# DEBUG:generate_samples:Batch 611/714 complete
# DEBUG:generate_samples:Batch 612/714 complete
# DEBUG:generate_samples:Batch 613/714 complete
# DEBUG:generate_samples:Batch 614/714 complete
# DEBUG:generate_samples:Batch 615/714 complete
# DEBUG:generate_samples:Batch 616/714 complete
# DEBUG:generate_samples:Batch 617/714 complete
# DEBUG:generate_samples:Batch 618/714 complete
# DEBUG:generate_samples:Batch 619/714 complete
# DEBUG:generate_samples:Batch 620/714 complete
# DEBUG:generate_samples:Batch 621/714 complete
# DEBUG:generate_samples:Batch 622/714 complete
# DEBUG:generate_samples:Batch 623/714 complete
# DEBUG:generate_samples:Batch 624/714 complete
# DEBUG:generate_samples:Batch 625/714 complete
# DEBUG:generate_samples:Batch 626/714 complete
# DEBUG:generate_samples:Batch 627/714 complete
# DEBUG:generate_samples:Batch 628/714 complete
# DEBUG:generate_samples:Batch 629/714 complete
# DEBUG:generate_samples:Batch 630/714 complete
# DEBUG:generate_samples:Batch 631/714 complete
# DEBUG:generate_samples:Batch 632/714 complete
# DEBUG:generate_samples:Batch 633/714 complete
# DEBUG:generate_samples:Batch 634/714 complete
# DEBUG:generate_samples:Batch 635/714 complete
# DEBUG:generate_samples:Batch 636/714 complete
# DEBUG:generate_samples:Batch 637/714 complete
# DEBUG:generate_samples:Batch 638/714 complete
# DEBUG:generate_samples:Batch 639/714 complete
# DEBUG:generate_samples:Batch 640/714 complete
# DEBUG:generate_samples:Batch 641/714 complete
# DEBUG:generate_samples:Batch 642/714 complete
# DEBUG:generate_samples:Batch 643/714 complete
# DEBUG:generate_samples:Batch 644/714 complete
# DEBUG:generate_samples:Batch 645/714 complete
# DEBUG:generate_samples:Batch 646/714 complete
# DEBUG:generate_samples:Batch 647/714 complete
# DEBUG:generate_samples:Batch 648/714 complete
# DEBUG:generate_samples:Batch 649/714 complete
# DEBUG:generate_samples:Batch 650/714 complete
# DEBUG:generate_samples:Batch 651/714 complete
# DEBUG:generate_samples:Batch 652/714 complete
# DEBUG:generate_samples:Batch 653/714 complete
# DEBUG:generate_samples:Batch 654/714 complete
# DEBUG:generate_samples:Batch 655/714 complete
# DEBUG:generate_samples:Batch 656/714 complete
# DEBUG:generate_samples:Batch 657/714 complete
# DEBUG:generate_samples:Batch 658/714 complete
# DEBUG:generate_samples:Batch 659/714 complete
# DEBUG:generate_samples:Batch 660/714 complete
# DEBUG:generate_samples:Batch 661/714 complete
# DEBUG:generate_samples:Batch 662/714 complete
# DEBUG:generate_samples:Batch 663/714 complete
# DEBUG:generate_samples:Batch 664/714 complete
# DEBUG:generate_samples:Batch 665/714 complete
# DEBUG:generate_samples:Batch 666/714 complete
# DEBUG:generate_samples:Batch 667/714 complete
# DEBUG:generate_samples:Batch 668/714 complete
# DEBUG:generate_samples:Batch 669/714 complete
# DEBUG:generate_samples:Batch 670/714 complete
# DEBUG:generate_samples:Batch 671/714 complete
# DEBUG:generate_samples:Batch 672/714 complete
# DEBUG:generate_samples:Batch 673/714 complete
# DEBUG:generate_samples:Batch 674/714 complete
# DEBUG:generate_samples:Batch 675/714 complete
# DEBUG:generate_samples:Batch 676/714 complete
# DEBUG:generate_samples:Batch 677/714 complete
# DEBUG:generate_samples:Batch 678/714 complete
# DEBUG:generate_samples:Batch 679/714 complete
# DEBUG:generate_samples:Batch 680/714 complete
# DEBUG:generate_samples:Batch 681/714 complete
# DEBUG:generate_samples:Batch 682/714 complete
# DEBUG:generate_samples:Batch 683/714 complete
# DEBUG:generate_samples:Batch 684/714 complete
# DEBUG:generate_samples:Batch 685/714 complete
# DEBUG:generate_samples:Batch 686/714 complete
# DEBUG:generate_samples:Batch 687/714 complete
# DEBUG:generate_samples:Batch 688/714 complete
# DEBUG:generate_samples:Batch 689/714 complete
# DEBUG:generate_samples:Batch 690/714 complete
# DEBUG:generate_samples:Batch 691/714 complete
# DEBUG:generate_samples:Batch 692/714 complete
# DEBUG:generate_samples:Batch 693/714 complete
# DEBUG:generate_samples:Batch 694/714 complete
# DEBUG:generate_samples:Batch 695/714 complete
# DEBUG:generate_samples:Batch 696/714 complete
# DEBUG:generate_samples:Batch 697/714 complete
# DEBUG:generate_samples:Batch 698/714 complete
# DEBUG:generate_samples:Batch 699/714 complete
# DEBUG:generate_samples:Batch 700/714 complete
# DEBUG:generate_samples:Batch 701/714 complete
# DEBUG:generate_samples:Batch 702/714 complete
# DEBUG:generate_samples:Batch 703/714 complete
# DEBUG:generate_samples:Batch 704/714 complete
# DEBUG:generate_samples:Batch 705/714 complete
# DEBUG:generate_samples:Batch 706/714 complete
# DEBUG:generate_samples:Batch 707/714 complete
# DEBUG:generate_samples:Batch 708/714 complete
# DEBUG:generate_samples:Batch 709/714 complete
# DEBUG:generate_samples:Batch 710/714 complete
# DEBUG:generate_samples:Batch 711/714 complete
# DEBUG:generate_samples:Batch 712/714 complete
# DEBUG:generate_samples:Batch 713/714 complete
# DEBUG:generate_samples:Batch 714/714 complete
# DEBUG:generate_samples:Batch 715/714 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/142 complete
# DEBUG:generate_samples:Batch 2/142 complete
# DEBUG:generate_samples:Batch 3/142 complete
# DEBUG:generate_samples:Batch 4/142 complete
# DEBUG:generate_samples:Batch 5/142 complete
# DEBUG:generate_samples:Batch 6/142 complete
# DEBUG:generate_samples:Batch 7/142 complete
# DEBUG:generate_samples:Batch 8/142 complete
# DEBUG:generate_samples:Batch 9/142 complete
# DEBUG:generate_samples:Batch 10/142 complete
# DEBUG:generate_samples:Batch 11/142 complete
# DEBUG:generate_samples:Batch 12/142 complete
# DEBUG:generate_samples:Batch 13/142 complete
# DEBUG:generate_samples:Batch 14/142 complete
# DEBUG:generate_samples:Batch 15/142 complete
# DEBUG:generate_samples:Batch 16/142 complete
# DEBUG:generate_samples:Batch 17/142 complete
# DEBUG:generate_samples:Batch 18/142 complete
# DEBUG:generate_samples:Batch 19/142 complete
# DEBUG:generate_samples:Batch 20/142 complete
# DEBUG:generate_samples:Batch 21/142 complete
# DEBUG:generate_samples:Batch 22/142 complete
# DEBUG:generate_samples:Batch 23/142 complete
# DEBUG:generate_samples:Batch 24/142 complete
# DEBUG:generate_samples:Batch 25/142 complete
# DEBUG:generate_samples:Batch 26/142 complete
# DEBUG:generate_samples:Batch 27/142 complete
# DEBUG:generate_samples:Batch 28/142 complete
# DEBUG:generate_samples:Batch 29/142 complete
# DEBUG:generate_samples:Batch 30/142 complete
# DEBUG:generate_samples:Batch 31/142 complete
# DEBUG:generate_samples:Batch 32/142 complete
# DEBUG:generate_samples:Batch 33/142 complete
# DEBUG:generate_samples:Batch 34/142 complete
# DEBUG:generate_samples:Batch 35/142 complete
# DEBUG:generate_samples:Batch 36/142 complete
# DEBUG:generate_samples:Batch 37/142 complete
# DEBUG:generate_samples:Batch 38/142 complete
# DEBUG:generate_samples:Batch 39/142 complete
# DEBUG:generate_samples:Batch 40/142 complete
# DEBUG:generate_samples:Batch 41/142 complete
# DEBUG:generate_samples:Batch 42/142 complete
# DEBUG:generate_samples:Batch 43/142 complete
# DEBUG:generate_samples:Batch 44/142 complete
# DEBUG:generate_samples:Batch 45/142 complete
# DEBUG:generate_samples:Batch 46/142 complete
# DEBUG:generate_samples:Batch 47/142 complete
# DEBUG:generate_samples:Batch 48/142 complete
# DEBUG:generate_samples:Batch 49/142 complete
# DEBUG:generate_samples:Batch 50/142 complete
# DEBUG:generate_samples:Batch 51/142 complete
# DEBUG:generate_samples:Batch 52/142 complete
# DEBUG:generate_samples:Batch 53/142 complete
# DEBUG:generate_samples:Batch 54/142 complete
# DEBUG:generate_samples:Batch 55/142 complete
# DEBUG:generate_samples:Batch 56/142 complete
# DEBUG:generate_samples:Batch 57/142 complete
# DEBUG:generate_samples:Batch 58/142 complete
# DEBUG:generate_samples:Batch 59/142 complete
# DEBUG:generate_samples:Batch 60/142 complete
# DEBUG:generate_samples:Batch 61/142 complete
# DEBUG:generate_samples:Batch 62/142 complete
# DEBUG:generate_samples:Batch 63/142 complete
# DEBUG:generate_samples:Batch 64/142 complete
# DEBUG:generate_samples:Batch 65/142 complete
# DEBUG:generate_samples:Batch 66/142 complete
# DEBUG:generate_samples:Batch 67/142 complete
# DEBUG:generate_samples:Batch 68/142 complete
# DEBUG:generate_samples:Batch 69/142 complete
# DEBUG:generate_samples:Batch 70/142 complete
# DEBUG:generate_samples:Batch 71/142 complete
# DEBUG:generate_samples:Batch 72/142 complete
# DEBUG:generate_samples:Batch 73/142 complete
# DEBUG:generate_samples:Batch 74/142 complete
# DEBUG:generate_samples:Batch 75/142 complete
# DEBUG:generate_samples:Batch 76/142 complete
# DEBUG:generate_samples:Batch 77/142 complete
# DEBUG:generate_samples:Batch 78/142 complete
# DEBUG:generate_samples:Batch 79/142 complete
# DEBUG:generate_samples:Batch 80/142 complete
# DEBUG:generate_samples:Batch 81/142 complete
# DEBUG:generate_samples:Batch 82/142 complete
# DEBUG:generate_samples:Batch 83/142 complete
# DEBUG:generate_samples:Batch 84/142 complete
# DEBUG:generate_samples:Batch 85/142 complete
# DEBUG:generate_samples:Batch 86/142 complete
# DEBUG:generate_samples:Batch 87/142 complete
# DEBUG:generate_samples:Batch 88/142 complete
# DEBUG:generate_samples:Batch 89/142 complete
# DEBUG:generate_samples:Batch 90/142 complete
# DEBUG:generate_samples:Batch 91/142 complete
# DEBUG:generate_samples:Batch 92/142 complete
# DEBUG:generate_samples:Batch 93/142 complete
# DEBUG:generate_samples:Batch 94/142 complete
# DEBUG:generate_samples:Batch 95/142 complete
# DEBUG:generate_samples:Batch 96/142 complete
# DEBUG:generate_samples:Batch 97/142 complete
# DEBUG:generate_samples:Batch 98/142 complete
# DEBUG:generate_samples:Batch 99/142 complete
# DEBUG:generate_samples:Batch 100/142 complete
# DEBUG:generate_samples:Batch 101/142 complete
# DEBUG:generate_samples:Batch 102/142 complete
# DEBUG:generate_samples:Batch 103/142 complete
# DEBUG:generate_samples:Batch 104/142 complete
# DEBUG:generate_samples:Batch 105/142 complete
# DEBUG:generate_samples:Batch 106/142 complete
# DEBUG:generate_samples:Batch 107/142 complete
# DEBUG:generate_samples:Batch 108/142 complete
# DEBUG:generate_samples:Batch 109/142 complete
# DEBUG:generate_samples:Batch 110/142 complete
# DEBUG:generate_samples:Batch 111/142 complete
# DEBUG:generate_samples:Batch 112/142 complete
# DEBUG:generate_samples:Batch 113/142 complete
# DEBUG:generate_samples:Batch 114/142 complete
# DEBUG:generate_samples:Batch 115/142 complete
# DEBUG:generate_samples:Batch 116/142 complete
# DEBUG:generate_samples:Batch 117/142 complete
# DEBUG:generate_samples:Batch 118/142 complete
# DEBUG:generate_samples:Batch 119/142 complete
# DEBUG:generate_samples:Batch 120/142 complete
# DEBUG:generate_samples:Batch 121/142 complete
# DEBUG:generate_samples:Batch 122/142 complete
# DEBUG:generate_samples:Batch 123/142 complete
# DEBUG:generate_samples:Batch 124/142 complete
# DEBUG:generate_samples:Batch 125/142 complete
# DEBUG:generate_samples:Batch 126/142 complete
# DEBUG:generate_samples:Batch 127/142 complete
# DEBUG:generate_samples:Batch 128/142 complete
# DEBUG:generate_samples:Batch 129/142 complete
# DEBUG:generate_samples:Batch 130/142 complete
# DEBUG:generate_samples:Batch 131/142 complete
# DEBUG:generate_samples:Batch 132/142 complete
# DEBUG:generate_samples:Batch 133/142 complete
# DEBUG:generate_samples:Batch 134/142 complete
# DEBUG:generate_samples:Batch 135/142 complete
# DEBUG:generate_samples:Batch 136/142 complete
# DEBUG:generate_samples:Batch 137/142 complete
# DEBUG:generate_samples:Batch 138/142 complete
# DEBUG:generate_samples:Batch 139/142 complete
# DEBUG:generate_samples:Batch 140/142 complete
# DEBUG:generate_samples:Batch 141/142 complete
# DEBUG:generate_samples:Batch 142/142 complete
# DEBUG:generate_samples:Batch 143/142 complete
# INFO:generate_samples:Done
#
#   PASS all 4 clip dirs now populated

# %% [markdown]
# ## 12. Resample TTS clips 22050 â†’ 16000 Hz
#
# Piper TTS outputs at libritts's native 22050 Hz. The augment + feature pipelines expect 16 kHz.

# %%
# !find /content -maxdepth 4 -type d -name "positive_train"
# Out:
# /content/vicky_output/vicky/positive_train

# %%
# !cd /content/piper-sample-generator && python3 generate_samples.py "hey vicky" --model models/fr_FR-mls-medium.pt --max-samples 2500 --output-dir /content/vicky_fr_1/
# !cd /content/piper-sample-generator && python3 generate_samples.py "ok vicky" --model models/fr_FR-mls-medium.pt --max-samples 2500 --output-dir /content/vicky_fr_2/
# !cd /content/piper-sample-generator && python3 generate_samples.py "dis vicky" --model models/fr_FR-mls-medium.pt --max-samples 2500 --output-dir /content/vicky_fr_3/
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:__main__:Batch 6/2500 complete
# DEBUG:__main__:Batch 7/2500 complete
# DEBUG:__main__:Batch 8/2500 complete
# DEBUG:__main__:Batch 9/2500 complete
# DEBUG:__main__:Batch 10/2500 complete
# DEBUG:__main__:Batch 11/2500 complete
# DEBUG:__main__:Batch 12/2500 complete
# DEBUG:__main__:Batch 13/2500 complete
# DEBUG:__main__:Batch 14/2500 complete
# DEBUG:__main__:Batch 15/2500 complete
# DEBUG:__main__:Batch 16/2500 complete
# DEBUG:__main__:Batch 17/2500 complete
# DEBUG:__main__:Batch 18/2500 complete
# DEBUG:__main__:Batch 19/2500 complete
# DEBUG:__main__:Batch 20/2500 complete
# DEBUG:__main__:Batch 21/2500 complete
# DEBUG:__main__:Batch 22/2500 complete
# DEBUG:__main__:Batch 23/2500 complete
# DEBUG:__main__:Batch 24/2500 complete
# DEBUG:__main__:Batch 25/2500 complete
# DEBUG:__main__:Batch 26/2500 complete
# DEBUG:__main__:Batch 27/2500 complete
# DEBUG:__main__:Batch 28/2500 complete
# DEBUG:__main__:Batch 29/2500 complete
# DEBUG:__main__:Batch 30/2500 complete
# DEBUG:__main__:Batch 31/2500 complete
# DEBUG:__main__:Batch 32/2500 complete
# DEBUG:__main__:Batch 33/2500 complete
# DEBUG:__main__:Batch 34/2500 complete
# DEBUG:__main__:Batch 35/2500 complete
# DEBUG:__main__:Batch 36/2500 complete
# DEBUG:__main__:Batch 37/2500 complete
# DEBUG:__main__:Batch 38/2500 complete
# DEBUG:__main__:Batch 39/2500 complete
# DEBUG:__main__:Batch 40/2500 complete
# DEBUG:__main__:Batch 41/2500 complete
# DEBUG:__main__:Batch 42/2500 complete
# DEBUG:__main__:Batch 43/2500 complete
# DEBUG:__main__:Batch 44/2500 complete
# DEBUG:__main__:Batch 45/2500 complete
# DEBUG:__main__:Batch 46/2500 complete
# DEBUG:__main__:Batch 47/2500 complete
# DEBUG:__main__:Batch 48/2500 complete
# DEBUG:__main__:Batch 49/2500 complete
# DEBUG:__main__:Batch 50/2500 complete
# DEBUG:__main__:Batch 51/2500 complete
# DEBUG:__main__:Batch 52/2500 complete
# DEBUG:__main__:Batch 53/2500 complete
# DEBUG:__main__:Batch 54/2500 complete
# DEBUG:__main__:Batch 55/2500 complete
# DEBUG:__main__:Batch 56/2500 complete
# DEBUG:__main__:Batch 57/2500 complete
# DEBUG:__main__:Batch 58/2500 complete
# DEBUG:__main__:Batch 59/2500 complete
# DEBUG:__main__:Batch 60/2500 complete
# DEBUG:__main__:Batch 61/2500 complete
# DEBUG:__main__:Batch 62/2500 complete
# DEBUG:__main__:Batch 63/2500 complete
# DEBUG:__main__:Batch 64/2500 complete
# DEBUG:__main__:Batch 65/2500 complete
# DEBUG:__main__:Batch 66/2500 complete
# DEBUG:__main__:Batch 67/2500 complete
# DEBUG:__main__:Batch 68/2500 complete
# DEBUG:__main__:Batch 69/2500 complete
# DEBUG:__main__:Batch 70/2500 complete
# DEBUG:__main__:Batch 71/2500 complete
# DEBUG:__main__:Batch 72/2500 complete
# DEBUG:__main__:Batch 73/2500 complete
# DEBUG:__main__:Batch 74/2500 complete
# DEBUG:__main__:Batch 75/2500 complete
# DEBUG:__main__:Batch 76/2500 complete
# DEBUG:__main__:Batch 77/2500 complete
# DEBUG:__main__:Batch 78/2500 complete
# DEBUG:__main__:Batch 79/2500 complete
# DEBUG:__main__:Batch 80/2500 complete
# DEBUG:__main__:Batch 81/2500 complete
# DEBUG:__main__:Batch 82/2500 complete
# DEBUG:__main__:Batch 83/2500 complete
# DEBUG:__main__:Batch 84/2500 complete
# DEBUG:__main__:Batch 85/2500 complete
# DEBUG:__main__:Batch 86/2500 complete
# DEBUG:__main__:Batch 87/2500 complete
# DEBUG:__main__:Batch 88/2500 complete
# DEBUG:__main__:Batch 89/2500 complete
# DEBUG:__main__:Batch 90/2500 complete
# DEBUG:__main__:Batch 91/2500 complete
# DEBUG:__main__:Batch 92/2500 complete
# DEBUG:__main__:Batch 93/2500 complete
# DEBUG:__main__:Batch 94/2500 complete
# DEBUG:__main__:Batch 95/2500 complete
# DEBUG:__main__:Batch 96/2500 complete
# DEBUG:__main__:Batch 97/2500 complete
# DEBUG:__main__:Batch 98/2500 complete
# DEBUG:__main__:Batch 99/2500 complete
# DEBUG:__main__:Batch 100/2500 complete
# DEBUG:__main__:Batch 101/2500 complete
# DEBUG:__main__:Batch 102/2500 complete
# DEBUG:__main__:Batch 103/2500 complete
# DEBUG:__main__:Batch 104/2500 complete
# DEBUG:__main__:Batch 105/2500 complete
# DEBUG:__main__:Batch 106/2500 complete
# DEBUG:__main__:Batch 107/2500 complete
# DEBUG:__main__:Batch 108/2500 complete
# DEBUG:__main__:Batch 109/2500 complete
# DEBUG:__main__:Batch 110/2500 complete
# DEBUG:__main__:Batch 111/2500 complete
# DEBUG:__main__:Batch 112/2500 complete
# DEBUG:__main__:Batch 113/2500 complete
# DEBUG:__main__:Batch 114/2500 complete
# DEBUG:__main__:Batch 115/2500 complete
# DEBUG:__main__:Batch 116/2500 complete
# DEBUG:__main__:Batch 117/2500 complete
# DEBUG:__main__:Batch 118/2500 complete
# DEBUG:__main__:Batch 119/2500 complete
# DEBUG:__main__:Batch 120/2500 complete
# DEBUG:__main__:Batch 121/2500 complete
# DEBUG:__main__:Batch 122/2500 complete
# DEBUG:__main__:Batch 123/2500 complete
# DEBUG:__main__:Batch 124/2500 complete
# DEBUG:__main__:Batch 125/2500 complete
# DEBUG:__main__:Batch 126/2500 complete
# DEBUG:__main__:Batch 127/2500 complete
# DEBUG:__main__:Batch 128/2500 complete
# DEBUG:__main__:Batch 129/2500 complete
# DEBUG:__main__:Batch 130/2500 complete
# DEBUG:__main__:Batch 131/2500 complete
# DEBUG:__main__:Batch 132/2500 complete
# DEBUG:__main__:Batch 133/2500 complete
# DEBUG:__main__:Batch 134/2500 complete
# DEBUG:__main__:Batch 135/2500 complete
# DEBUG:__main__:Batch 136/2500 complete
# DEBUG:__main__:Batch 137/2500 complete
# DEBUG:__main__:Batch 138/2500 complete
# DEBUG:__main__:Batch 139/2500 complete
# DEBUG:__main__:Batch 140/2500 complete
# DEBUG:__main__:Batch 141/2500 complete
# DEBUG:__main__:Batch 142/2500 complete
# DEBUG:__main__:Batch 143/2500 complete
# DEBUG:__main__:Batch 144/2500 complete
# DEBUG:__main__:Batch 145/2500 complete
# DEBUG:__main__:Batch 146/2500 complete
# DEBUG:__main__:Batch 147/2500 complete
# DEBUG:__main__:Batch 148/2500 complete
# DEBUG:__main__:Batch 149/2500 complete
# DEBUG:__main__:Batch 150/2500 complete
# DEBUG:__main__:Batch 151/2500 complete
# DEBUG:__main__:Batch 152/2500 complete
# DEBUG:__main__:Batch 153/2500 complete
# DEBUG:__main__:Batch 154/2500 complete
# DEBUG:__main__:Batch 155/2500 complete
# DEBUG:__main__:Batch 156/2500 complete
# DEBUG:__main__:Batch 157/2500 complete
# DEBUG:__main__:Batch 158/2500 complete
# DEBUG:__main__:Batch 159/2500 complete
# DEBUG:__main__:Batch 160/2500 complete
# DEBUG:__main__:Batch 161/2500 complete
# DEBUG:__main__:Batch 162/2500 complete
# DEBUG:__main__:Batch 163/2500 complete
# DEBUG:__main__:Batch 164/2500 complete
# DEBUG:__main__:Batch 165/2500 complete
# DEBUG:__main__:Batch 166/2500 complete
# DEBUG:__main__:Batch 167/2500 complete
# DEBUG:__main__:Batch 168/2500 complete
# DEBUG:__main__:Batch 169/2500 complete
# DEBUG:__main__:Batch 170/2500 complete
# DEBUG:__main__:Batch 171/2500 complete
# DEBUG:__main__:Batch 172/2500 complete
# DEBUG:__main__:Batch 173/2500 complete
# DEBUG:__main__:Batch 174/2500 complete
# DEBUG:__main__:Batch 175/2500 complete
# DEBUG:__main__:Batch 176/2500 complete
# DEBUG:__main__:Batch 177/2500 complete
# DEBUG:__main__:Batch 178/2500 complete
# DEBUG:__main__:Batch 179/2500 complete
# DEBUG:__main__:Batch 180/2500 complete
# DEBUG:__main__:Batch 181/2500 complete
# DEBUG:__main__:Batch 182/2500 complete
# DEBUG:__main__:Batch 183/2500 complete
# DEBUG:__main__:Batch 184/2500 complete
# DEBUG:__main__:Batch 185/2500 complete
# DEBUG:__main__:Batch 186/2500 complete
# DEBUG:__main__:Batch 187/2500 complete
# DEBUG:__main__:Batch 188/2500 complete
# DEBUG:__main__:Batch 189/2500 complete
# DEBUG:__main__:Batch 190/2500 complete
# DEBUG:__main__:Batch 191/2500 complete
# DEBUG:__main__:Batch 192/2500 complete
# DEBUG:__main__:Batch 193/2500 complete
# DEBUG:__main__:Batch 194/2500 complete
# DEBUG:__main__:Batch 195/2500 complete
# DEBUG:__main__:Batch 196/2500 complete
# DEBUG:__main__:Batch 197/2500 complete
# DEBUG:__main__:Batch 198/2500 complete
# DEBUG:__main__:Batch 199/2500 complete
# DEBUG:__main__:Batch 200/2500 complete
# DEBUG:__main__:Batch 201/2500 complete
# DEBUG:__main__:Batch 202/2500 complete
# DEBUG:__main__:Batch 203/2500 complete
# DEBUG:__main__:Batch 204/2500 complete
# DEBUG:__main__:Batch 205/2500 complete
# DEBUG:__main__:Batch 206/2500 complete
# DEBUG:__main__:Batch 207/2500 complete
# DEBUG:__main__:Batch 208/2500 complete
# DEBUG:__main__:Batch 209/2500 complete
# DEBUG:__main__:Batch 210/2500 complete
# DEBUG:__main__:Batch 211/2500 complete
# DEBUG:__main__:Batch 212/2500 complete
# DEBUG:__main__:Batch 213/2500 complete
# DEBUG:__main__:Batch 214/2500 complete
# DEBUG:__main__:Batch 215/2500 complete
# DEBUG:__main__:Batch 216/2500 complete
# DEBUG:__main__:Batch 217/2500 complete
# DEBUG:__main__:Batch 218/2500 complete
# DEBUG:__main__:Batch 219/2500 complete
# DEBUG:__main__:Batch 220/2500 complete
# DEBUG:__main__:Batch 221/2500 complete
# DEBUG:__main__:Batch 222/2500 complete
# DEBUG:__main__:Batch 223/2500 complete
# DEBUG:__main__:Batch 224/2500 complete
# DEBUG:__main__:Batch 225/2500 complete
# DEBUG:__main__:Batch 226/2500 complete
# DEBUG:__main__:Batch 227/2500 complete
# DEBUG:__main__:Batch 228/2500 complete
# DEBUG:__main__:Batch 229/2500 complete
# DEBUG:__main__:Batch 230/2500 complete
# DEBUG:__main__:Batch 231/2500 complete
# DEBUG:__main__:Batch 232/2500 complete
# DEBUG:__main__:Batch 233/2500 complete
# DEBUG:__main__:Batch 234/2500 complete
# DEBUG:__main__:Batch 235/2500 complete
# DEBUG:__main__:Batch 236/2500 complete
# DEBUG:__main__:Batch 237/2500 complete
# DEBUG:__main__:Batch 238/2500 complete
# DEBUG:__main__:Batch 239/2500 complete
# DEBUG:__main__:Batch 240/2500 complete
# DEBUG:__main__:Batch 241/2500 complete
# DEBUG:__main__:Batch 242/2500 complete
# DEBUG:__main__:Batch 243/2500 complete
# DEBUG:__main__:Batch 244/2500 complete
# DEBUG:__main__:Batch 245/2500 complete
# DEBUG:__main__:Batch 246/2500 complete
# DEBUG:__main__:Batch 247/2500 complete
# DEBUG:__main__:Batch 248/2500 complete
# DEBUG:__main__:Batch 249/2500 complete
# DEBUG:__main__:Batch 250/2500 complete
# DEBUG:__main__:Batch 251/2500 complete
# DEBUG:__main__:Batch 252/2500 complete
# DEBUG:__main__:Batch 253/2500 complete
# DEBUG:__main__:Batch 254/2500 complete
# DEBUG:__main__:Batch 255/2500 complete
# DEBUG:__main__:Batch 256/2500 complete
# DEBUG:__main__:Batch 257/2500 complete
# DEBUG:__main__:Batch 258/2500 complete
# DEBUG:__main__:Batch 259/2500 complete
# DEBUG:__main__:Batch 260/2500 complete
# DEBUG:__main__:Batch 261/2500 complete
# DEBUG:__main__:Batch 262/2500 complete
# DEBUG:__main__:Batch 263/2500 complete
# DEBUG:__main__:Batch 264/2500 complete
# DEBUG:__main__:Batch 265/2500 complete
# DEBUG:__main__:Batch 266/2500 complete
# DEBUG:__main__:Batch 267/2500 complete
# DEBUG:__main__:Batch 268/2500 complete
# DEBUG:__main__:Batch 269/2500 complete
# DEBUG:__main__:Batch 270/2500 complete
# DEBUG:__main__:Batch 271/2500 complete
# DEBUG:__main__:Batch 272/2500 complete
# DEBUG:__main__:Batch 273/2500 complete
# DEBUG:__main__:Batch 274/2500 complete
# DEBUG:__main__:Batch 275/2500 complete
# DEBUG:__main__:Batch 276/2500 complete
# DEBUG:__main__:Batch 277/2500 complete
# DEBUG:__main__:Batch 278/2500 complete
# DEBUG:__main__:Batch 279/2500 complete
# DEBUG:__main__:Batch 280/2500 complete
# DEBUG:__main__:Batch 281/2500 complete
# DEBUG:__main__:Batch 282/2500 complete
# DEBUG:__main__:Batch 283/2500 complete
# DEBUG:__main__:Batch 284/2500 complete
# DEBUG:__main__:Batch 285/2500 complete
# DEBUG:__main__:Batch 286/2500 complete
# DEBUG:__main__:Batch 287/2500 complete
# DEBUG:__main__:Batch 288/2500 complete
# DEBUG:__main__:Batch 289/2500 complete
# DEBUG:__main__:Batch 290/2500 complete
# DEBUG:__main__:Batch 291/2500 complete
# DEBUG:__main__:Batch 292/2500 complete
# DEBUG:__main__:Batch 293/2500 complete
# DEBUG:__main__:Batch 294/2500 complete
# DEBUG:__main__:Batch 295/2500 complete
# DEBUG:__main__:Batch 296/2500 complete
# DEBUG:__main__:Batch 297/2500 complete
# DEBUG:__main__:Batch 298/2500 complete
# DEBUG:__main__:Batch 299/2500 complete
# DEBUG:__main__:Batch 300/2500 complete
# DEBUG:__main__:Batch 301/2500 complete
# DEBUG:__main__:Batch 302/2500 complete
# DEBUG:__main__:Batch 303/2500 complete
# DEBUG:__main__:Batch 304/2500 complete
# DEBUG:__main__:Batch 305/2500 complete
# DEBUG:__main__:Batch 306/2500 complete
# DEBUG:__main__:Batch 307/2500 complete
# DEBUG:__main__:Batch 308/2500 complete
# DEBUG:__main__:Batch 309/2500 complete
# DEBUG:__main__:Batch 310/2500 complete
# DEBUG:__main__:Batch 311/2500 complete
# DEBUG:__main__:Batch 312/2500 complete
# DEBUG:__main__:Batch 313/2500 complete
# DEBUG:__main__:Batch 314/2500 complete
# DEBUG:__main__:Batch 315/2500 complete
# DEBUG:__main__:Batch 316/2500 complete
# DEBUG:__main__:Batch 317/2500 complete
# DEBUG:__main__:Batch 318/2500 complete
# DEBUG:__main__:Batch 319/2500 complete
# DEBUG:__main__:Batch 320/2500 complete
# DEBUG:__main__:Batch 321/2500 complete
# DEBUG:__main__:Batch 322/2500 complete
# DEBUG:__main__:Batch 323/2500 complete
# DEBUG:__main__:Batch 324/2500 complete
# DEBUG:__main__:Batch 325/2500 complete
# DEBUG:__main__:Batch 326/2500 complete
# DEBUG:__main__:Batch 327/2500 complete
# DEBUG:__main__:Batch 328/2500 complete
# DEBUG:__main__:Batch 329/2500 complete
# DEBUG:__main__:Batch 330/2500 complete
# DEBUG:__main__:Batch 331/2500 complete
# DEBUG:__main__:Batch 332/2500 complete
# DEBUG:__main__:Batch 333/2500 complete
# DEBUG:__main__:Batch 334/2500 complete
# DEBUG:__main__:Batch 335/2500 complete
# DEBUG:__main__:Batch 336/2500 complete
# DEBUG:__main__:Batch 337/2500 complete
# DEBUG:__main__:Batch 338/2500 complete
# DEBUG:__main__:Batch 339/2500 complete
# DEBUG:__main__:Batch 340/2500 complete
# DEBUG:__main__:Batch 341/2500 complete
# DEBUG:__main__:Batch 342/2500 complete
# DEBUG:__main__:Batch 343/2500 complete
# DEBUG:__main__:Batch 344/2500 complete
# DEBUG:__main__:Batch 345/2500 complete
# DEBUG:__main__:Batch 346/2500 complete
# DEBUG:__main__:Batch 347/2500 complete
# DEBUG:__main__:Batch 348/2500 complete
# DEBUG:__main__:Batch 349/2500 complete
# DEBUG:__main__:Batch 350/2500 complete
# DEBUG:__main__:Batch 351/2500 complete
# DEBUG:__main__:Batch 352/2500 complete
# DEBUG:__main__:Batch 353/2500 complete
# DEBUG:__main__:Batch 354/2500 complete
# DEBUG:__main__:Batch 355/2500 complete
# DEBUG:__main__:Batch 356/2500 complete
# DEBUG:__main__:Batch 357/2500 complete
# DEBUG:__main__:Batch 358/2500 complete
# DEBUG:__main__:Batch 359/2500 complete
# DEBUG:__main__:Batch 360/2500 complete
# DEBUG:__main__:Batch 361/2500 complete
# DEBUG:__main__:Batch 362/2500 complete
# DEBUG:__main__:Batch 363/2500 complete
# DEBUG:__main__:Batch 364/2500 complete
# DEBUG:__main__:Batch 365/2500 complete
# DEBUG:__main__:Batch 366/2500 complete
# DEBUG:__main__:Batch 367/2500 complete
# DEBUG:__main__:Batch 368/2500 complete
# DEBUG:__main__:Batch 369/2500 complete
# DEBUG:__main__:Batch 370/2500 complete
# DEBUG:__main__:Batch 371/2500 complete
# DEBUG:__main__:Batch 372/2500 complete
# DEBUG:__main__:Batch 373/2500 complete
# DEBUG:__main__:Batch 374/2500 complete
# DEBUG:__main__:Batch 375/2500 complete
# DEBUG:__main__:Batch 376/2500 complete
# DEBUG:__main__:Batch 377/2500 complete
# DEBUG:__main__:Batch 378/2500 complete
# DEBUG:__main__:Batch 379/2500 complete
# DEBUG:__main__:Batch 380/2500 complete
# DEBUG:__main__:Batch 381/2500 complete
# DEBUG:__main__:Batch 382/2500 complete
# DEBUG:__main__:Batch 383/2500 complete
# DEBUG:__main__:Batch 384/2500 complete
# DEBUG:__main__:Batch 385/2500 complete
# DEBUG:__main__:Batch 386/2500 complete
# DEBUG:__main__:Batch 387/2500 complete
# DEBUG:__main__:Batch 388/2500 complete
# DEBUG:__main__:Batch 389/2500 complete
# DEBUG:__main__:Batch 390/2500 complete
# DEBUG:__main__:Batch 391/2500 complete
# DEBUG:__main__:Batch 392/2500 complete
# DEBUG:__main__:Batch 393/2500 complete
# DEBUG:__main__:Batch 394/2500 complete
# DEBUG:__main__:Batch 395/2500 complete
# DEBUG:__main__:Batch 396/2500 complete
# DEBUG:__main__:Batch 397/2500 complete
# DEBUG:__main__:Batch 398/2500 complete
# DEBUG:__main__:Batch 399/2500 complete
# DEBUG:__main__:Batch 400/2500 complete
# DEBUG:__main__:Batch 401/2500 complete
# DEBUG:__main__:Batch 402/2500 complete
# DEBUG:__main__:Batch 403/2500 complete
# DEBUG:__main__:Batch 404/2500 complete
# DEBUG:__main__:Batch 405/2500 complete
# DEBUG:__main__:Batch 406/2500 complete
# DEBUG:__main__:Batch 407/2500 complete
# DEBUG:__main__:Batch 408/2500 complete
# DEBUG:__main__:Batch 409/2500 complete
# DEBUG:__main__:Batch 410/2500 complete
# DEBUG:__main__:Batch 411/2500 complete
# DEBUG:__main__:Batch 412/2500 complete
# DEBUG:__main__:Batch 413/2500 complete
# DEBUG:__main__:Batch 414/2500 complete
# DEBUG:__main__:Batch 415/2500 complete
# DEBUG:__main__:Batch 416/2500 complete
# DEBUG:__main__:Batch 417/2500 complete
# DEBUG:__main__:Batch 418/2500 complete
# DEBUG:__main__:Batch 419/2500 complete
# DEBUG:__main__:Batch 420/2500 complete
# DEBUG:__main__:Batch 421/2500 complete
# DEBUG:__main__:Batch 422/2500 complete
# DEBUG:__main__:Batch 423/2500 complete
# DEBUG:__main__:Batch 424/2500 complete
# DEBUG:__main__:Batch 425/2500 complete
# DEBUG:__main__:Batch 426/2500 complete
# DEBUG:__main__:Batch 427/2500 complete
# DEBUG:__main__:Batch 428/2500 complete
# DEBUG:__main__:Batch 429/2500 complete
# DEBUG:__main__:Batch 430/2500 complete
# DEBUG:__main__:Batch 431/2500 complete
# DEBUG:__main__:Batch 432/2500 complete
# DEBUG:__main__:Batch 433/2500 complete
# DEBUG:__main__:Batch 434/2500 complete
# DEBUG:__main__:Batch 435/2500 complete
# DEBUG:__main__:Batch 436/2500 complete
# DEBUG:__main__:Batch 437/2500 complete
# DEBUG:__main__:Batch 438/2500 complete
# DEBUG:__main__:Batch 439/2500 complete
# DEBUG:__main__:Batch 440/2500 complete
# DEBUG:__main__:Batch 441/2500 complete
# DEBUG:__main__:Batch 442/2500 complete
# DEBUG:__main__:Batch 443/2500 complete
# DEBUG:__main__:Batch 444/2500 complete
# DEBUG:__main__:Batch 445/2500 complete
# DEBUG:__main__:Batch 446/2500 complete
# DEBUG:__main__:Batch 447/2500 complete
# DEBUG:__main__:Batch 448/2500 complete
# DEBUG:__main__:Batch 449/2500 complete
# DEBUG:__main__:Batch 450/2500 complete
# DEBUG:__main__:Batch 451/2500 complete
# DEBUG:__main__:Batch 452/2500 complete
# DEBUG:__main__:Batch 453/2500 complete
# DEBUG:__main__:Batch 454/2500 complete
# DEBUG:__main__:Batch 455/2500 complete
# DEBUG:__main__:Batch 456/2500 complete
# DEBUG:__main__:Batch 457/2500 complete
# DEBUG:__main__:Batch 458/2500 complete
# DEBUG:__main__:Batch 459/2500 complete
# DEBUG:__main__:Batch 460/2500 complete
# DEBUG:__main__:Batch 461/2500 complete
# DEBUG:__main__:Batch 462/2500 complete
# DEBUG:__main__:Batch 463/2500 complete
# DEBUG:__main__:Batch 464/2500 complete
# DEBUG:__main__:Batch 465/2500 complete
# DEBUG:__main__:Batch 466/2500 complete
# DEBUG:__main__:Batch 467/2500 complete
# DEBUG:__main__:Batch 468/2500 complete
# DEBUG:__main__:Batch 469/2500 complete
# DEBUG:__main__:Batch 470/2500 complete
# DEBUG:__main__:Batch 471/2500 complete
# DEBUG:__main__:Batch 472/2500 complete
# DEBUG:__main__:Batch 473/2500 complete
# DEBUG:__main__:Batch 474/2500 complete
# DEBUG:__main__:Batch 475/2500 complete
# DEBUG:__main__:Batch 476/2500 complete
# DEBUG:__main__:Batch 477/2500 complete
# DEBUG:__main__:Batch 478/2500 complete
# DEBUG:__main__:Batch 479/2500 complete
# DEBUG:__main__:Batch 480/2500 complete
# DEBUG:__main__:Batch 481/2500 complete
# DEBUG:__main__:Batch 482/2500 complete
# DEBUG:__main__:Batch 483/2500 complete
# DEBUG:__main__:Batch 484/2500 complete
# DEBUG:__main__:Batch 485/2500 complete
# DEBUG:__main__:Batch 486/2500 complete
# DEBUG:__main__:Batch 487/2500 complete
# DEBUG:__main__:Batch 488/2500 complete
# DEBUG:__main__:Batch 489/2500 complete
# DEBUG:__main__:Batch 490/2500 complete
# DEBUG:__main__:Batch 491/2500 complete
# DEBUG:__main__:Batch 492/2500 complete
# DEBUG:__main__:Batch 493/2500 complete
# DEBUG:__main__:Batch 494/2500 complete
# DEBUG:__main__:Batch 495/2500 complete
# DEBUG:__main__:Batch 496/2500 complete
# DEBUG:__main__:Batch 497/2500 complete
# DEBUG:__main__:Batch 498/2500 complete
# DEBUG:__main__:Batch 499/2500 complete
# DEBUG:__main__:Batch 500/2500 complete
# DEBUG:__main__:Batch 501/2500 complete
# DEBUG:__main__:Batch 502/2500 complete
# DEBUG:__main__:Batch 503/2500 complete
# DEBUG:__main__:Batch 504/2500 complete
# DEBUG:__main__:Batch 505/2500 complete
# DEBUG:__main__:Batch 506/2500 complete
# DEBUG:__main__:Batch 507/2500 complete
# DEBUG:__main__:Batch 508/2500 complete
# DEBUG:__main__:Batch 509/2500 complete
# DEBUG:__main__:Batch 510/2500 complete
# DEBUG:__main__:Batch 511/2500 complete
# DEBUG:__main__:Batch 512/2500 complete
# DEBUG:__main__:Batch 513/2500 complete
# DEBUG:__main__:Batch 514/2500 complete
# DEBUG:__main__:Batch 515/2500 complete
# DEBUG:__main__:Batch 516/2500 complete
# DEBUG:__main__:Batch 517/2500 complete
# DEBUG:__main__:Batch 518/2500 complete
# DEBUG:__main__:Batch 519/2500 complete
# DEBUG:__main__:Batch 520/2500 complete
# DEBUG:__main__:Batch 521/2500 complete
# DEBUG:__main__:Batch 522/2500 complete
# DEBUG:__main__:Batch 523/2500 complete
# DEBUG:__main__:Batch 524/2500 complete
# DEBUG:__main__:Batch 525/2500 complete
# DEBUG:__main__:Batch 526/2500 complete
# DEBUG:__main__:Batch 527/2500 complete
# DEBUG:__main__:Batch 528/2500 complete
# DEBUG:__main__:Batch 529/2500 complete
# DEBUG:__main__:Batch 530/2500 complete
# DEBUG:__main__:Batch 531/2500 complete
# DEBUG:__main__:Batch 532/2500 complete
# DEBUG:__main__:Batch 533/2500 complete
# DEBUG:__main__:Batch 534/2500 complete
# DEBUG:__main__:Batch 535/2500 complete
# DEBUG:__main__:Batch 536/2500 complete
# DEBUG:__main__:Batch 537/2500 complete
# DEBUG:__main__:Batch 538/2500 complete
# DEBUG:__main__:Batch 539/2500 complete
# DEBUG:__main__:Batch 540/2500 complete
# DEBUG:__main__:Batch 541/2500 complete
# DEBUG:__main__:Batch 542/2500 complete
# DEBUG:__main__:Batch 543/2500 complete
# DEBUG:__main__:Batch 544/2500 complete
# DEBUG:__main__:Batch 545/2500 complete
# DEBUG:__main__:Batch 546/2500 complete
# DEBUG:__main__:Batch 547/2500 complete
# DEBUG:__main__:Batch 548/2500 complete
# DEBUG:__main__:Batch 549/2500 complete
# DEBUG:__main__:Batch 550/2500 complete
# DEBUG:__main__:Batch 551/2500 complete
# DEBUG:__main__:Batch 552/2500 complete
# DEBUG:__main__:Batch 553/2500 complete
# DEBUG:__main__:Batch 554/2500 complete
# DEBUG:__main__:Batch 555/2500 complete
# DEBUG:__main__:Batch 556/2500 complete
# DEBUG:__main__:Batch 557/2500 complete
# DEBUG:__main__:Batch 558/2500 complete
# DEBUG:__main__:Batch 559/2500 complete
# DEBUG:__main__:Batch 560/2500 complete
# DEBUG:__main__:Batch 561/2500 complete
# DEBUG:__main__:Batch 562/2500 complete
# DEBUG:__main__:Batch 563/2500 complete
# DEBUG:__main__:Batch 564/2500 complete
# DEBUG:__main__:Batch 565/2500 complete
# DEBUG:__main__:Batch 566/2500 complete
# DEBUG:__main__:Batch 567/2500 complete
# DEBUG:__main__:Batch 568/2500 complete
# DEBUG:__main__:Batch 569/2500 complete
# DEBUG:__main__:Batch 570/2500 complete
# DEBUG:__main__:Batch 571/2500 complete
# DEBUG:__main__:Batch 572/2500 complete
# DEBUG:__main__:Batch 573/2500 complete
# DEBUG:__main__:Batch 574/2500 complete
# DEBUG:__main__:Batch 575/2500 complete
# DEBUG:__main__:Batch 576/2500 complete
# DEBUG:__main__:Batch 577/2500 complete
# DEBUG:__main__:Batch 578/2500 complete
# DEBUG:__main__:Batch 579/2500 complete
# DEBUG:__main__:Batch 580/2500 complete
# DEBUG:__main__:Batch 581/2500 complete
# DEBUG:__main__:Batch 582/2500 complete
# DEBUG:__main__:Batch 583/2500 complete
# DEBUG:__main__:Batch 584/2500 complete
# DEBUG:__main__:Batch 585/2500 complete
# DEBUG:__main__:Batch 586/2500 complete
# DEBUG:__main__:Batch 587/2500 complete
# DEBUG:__main__:Batch 588/2500 complete
# DEBUG:__main__:Batch 589/2500 complete
# DEBUG:__main__:Batch 590/2500 complete
# DEBUG:__main__:Batch 591/2500 complete
# DEBUG:__main__:Batch 592/2500 complete
# DEBUG:__main__:Batch 593/2500 complete
# DEBUG:__main__:Batch 594/2500 complete
# DEBUG:__main__:Batch 595/2500 complete
# DEBUG:__main__:Batch 596/2500 complete
# DEBUG:__main__:Batch 597/2500 complete
# DEBUG:__main__:Batch 598/2500 complete
# DEBUG:__main__:Batch 599/2500 complete
# DEBUG:__main__:Batch 600/2500 complete
# DEBUG:__main__:Batch 601/2500 complete
# DEBUG:__main__:Batch 602/2500 complete
# DEBUG:__main__:Batch 603/2500 complete
# DEBUG:__main__:Batch 604/2500 complete
# DEBUG:__main__:Batch 605/2500 complete
# DEBUG:__main__:Batch 606/2500 complete
# DEBUG:__main__:Batch 607/2500 complete
# DEBUG:__main__:Batch 608/2500 complete
# DEBUG:__main__:Batch 609/2500 complete
# DEBUG:__main__:Batch 610/2500 complete
# DEBUG:__main__:Batch 611/2500 complete
# DEBUG:__main__:Batch 612/2500 complete
# DEBUG:__main__:Batch 613/2500 complete
# DEBUG:__main__:Batch 614/2500 complete
# DEBUG:__main__:Batch 615/2500 complete
# DEBUG:__main__:Batch 616/2500 complete
# DEBUG:__main__:Batch 617/2500 complete
# DEBUG:__main__:Batch 618/2500 complete
# DEBUG:__main__:Batch 619/2500 complete
# DEBUG:__main__:Batch 620/2500 complete
# DEBUG:__main__:Batch 621/2500 complete
# DEBUG:__main__:Batch 622/2500 complete
# DEBUG:__main__:Batch 623/2500 complete
# DEBUG:__main__:Batch 624/2500 complete
# DEBUG:__main__:Batch 625/2500 complete
# DEBUG:__main__:Batch 626/2500 complete
# DEBUG:__main__:Batch 627/2500 complete
# DEBUG:__main__:Batch 628/2500 complete
# DEBUG:__main__:Batch 629/2500 complete
# DEBUG:__main__:Batch 630/2500 complete
# DEBUG:__main__:Batch 631/2500 complete
# DEBUG:__main__:Batch 632/2500 complete
# DEBUG:__main__:Batch 633/2500 complete
# DEBUG:__main__:Batch 634/2500 complete
# DEBUG:__main__:Batch 635/2500 complete
# DEBUG:__main__:Batch 636/2500 complete
# DEBUG:__main__:Batch 637/2500 complete
# DEBUG:__main__:Batch 638/2500 complete
# DEBUG:__main__:Batch 639/2500 complete
# DEBUG:__main__:Batch 640/2500 complete
# DEBUG:__main__:Batch 641/2500 complete
# DEBUG:__main__:Batch 642/2500 complete
# DEBUG:__main__:Batch 643/2500 complete
# DEBUG:__main__:Batch 644/2500 complete
# DEBUG:__main__:Batch 645/2500 complete
# DEBUG:__main__:Batch 646/2500 complete
# DEBUG:__main__:Batch 647/2500 complete
# DEBUG:__main__:Batch 648/2500 complete
# DEBUG:__main__:Batch 649/2500 complete
# DEBUG:__main__:Batch 650/2500 complete
# DEBUG:__main__:Batch 651/2500 complete
# DEBUG:__main__:Batch 652/2500 complete
# DEBUG:__main__:Batch 653/2500 complete
# DEBUG:__main__:Batch 654/2500 complete
# DEBUG:__main__:Batch 655/2500 complete
# DEBUG:__main__:Batch 656/2500 complete
# DEBUG:__main__:Batch 657/2500 complete
# DEBUG:__main__:Batch 658/2500 complete
# DEBUG:__main__:Batch 659/2500 complete
# DEBUG:__main__:Batch 660/2500 complete
# DEBUG:__main__:Batch 661/2500 complete
# DEBUG:__main__:Batch 662/2500 complete
# DEBUG:__main__:Batch 663/2500 complete
# DEBUG:__main__:Batch 664/2500 complete
# DEBUG:__main__:Batch 665/2500 complete
# DEBUG:__main__:Batch 666/2500 complete
# DEBUG:__main__:Batch 667/2500 complete
# DEBUG:__main__:Batch 668/2500 complete
# DEBUG:__main__:Batch 669/2500 complete
# DEBUG:__main__:Batch 670/2500 complete
# DEBUG:__main__:Batch 671/2500 complete
# DEBUG:__main__:Batch 672/2500 complete
# DEBUG:__main__:Batch 673/2500 complete
# DEBUG:__main__:Batch 674/2500 complete
# DEBUG:__main__:Batch 675/2500 complete
# DEBUG:__main__:Batch 676/2500 complete
# DEBUG:__main__:Batch 677/2500 complete
# DEBUG:__main__:Batch 678/2500 complete
# DEBUG:__main__:Batch 679/2500 complete
# DEBUG:__main__:Batch 680/2500 complete
# DEBUG:__main__:Batch 681/2500 complete
# DEBUG:__main__:Batch 682/2500 complete
# DEBUG:__main__:Batch 683/2500 complete
# DEBUG:__main__:Batch 684/2500 complete
# DEBUG:__main__:Batch 685/2500 complete
# DEBUG:__main__:Batch 686/2500 complete
# DEBUG:__main__:Batch 687/2500 complete
# DEBUG:__main__:Batch 688/2500 complete
# DEBUG:__main__:Batch 689/2500 complete
# DEBUG:__main__:Batch 690/2500 complete
# DEBUG:__main__:Batch 691/2500 complete
# DEBUG:__main__:Batch 692/2500 complete
# DEBUG:__main__:Batch 693/2500 complete
# DEBUG:__main__:Batch 694/2500 complete
# DEBUG:__main__:Batch 695/2500 complete
# DEBUG:__main__:Batch 696/2500 complete
# DEBUG:__main__:Batch 697/2500 complete
# DEBUG:__main__:Batch 698/2500 complete
# DEBUG:__main__:Batch 699/2500 complete
# DEBUG:__main__:Batch 700/2500 complete
# DEBUG:__main__:Batch 701/2500 complete
# DEBUG:__main__:Batch 702/2500 complete
# DEBUG:__main__:Batch 703/2500 complete
# DEBUG:__main__:Batch 704/2500 complete
# DEBUG:__main__:Batch 705/2500 complete
# DEBUG:__main__:Batch 706/2500 complete
# DEBUG:__main__:Batch 707/2500 complete
# DEBUG:__main__:Batch 708/2500 complete
# DEBUG:__main__:Batch 709/2500 complete
# DEBUG:__main__:Batch 710/2500 complete
# DEBUG:__main__:Batch 711/2500 complete
# DEBUG:__main__:Batch 712/2500 complete
# DEBUG:__main__:Batch 713/2500 complete
# DEBUG:__main__:Batch 714/2500 complete
# DEBUG:__main__:Batch 715/2500 complete
# DEBUG:__main__:Batch 716/2500 complete
# DEBUG:__main__:Batch 717/2500 complete
# DEBUG:__main__:Batch 718/2500 complete
# DEBUG:__main__:Batch 719/2500 complete
# DEBUG:__main__:Batch 720/2500 complete
# DEBUG:__main__:Batch 721/2500 complete
# DEBUG:__main__:Batch 722/2500 complete
# DEBUG:__main__:Batch 723/2500 complete
# DEBUG:__main__:Batch 724/2500 complete
# DEBUG:__main__:Batch 725/2500 complete
# DEBUG:__main__:Batch 726/2500 complete
# DEBUG:__main__:Batch 727/2500 complete
# DEBUG:__main__:Batch 728/2500 complete
# DEBUG:__main__:Batch 729/2500 complete
# DEBUG:__main__:Batch 730/2500 complete
# DEBUG:__main__:Batch 731/2500 complete
# DEBUG:__main__:Batch 732/2500 complete
# DEBUG:__main__:Batch 733/2500 complete
# DEBUG:__main__:Batch 734/2500 complete
# DEBUG:__main__:Batch 735/2500 complete
# DEBUG:__main__:Batch 736/2500 complete
# DEBUG:__main__:Batch 737/2500 complete
# DEBUG:__main__:Batch 738/2500 complete
# DEBUG:__main__:Batch 739/2500 complete
# DEBUG:__main__:Batch 740/2500 complete
# DEBUG:__main__:Batch 741/2500 complete
# DEBUG:__main__:Batch 742/2500 complete
# DEBUG:__main__:Batch 743/2500 complete
# DEBUG:__main__:Batch 744/2500 complete
# DEBUG:__main__:Batch 745/2500 complete
# DEBUG:__main__:Batch 746/2500 complete
# DEBUG:__main__:Batch 747/2500 complete
# DEBUG:__main__:Batch 748/2500 complete
# DEBUG:__main__:Batch 749/2500 complete
# DEBUG:__main__:Batch 750/2500 complete
# DEBUG:__main__:Batch 751/2500 complete
# DEBUG:__main__:Batch 752/2500 complete
# DEBUG:__main__:Batch 753/2500 complete
# DEBUG:__main__:Batch 754/2500 complete
# DEBUG:__main__:Batch 755/2500 complete
# DEBUG:__main__:Batch 756/2500 complete
# DEBUG:__main__:Batch 757/2500 complete
# DEBUG:__main__:Batch 758/2500 complete
# DEBUG:__main__:Batch 759/2500 complete
# DEBUG:__main__:Batch 760/2500 complete
# DEBUG:__main__:Batch 761/2500 complete
# DEBUG:__main__:Batch 762/2500 complete
# DEBUG:__main__:Batch 763/2500 complete
# DEBUG:__main__:Batch 764/2500 complete
# DEBUG:__main__:Batch 765/2500 complete
# DEBUG:__main__:Batch 766/2500 complete
# DEBUG:__main__:Batch 767/2500 complete
# DEBUG:__main__:Batch 768/2500 complete
# DEBUG:__main__:Batch 769/2500 complete
# DEBUG:__main__:Batch 770/2500 complete
# DEBUG:__main__:Batch 771/2500 complete
# DEBUG:__main__:Batch 772/2500 complete
# DEBUG:__main__:Batch 773/2500 complete
# DEBUG:__main__:Batch 774/2500 complete
# DEBUG:__main__:Batch 775/2500 complete
# DEBUG:__main__:Batch 776/2500 complete
# DEBUG:__main__:Batch 777/2500 complete
# DEBUG:__main__:Batch 778/2500 complete
# DEBUG:__main__:Batch 779/2500 complete
# DEBUG:__main__:Batch 780/2500 complete
# DEBUG:__main__:Batch 781/2500 complete
# DEBUG:__main__:Batch 782/2500 complete
# DEBUG:__main__:Batch 783/2500 complete
# DEBUG:__main__:Batch 784/2500 complete
# DEBUG:__main__:Batch 785/2500 complete
# DEBUG:__main__:Batch 786/2500 complete
# DEBUG:__main__:Batch 787/2500 complete
# DEBUG:__main__:Batch 788/2500 complete
# DEBUG:__main__:Batch 789/2500 complete
# DEBUG:__main__:Batch 790/2500 complete
# DEBUG:__main__:Batch 791/2500 complete
# DEBUG:__main__:Batch 792/2500 complete
# DEBUG:__main__:Batch 793/2500 complete
# DEBUG:__main__:Batch 794/2500 complete
# DEBUG:__main__:Batch 795/2500 complete
# DEBUG:__main__:Batch 796/2500 complete
# DEBUG:__main__:Batch 797/2500 complete
# DEBUG:__main__:Batch 798/2500 complete
# DEBUG:__main__:Batch 799/2500 complete
# DEBUG:__main__:Batch 800/2500 complete
# DEBUG:__main__:Batch 801/2500 complete
# DEBUG:__main__:Batch 802/2500 complete
# DEBUG:__main__:Batch 803/2500 complete
# DEBUG:__main__:Batch 804/2500 complete
# DEBUG:__main__:Batch 805/2500 complete
# DEBUG:__main__:Batch 806/2500 complete
# DEBUG:__main__:Batch 807/2500 complete
# DEBUG:__main__:Batch 808/2500 complete
# DEBUG:__main__:Batch 809/2500 complete
# DEBUG:__main__:Batch 810/2500 complete
# DEBUG:__main__:Batch 811/2500 complete
# DEBUG:__main__:Batch 812/2500 complete
# DEBUG:__main__:Batch 813/2500 complete
# DEBUG:__main__:Batch 814/2500 complete
# DEBUG:__main__:Batch 815/2500 complete
# DEBUG:__main__:Batch 816/2500 complete
# DEBUG:__main__:Batch 817/2500 complete
# DEBUG:__main__:Batch 818/2500 complete
# DEBUG:__main__:Batch 819/2500 complete
# DEBUG:__main__:Batch 820/2500 complete
# DEBUG:__main__:Batch 821/2500 complete
# DEBUG:__main__:Batch 822/2500 complete
# DEBUG:__main__:Batch 823/2500 complete
# DEBUG:__main__:Batch 824/2500 complete
# DEBUG:__main__:Batch 825/2500 complete
# DEBUG:__main__:Batch 826/2500 complete
# DEBUG:__main__:Batch 827/2500 complete
# DEBUG:__main__:Batch 828/2500 complete
# DEBUG:__main__:Batch 829/2500 complete
# DEBUG:__main__:Batch 830/2500 complete
# DEBUG:__main__:Batch 831/2500 complete
# DEBUG:__main__:Batch 832/2500 complete
# DEBUG:__main__:Batch 833/2500 complete
# DEBUG:__main__:Batch 834/2500 complete
# DEBUG:__main__:Batch 835/2500 complete
# DEBUG:__main__:Batch 836/2500 complete
# DEBUG:__main__:Batch 837/2500 complete
# DEBUG:__main__:Batch 838/2500 complete
# DEBUG:__main__:Batch 839/2500 complete
# DEBUG:__main__:Batch 840/2500 complete
# DEBUG:__main__:Batch 841/2500 complete
# DEBUG:__main__:Batch 842/2500 complete
# DEBUG:__main__:Batch 843/2500 complete
# DEBUG:__main__:Batch 844/2500 complete
# DEBUG:__main__:Batch 845/2500 complete
# DEBUG:__main__:Batch 846/2500 complete
# DEBUG:__main__:Batch 847/2500 complete
# DEBUG:__main__:Batch 848/2500 complete
# DEBUG:__main__:Batch 849/2500 complete
# DEBUG:__main__:Batch 850/2500 complete
# DEBUG:__main__:Batch 851/2500 complete
# DEBUG:__main__:Batch 852/2500 complete
# DEBUG:__main__:Batch 853/2500 complete
# DEBUG:__main__:Batch 854/2500 complete
# DEBUG:__main__:Batch 855/2500 complete
# DEBUG:__main__:Batch 856/2500 complete
# DEBUG:__main__:Batch 857/2500 complete
# DEBUG:__main__:Batch 858/2500 complete
# DEBUG:__main__:Batch 859/2500 complete
# DEBUG:__main__:Batch 860/2500 complete
# DEBUG:__main__:Batch 861/2500 complete
# DEBUG:__main__:Batch 862/2500 complete
# DEBUG:__main__:Batch 863/2500 complete
# DEBUG:__main__:Batch 864/2500 complete
# DEBUG:__main__:Batch 865/2500 complete
# DEBUG:__main__:Batch 866/2500 complete
# DEBUG:__main__:Batch 867/2500 complete
# DEBUG:__main__:Batch 868/2500 complete
# DEBUG:__main__:Batch 869/2500 complete
# DEBUG:__main__:Batch 870/2500 complete
# DEBUG:__main__:Batch 871/2500 complete
# DEBUG:__main__:Batch 872/2500 complete
# DEBUG:__main__:Batch 873/2500 complete
# DEBUG:__main__:Batch 874/2500 complete
# DEBUG:__main__:Batch 875/2500 complete
# DEBUG:__main__:Batch 876/2500 complete
# DEBUG:__main__:Batch 877/2500 complete
# DEBUG:__main__:Batch 878/2500 complete
# DEBUG:__main__:Batch 879/2500 complete
# DEBUG:__main__:Batch 880/2500 complete
# DEBUG:__main__:Batch 881/2500 complete
# DEBUG:__main__:Batch 882/2500 complete
# DEBUG:__main__:Batch 883/2500 complete
# DEBUG:__main__:Batch 884/2500 complete
# DEBUG:__main__:Batch 885/2500 complete
# DEBUG:__main__:Batch 886/2500 complete
# DEBUG:__main__:Batch 887/2500 complete
# DEBUG:__main__:Batch 888/2500 complete
# DEBUG:__main__:Batch 889/2500 complete
# DEBUG:__main__:Batch 890/2500 complete
# DEBUG:__main__:Batch 891/2500 complete
# DEBUG:__main__:Batch 892/2500 complete
# DEBUG:__main__:Batch 893/2500 complete
# DEBUG:__main__:Batch 894/2500 complete
# DEBUG:__main__:Batch 895/2500 complete
# DEBUG:__main__:Batch 896/2500 complete
# DEBUG:__main__:Batch 897/2500 complete
# DEBUG:__main__:Batch 898/2500 complete
# DEBUG:__main__:Batch 899/2500 complete
# DEBUG:__main__:Batch 900/2500 complete
# DEBUG:__main__:Batch 901/2500 complete
# DEBUG:__main__:Batch 902/2500 complete
# DEBUG:__main__:Batch 903/2500 complete
# DEBUG:__main__:Batch 904/2500 complete
# DEBUG:__main__:Batch 905/2500 complete
# DEBUG:__main__:Batch 906/2500 complete
# DEBUG:__main__:Batch 907/2500 complete
# DEBUG:__main__:Batch 908/2500 complete
# DEBUG:__main__:Batch 909/2500 complete
# DEBUG:__main__:Batch 910/2500 complete
# DEBUG:__main__:Batch 911/2500 complete
# DEBUG:__main__:Batch 912/2500 complete
# DEBUG:__main__:Batch 913/2500 complete
# DEBUG:__main__:Batch 914/2500 complete
# DEBUG:__main__:Batch 915/2500 complete
# DEBUG:__main__:Batch 916/2500 complete
# DEBUG:__main__:Batch 917/2500 complete
# DEBUG:__main__:Batch 918/2500 complete
# DEBUG:__main__:Batch 919/2500 complete
# DEBUG:__main__:Batch 920/2500 complete
# DEBUG:__main__:Batch 921/2500 complete
# DEBUG:__main__:Batch 922/2500 complete
# DEBUG:__main__:Batch 923/2500 complete
# DEBUG:__main__:Batch 924/2500 complete
# DEBUG:__main__:Batch 925/2500 complete
# DEBUG:__main__:Batch 926/2500 complete
# DEBUG:__main__:Batch 927/2500 complete
# DEBUG:__main__:Batch 928/2500 complete
# DEBUG:__main__:Batch 929/2500 complete
# DEBUG:__main__:Batch 930/2500 complete
# DEBUG:__main__:Batch 931/2500 complete
# DEBUG:__main__:Batch 932/2500 complete
# DEBUG:__main__:Batch 933/2500 complete
# DEBUG:__main__:Batch 934/2500 complete
# DEBUG:__main__:Batch 935/2500 complete
# DEBUG:__main__:Batch 936/2500 complete
# DEBUG:__main__:Batch 937/2500 complete
# DEBUG:__main__:Batch 938/2500 complete
# DEBUG:__main__:Batch 939/2500 complete
# DEBUG:__main__:Batch 940/2500 complete
# DEBUG:__main__:Batch 941/2500 complete
# DEBUG:__main__:Batch 942/2500 complete
# DEBUG:__main__:Batch 943/2500 complete
# DEBUG:__main__:Batch 944/2500 complete
# DEBUG:__main__:Batch 945/2500 complete
# DEBUG:__main__:Batch 946/2500 complete
# DEBUG:__main__:Batch 947/2500 complete
# DEBUG:__main__:Batch 948/2500 complete
# DEBUG:__main__:Batch 949/2500 complete
# DEBUG:__main__:Batch 950/2500 complete
# DEBUG:__main__:Batch 951/2500 complete
# DEBUG:__main__:Batch 952/2500 complete
# DEBUG:__main__:Batch 953/2500 complete
# DEBUG:__main__:Batch 954/2500 complete
# DEBUG:__main__:Batch 955/2500 complete
# DEBUG:__main__:Batch 956/2500 complete
# DEBUG:__main__:Batch 957/2500 complete
# DEBUG:__main__:Batch 958/2500 complete
# DEBUG:__main__:Batch 959/2500 complete
# DEBUG:__main__:Batch 960/2500 complete
# DEBUG:__main__:Batch 961/2500 complete
# DEBUG:__main__:Batch 962/2500 complete
# DEBUG:__main__:Batch 963/2500 complete
# DEBUG:__main__:Batch 964/2500 complete
# DEBUG:__main__:Batch 965/2500 complete
# DEBUG:__main__:Batch 966/2500 complete
# DEBUG:__main__:Batch 967/2500 complete
# DEBUG:__main__:Batch 968/2500 complete
# DEBUG:__main__:Batch 969/2500 complete
# DEBUG:__main__:Batch 970/2500 complete
# DEBUG:__main__:Batch 971/2500 complete
# DEBUG:__main__:Batch 972/2500 complete
# DEBUG:__main__:Batch 973/2500 complete
# DEBUG:__main__:Batch 974/2500 complete
# DEBUG:__main__:Batch 975/2500 complete
# DEBUG:__main__:Batch 976/2500 complete
# DEBUG:__main__:Batch 977/2500 complete
# DEBUG:__main__:Batch 978/2500 complete
# DEBUG:__main__:Batch 979/2500 complete
# DEBUG:__main__:Batch 980/2500 complete
# DEBUG:__main__:Batch 981/2500 complete
# DEBUG:__main__:Batch 982/2500 complete
# DEBUG:__main__:Batch 983/2500 complete
# DEBUG:__main__:Batch 984/2500 complete
# DEBUG:__main__:Batch 985/2500 complete
# DEBUG:__main__:Batch 986/2500 complete
# DEBUG:__main__:Batch 987/2500 complete
# DEBUG:__main__:Batch 988/2500 complete
# DEBUG:__main__:Batch 989/2500 complete
# DEBUG:__main__:Batch 990/2500 complete
# DEBUG:__main__:Batch 991/2500 complete
# DEBUG:__main__:Batch 992/2500 complete
# DEBUG:__main__:Batch 993/2500 complete
# DEBUG:__main__:Batch 994/2500 complete
# DEBUG:__main__:Batch 995/2500 complete
# DEBUG:__main__:Batch 996/2500 complete
# DEBUG:__main__:Batch 997/2500 complete
# DEBUG:__main__:Batch 998/2500 complete
# DEBUG:__main__:Batch 999/2500 complete
# DEBUG:__main__:Batch 1000/2500 complete
# DEBUG:__main__:Batch 1001/2500 complete
# DEBUG:__main__:Batch 1002/2500 complete
# DEBUG:__main__:Batch 1003/2500 complete
# DEBUG:__main__:Batch 1004/2500 complete
# DEBUG:__main__:Batch 1005/2500 complete
# DEBUG:__main__:Batch 1006/2500 complete
# DEBUG:__main__:Batch 1007/2500 complete
# DEBUG:__main__:Batch 1008/2500 complete
# DEBUG:__main__:Batch 1009/2500 complete
# DEBUG:__main__:Batch 1010/2500 complete
# DEBUG:__main__:Batch 1011/2500 complete
# DEBUG:__main__:Batch 1012/2500 complete
# DEBUG:__main__:Batch 1013/2500 complete
# DEBUG:__main__:Batch 1014/2500 complete
# DEBUG:__main__:Batch 1015/2500 complete
# DEBUG:__main__:Batch 1016/2500 complete
# DEBUG:__main__:Batch 1017/2500 complete
# DEBUG:__main__:Batch 1018/2500 complete
# DEBUG:__main__:Batch 1019/2500 complete
# DEBUG:__main__:Batch 1020/2500 complete
# DEBUG:__main__:Batch 1021/2500 complete
# DEBUG:__main__:Batch 1022/2500 complete
# DEBUG:__main__:Batch 1023/2500 complete
# DEBUG:__main__:Batch 1024/2500 complete
# DEBUG:__main__:Batch 1025/2500 complete
# DEBUG:__main__:Batch 1026/2500 complete
# DEBUG:__main__:Batch 1027/2500 complete
# DEBUG:__main__:Batch 1028/2500 complete
# DEBUG:__main__:Batch 1029/2500 complete
# DEBUG:__main__:Batch 1030/2500 complete
# DEBUG:__main__:Batch 1031/2500 complete
# DEBUG:__main__:Batch 1032/2500 complete
# DEBUG:__main__:Batch 1033/2500 complete
# DEBUG:__main__:Batch 1034/2500 complete
# DEBUG:__main__:Batch 1035/2500 complete
# DEBUG:__main__:Batch 1036/2500 complete
# DEBUG:__main__:Batch 1037/2500 complete
# DEBUG:__main__:Batch 1038/2500 complete
# DEBUG:__main__:Batch 1039/2500 complete
# DEBUG:__main__:Batch 1040/2500 complete
# DEBUG:__main__:Batch 1041/2500 complete
# DEBUG:__main__:Batch 1042/2500 complete
# DEBUG:__main__:Batch 1043/2500 complete
# DEBUG:__main__:Batch 1044/2500 complete
# DEBUG:__main__:Batch 1045/2500 complete
# DEBUG:__main__:Batch 1046/2500 complete
# DEBUG:__main__:Batch 1047/2500 complete
# DEBUG:__main__:Batch 1048/2500 complete
# DEBUG:__main__:Batch 1049/2500 complete
# DEBUG:__main__:Batch 1050/2500 complete
# DEBUG:__main__:Batch 1051/2500 complete
# DEBUG:__main__:Batch 1052/2500 complete
# DEBUG:__main__:Batch 1053/2500 complete
# DEBUG:__main__:Batch 1054/2500 complete
# DEBUG:__main__:Batch 1055/2500 complete
# DEBUG:__main__:Batch 1056/2500 complete
# DEBUG:__main__:Batch 1057/2500 complete
# DEBUG:__main__:Batch 1058/2500 complete
# DEBUG:__main__:Batch 1059/2500 complete
# DEBUG:__main__:Batch 1060/2500 complete
# DEBUG:__main__:Batch 1061/2500 complete
# DEBUG:__main__:Batch 1062/2500 complete
# DEBUG:__main__:Batch 1063/2500 complete
# DEBUG:__main__:Batch 1064/2500 complete
# DEBUG:__main__:Batch 1065/2500 complete
# DEBUG:__main__:Batch 1066/2500 complete
# DEBUG:__main__:Batch 1067/2500 complete
# DEBUG:__main__:Batch 1068/2500 complete
# DEBUG:__main__:Batch 1069/2500 complete
# DEBUG:__main__:Batch 1070/2500 complete
# DEBUG:__main__:Batch 1071/2500 complete
# DEBUG:__main__:Batch 1072/2500 complete
# DEBUG:__main__:Batch 1073/2500 complete
# DEBUG:__main__:Batch 1074/2500 complete
# DEBUG:__main__:Batch 1075/2500 complete
# DEBUG:__main__:Batch 1076/2500 complete
# DEBUG:__main__:Batch 1077/2500 complete
# DEBUG:__main__:Batch 1078/2500 complete
# DEBUG:__main__:Batch 1079/2500 complete
# DEBUG:__main__:Batch 1080/2500 complete
# DEBUG:__main__:Batch 1081/2500 complete
# DEBUG:__main__:Batch 1082/2500 complete
# DEBUG:__main__:Batch 1083/2500 complete
# DEBUG:__main__:Batch 1084/2500 complete
# DEBUG:__main__:Batch 1085/2500 complete
# DEBUG:__main__:Batch 1086/2500 complete
# DEBUG:__main__:Batch 1087/2500 complete
# DEBUG:__main__:Batch 1088/2500 complete
# DEBUG:__main__:Batch 1089/2500 complete
# DEBUG:__main__:Batch 1090/2500 complete
# DEBUG:__main__:Batch 1091/2500 complete
# DEBUG:__main__:Batch 1092/2500 complete
# DEBUG:__main__:Batch 1093/2500 complete
# DEBUG:__main__:Batch 1094/2500 complete
# DEBUG:__main__:Batch 1095/2500 complete
# DEBUG:__main__:Batch 1096/2500 complete
# DEBUG:__main__:Batch 1097/2500 complete
# DEBUG:__main__:Batch 1098/2500 complete
# DEBUG:__main__:Batch 1099/2500 complete
# DEBUG:__main__:Batch 1100/2500 complete
# DEBUG:__main__:Batch 1101/2500 complete
# DEBUG:__main__:Batch 1102/2500 complete
# DEBUG:__main__:Batch 1103/2500 complete
# DEBUG:__main__:Batch 1104/2500 complete
# DEBUG:__main__:Batch 1105/2500 complete
# DEBUG:__main__:Batch 1106/2500 complete
# DEBUG:__main__:Batch 1107/2500 complete
# DEBUG:__main__:Batch 1108/2500 complete
# DEBUG:__main__:Batch 1109/2500 complete
# DEBUG:__main__:Batch 1110/2500 complete
# DEBUG:__main__:Batch 1111/2500 complete
# DEBUG:__main__:Batch 1112/2500 complete
# DEBUG:__main__:Batch 1113/2500 complete
# DEBUG:__main__:Batch 1114/2500 complete
# DEBUG:__main__:Batch 1115/2500 complete
# DEBUG:__main__:Batch 1116/2500 complete
# DEBUG:__main__:Batch 1117/2500 complete
# DEBUG:__main__:Batch 1118/2500 complete
# DEBUG:__main__:Batch 1119/2500 complete
# DEBUG:__main__:Batch 1120/2500 complete
# DEBUG:__main__:Batch 1121/2500 complete
# DEBUG:__main__:Batch 1122/2500 complete
# DEBUG:__main__:Batch 1123/2500 complete
# DEBUG:__main__:Batch 1124/2500 complete
# DEBUG:__main__:Batch 1125/2500 complete
# DEBUG:__main__:Batch 1126/2500 complete
# DEBUG:__main__:Batch 1127/2500 complete
# DEBUG:__main__:Batch 1128/2500 complete
# DEBUG:__main__:Batch 1129/2500 complete
# DEBUG:__main__:Batch 1130/2500 complete
# DEBUG:__main__:Batch 1131/2500 complete
# DEBUG:__main__:Batch 1132/2500 complete
# DEBUG:__main__:Batch 1133/2500 complete
# DEBUG:__main__:Batch 1134/2500 complete
# DEBUG:__main__:Batch 1135/2500 complete
# DEBUG:__main__:Batch 1136/2500 complete
# DEBUG:__main__:Batch 1137/2500 complete
# DEBUG:__main__:Batch 1138/2500 complete
# DEBUG:__main__:Batch 1139/2500 complete
# DEBUG:__main__:Batch 1140/2500 complete
# DEBUG:__main__:Batch 1141/2500 complete
# DEBUG:__main__:Batch 1142/2500 complete
# DEBUG:__main__:Batch 1143/2500 complete
# DEBUG:__main__:Batch 1144/2500 complete
# DEBUG:__main__:Batch 1145/2500 complete
# DEBUG:__main__:Batch 1146/2500 complete
# DEBUG:__main__:Batch 1147/2500 complete
# DEBUG:__main__:Batch 1148/2500 complete
# DEBUG:__main__:Batch 1149/2500 complete
# DEBUG:__main__:Batch 1150/2500 complete
# DEBUG:__main__:Batch 1151/2500 complete
# DEBUG:__main__:Batch 1152/2500 complete
# DEBUG:__main__:Batch 1153/2500 complete
# DEBUG:__main__:Batch 1154/2500 complete
# DEBUG:__main__:Batch 1155/2500 complete
# DEBUG:__main__:Batch 1156/2500 complete
# DEBUG:__main__:Batch 1157/2500 complete
# DEBUG:__main__:Batch 1158/2500 complete
# DEBUG:__main__:Batch 1159/2500 complete
# DEBUG:__main__:Batch 1160/2500 complete
# DEBUG:__main__:Batch 1161/2500 complete
# DEBUG:__main__:Batch 1162/2500 complete
# DEBUG:__main__:Batch 1163/2500 complete
# DEBUG:__main__:Batch 1164/2500 complete
# DEBUG:__main__:Batch 1165/2500 complete
# DEBUG:__main__:Batch 1166/2500 complete
# DEBUG:__main__:Batch 1167/2500 complete
# DEBUG:__main__:Batch 1168/2500 complete
# DEBUG:__main__:Batch 1169/2500 complete
# DEBUG:__main__:Batch 1170/2500 complete
# DEBUG:__main__:Batch 1171/2500 complete
# DEBUG:__main__:Batch 1172/2500 complete
# DEBUG:__main__:Batch 1173/2500 complete
# DEBUG:__main__:Batch 1174/2500 complete
# DEBUG:__main__:Batch 1175/2500 complete
# DEBUG:__main__:Batch 1176/2500 complete
# DEBUG:__main__:Batch 1177/2500 complete
# DEBUG:__main__:Batch 1178/2500 complete
# DEBUG:__main__:Batch 1179/2500 complete
# DEBUG:__main__:Batch 1180/2500 complete
# DEBUG:__main__:Batch 1181/2500 complete
# DEBUG:__main__:Batch 1182/2500 complete
# DEBUG:__main__:Batch 1183/2500 complete
# DEBUG:__main__:Batch 1184/2500 complete
# DEBUG:__main__:Batch 1185/2500 complete
# DEBUG:__main__:Batch 1186/2500 complete
# DEBUG:__main__:Batch 1187/2500 complete
# DEBUG:__main__:Batch 1188/2500 complete
# DEBUG:__main__:Batch 1189/2500 complete
# DEBUG:__main__:Batch 1190/2500 complete
# DEBUG:__main__:Batch 1191/2500 complete
# DEBUG:__main__:Batch 1192/2500 complete
# DEBUG:__main__:Batch 1193/2500 complete
# DEBUG:__main__:Batch 1194/2500 complete
# DEBUG:__main__:Batch 1195/2500 complete
# DEBUG:__main__:Batch 1196/2500 complete
# DEBUG:__main__:Batch 1197/2500 complete
# DEBUG:__main__:Batch 1198/2500 complete
# DEBUG:__main__:Batch 1199/2500 complete
# DEBUG:__main__:Batch 1200/2500 complete
# DEBUG:__main__:Batch 1201/2500 complete
# DEBUG:__main__:Batch 1202/2500 complete
# DEBUG:__main__:Batch 1203/2500 complete
# DEBUG:__main__:Batch 1204/2500 complete
# DEBUG:__main__:Batch 1205/2500 complete
# DEBUG:__main__:Batch 1206/2500 complete
# DEBUG:__main__:Batch 1207/2500 complete
# DEBUG:__main__:Batch 1208/2500 complete
# DEBUG:__main__:Batch 1209/2500 complete
# DEBUG:__main__:Batch 1210/2500 complete
# DEBUG:__main__:Batch 1211/2500 complete
# DEBUG:__main__:Batch 1212/2500 complete
# DEBUG:__main__:Batch 1213/2500 complete
# DEBUG:__main__:Batch 1214/2500 complete
# DEBUG:__main__:Batch 1215/2500 complete
# DEBUG:__main__:Batch 1216/2500 complete
# DEBUG:__main__:Batch 1217/2500 complete
# DEBUG:__main__:Batch 1218/2500 complete
# DEBUG:__main__:Batch 1219/2500 complete
# DEBUG:__main__:Batch 1220/2500 complete
# DEBUG:__main__:Batch 1221/2500 complete
# DEBUG:__main__:Batch 1222/2500 complete
# DEBUG:__main__:Batch 1223/2500 complete
# DEBUG:__main__:Batch 1224/2500 complete
# DEBUG:__main__:Batch 1225/2500 complete
# DEBUG:__main__:Batch 1226/2500 complete
# DEBUG:__main__:Batch 1227/2500 complete
# DEBUG:__main__:Batch 1228/2500 complete
# DEBUG:__main__:Batch 1229/2500 complete
# DEBUG:__main__:Batch 1230/2500 complete
# DEBUG:__main__:Batch 1231/2500 complete
# ...
# DEBUG:__main__:Batch 2102/2500 complete
# DEBUG:__main__:Batch 2103/2500 complete
# DEBUG:__main__:Batch 2104/2500 complete
# DEBUG:__main__:Batch 2105/2500 complete
# DEBUG:__main__:Batch 2106/2500 complete
# DEBUG:__main__:Batch 2107/2500 complete
# DEBUG:__main__:Batch 2108/2500 complete
# DEBUG:__main__:Batch 2109/2500 complete
# DEBUG:__main__:Batch 2110/2500 complete
# DEBUG:__main__:Batch 2111/2500 complete
# DEBUG:__main__:Batch 2112/2500 complete
# DEBUG:__main__:Batch 2113/2500 complete
# DEBUG:__main__:Batch 2114/2500 complete
# DEBUG:__main__:Batch 2115/2500 complete
# DEBUG:__main__:Batch 2116/2500 complete
# DEBUG:__main__:Batch 2117/2500 complete
# DEBUG:__main__:Batch 2118/2500 complete
# DEBUG:__main__:Batch 2119/2500 complete
# DEBUG:__main__:Batch 2120/2500 complete
# DEBUG:__main__:Batch 2121/2500 complete
# DEBUG:__main__:Batch 2122/2500 complete
# DEBUG:__main__:Batch 2123/2500 complete
# DEBUG:__main__:Batch 2124/2500 complete
# DEBUG:__main__:Batch 2125/2500 complete
# DEBUG:__main__:Batch 2126/2500 complete
# DEBUG:__main__:Batch 2127/2500 complete
# DEBUG:__main__:Batch 2128/2500 complete
# DEBUG:__main__:Batch 2129/2500 complete
# DEBUG:__main__:Batch 2130/2500 complete
# DEBUG:__main__:Batch 2131/2500 complete
# DEBUG:__main__:Batch 2132/2500 complete
# DEBUG:__main__:Batch 2133/2500 complete
# DEBUG:__main__:Batch 2134/2500 complete
# DEBUG:__main__:Batch 2135/2500 complete
# DEBUG:__main__:Batch 2136/2500 complete
# DEBUG:__main__:Batch 2137/2500 complete
# DEBUG:__main__:Batch 2138/2500 complete
# DEBUG:__main__:Batch 2139/2500 complete
# DEBUG:__main__:Batch 2140/2500 complete
# DEBUG:__main__:Batch 2141/2500 complete
# DEBUG:__main__:Batch 2142/2500 complete
# DEBUG:__main__:Batch 2143/2500 complete
# DEBUG:__main__:Batch 2144/2500 complete
# DEBUG:__main__:Batch 2145/2500 complete
# DEBUG:__main__:Batch 2146/2500 complete
# DEBUG:__main__:Batch 2147/2500 complete
# DEBUG:__main__:Batch 2148/2500 complete
# DEBUG:__main__:Batch 2149/2500 complete
# DEBUG:__main__:Batch 2150/2500 complete
# DEBUG:__main__:Batch 2151/2500 complete
# DEBUG:__main__:Batch 2152/2500 complete
# DEBUG:__main__:Batch 2153/2500 complete
# DEBUG:__main__:Batch 2154/2500 complete
# DEBUG:__main__:Batch 2155/2500 complete
# DEBUG:__main__:Batch 2156/2500 complete
# DEBUG:__main__:Batch 2157/2500 complete
# DEBUG:__main__:Batch 2158/2500 complete
# DEBUG:__main__:Batch 2159/2500 complete
# DEBUG:__main__:Batch 2160/2500 complete
# DEBUG:__main__:Batch 2161/2500 complete
# DEBUG:__main__:Batch 2162/2500 complete
# DEBUG:__main__:Batch 2163/2500 complete
# DEBUG:__main__:Batch 2164/2500 complete
# DEBUG:__main__:Batch 2165/2500 complete
# DEBUG:__main__:Batch 2166/2500 complete
# DEBUG:__main__:Batch 2167/2500 complete
# DEBUG:__main__:Batch 2168/2500 complete
# DEBUG:__main__:Batch 2169/2500 complete
# DEBUG:__main__:Batch 2170/2500 complete
# DEBUG:__main__:Batch 2171/2500 complete
# DEBUG:__main__:Batch 2172/2500 complete
# DEBUG:__main__:Batch 2173/2500 complete
# DEBUG:__main__:Batch 2174/2500 complete
# DEBUG:__main__:Batch 2175/2500 complete
# DEBUG:__main__:Batch 2176/2500 complete
# DEBUG:__main__:Batch 2177/2500 complete
# DEBUG:__main__:Batch 2178/2500 complete
# DEBUG:__main__:Batch 2179/2500 complete
# DEBUG:__main__:Batch 2180/2500 complete
# DEBUG:__main__:Batch 2181/2500 complete
# DEBUG:__main__:Batch 2182/2500 complete
# DEBUG:__main__:Batch 2183/2500 complete
# DEBUG:__main__:Batch 2184/2500 complete
# DEBUG:__main__:Batch 2185/2500 complete
# DEBUG:__main__:Batch 2186/2500 complete
# DEBUG:__main__:Batch 2187/2500 complete
# DEBUG:__main__:Batch 2188/2500 complete
# DEBUG:__main__:Batch 2189/2500 complete
# DEBUG:__main__:Batch 2190/2500 complete
# DEBUG:__main__:Batch 2191/2500 complete
# DEBUG:__main__:Batch 2192/2500 complete
# DEBUG:__main__:Batch 2193/2500 complete
# DEBUG:__main__:Batch 2194/2500 complete
# DEBUG:__main__:Batch 2195/2500 complete
# DEBUG:__main__:Batch 2196/2500 complete
# DEBUG:__main__:Batch 2197/2500 complete
# DEBUG:__main__:Batch 2198/2500 complete
# DEBUG:__main__:Batch 2199/2500 complete
# DEBUG:__main__:Batch 2200/2500 complete
# DEBUG:__main__:Batch 2201/2500 complete
# DEBUG:__main__:Batch 2202/2500 complete
# DEBUG:__main__:Batch 2203/2500 complete
# DEBUG:__main__:Batch 2204/2500 complete
# DEBUG:__main__:Batch 2205/2500 complete
# DEBUG:__main__:Batch 2206/2500 complete
# DEBUG:__main__:Batch 2207/2500 complete
# DEBUG:__main__:Batch 2208/2500 complete
# DEBUG:__main__:Batch 2209/2500 complete
# DEBUG:__main__:Batch 2210/2500 complete
# DEBUG:__main__:Batch 2211/2500 complete
# DEBUG:__main__:Batch 2212/2500 complete
# DEBUG:__main__:Batch 2213/2500 complete
# DEBUG:__main__:Batch 2214/2500 complete
# DEBUG:__main__:Batch 2215/2500 complete
# DEBUG:__main__:Batch 2216/2500 complete
# DEBUG:__main__:Batch 2217/2500 complete
# DEBUG:__main__:Batch 2218/2500 complete
# DEBUG:__main__:Batch 2219/2500 complete
# DEBUG:__main__:Batch 2220/2500 complete
# DEBUG:__main__:Batch 2221/2500 complete
# DEBUG:__main__:Batch 2222/2500 complete
# DEBUG:__main__:Batch 2223/2500 complete
# DEBUG:__main__:Batch 2224/2500 complete
# DEBUG:__main__:Batch 2225/2500 complete
# DEBUG:__main__:Batch 2226/2500 complete
# DEBUG:__main__:Batch 2227/2500 complete
# DEBUG:__main__:Batch 2228/2500 complete
# DEBUG:__main__:Batch 2229/2500 complete
# DEBUG:__main__:Batch 2230/2500 complete
# DEBUG:__main__:Batch 2231/2500 complete
# DEBUG:__main__:Batch 2232/2500 complete
# DEBUG:__main__:Batch 2233/2500 complete
# DEBUG:__main__:Batch 2234/2500 complete
# DEBUG:__main__:Batch 2235/2500 complete
# DEBUG:__main__:Batch 2236/2500 complete
# DEBUG:__main__:Batch 2237/2500 complete
# DEBUG:__main__:Batch 2238/2500 complete
# DEBUG:__main__:Batch 2239/2500 complete
# DEBUG:__main__:Batch 2240/2500 complete
# DEBUG:__main__:Batch 2241/2500 complete
# DEBUG:__main__:Batch 2242/2500 complete
# DEBUG:__main__:Batch 2243/2500 complete
# DEBUG:__main__:Batch 2244/2500 complete
# DEBUG:__main__:Batch 2245/2500 complete
# DEBUG:__main__:Batch 2246/2500 complete
# DEBUG:__main__:Batch 2247/2500 complete
# DEBUG:__main__:Batch 2248/2500 complete
# DEBUG:__main__:Batch 2249/2500 complete
# DEBUG:__main__:Batch 2250/2500 complete
# DEBUG:__main__:Batch 2251/2500 complete
# DEBUG:__main__:Batch 2252/2500 complete
# DEBUG:__main__:Batch 2253/2500 complete
# DEBUG:__main__:Batch 2254/2500 complete
# DEBUG:__main__:Batch 2255/2500 complete
# DEBUG:__main__:Batch 2256/2500 complete
# DEBUG:__main__:Batch 2257/2500 complete
# DEBUG:__main__:Batch 2258/2500 complete
# DEBUG:__main__:Batch 2259/2500 complete
# DEBUG:__main__:Batch 2260/2500 complete
# DEBUG:__main__:Batch 2261/2500 complete
# DEBUG:__main__:Batch 2262/2500 complete
# DEBUG:__main__:Batch 2263/2500 complete
# DEBUG:__main__:Batch 2264/2500 complete
# DEBUG:__main__:Batch 2265/2500 complete
# DEBUG:__main__:Batch 2266/2500 complete
# DEBUG:__main__:Batch 2267/2500 complete
# DEBUG:__main__:Batch 2268/2500 complete
# DEBUG:__main__:Batch 2269/2500 complete
# DEBUG:__main__:Batch 2270/2500 complete
# DEBUG:__main__:Batch 2271/2500 complete
# DEBUG:__main__:Batch 2272/2500 complete
# DEBUG:__main__:Batch 2273/2500 complete
# DEBUG:__main__:Batch 2274/2500 complete
# DEBUG:__main__:Batch 2275/2500 complete
# DEBUG:__main__:Batch 2276/2500 complete
# DEBUG:__main__:Batch 2277/2500 complete
# DEBUG:__main__:Batch 2278/2500 complete
# DEBUG:__main__:Batch 2279/2500 complete
# DEBUG:__main__:Batch 2280/2500 complete
# DEBUG:__main__:Batch 2281/2500 complete
# DEBUG:__main__:Batch 2282/2500 complete
# DEBUG:__main__:Batch 2283/2500 complete
# DEBUG:__main__:Batch 2284/2500 complete
# DEBUG:__main__:Batch 2285/2500 complete
# DEBUG:__main__:Batch 2286/2500 complete
# DEBUG:__main__:Batch 2287/2500 complete
# DEBUG:__main__:Batch 2288/2500 complete
# DEBUG:__main__:Batch 2289/2500 complete
# DEBUG:__main__:Batch 2290/2500 complete
# DEBUG:__main__:Batch 2291/2500 complete
# DEBUG:__main__:Batch 2292/2500 complete
# DEBUG:__main__:Batch 2293/2500 complete
# DEBUG:__main__:Batch 2294/2500 complete
# DEBUG:__main__:Batch 2295/2500 complete
# DEBUG:__main__:Batch 2296/2500 complete
# DEBUG:__main__:Batch 2297/2500 complete
# DEBUG:__main__:Batch 2298/2500 complete
# DEBUG:__main__:Batch 2299/2500 complete
# DEBUG:__main__:Batch 2300/2500 complete
# DEBUG:__main__:Batch 2301/2500 complete
# DEBUG:__main__:Batch 2302/2500 complete
# DEBUG:__main__:Batch 2303/2500 complete
# DEBUG:__main__:Batch 2304/2500 complete
# DEBUG:__main__:Batch 2305/2500 complete
# DEBUG:__main__:Batch 2306/2500 complete
# DEBUG:__main__:Batch 2307/2500 complete
# DEBUG:__main__:Batch 2308/2500 complete
# DEBUG:__main__:Batch 2309/2500 complete
# DEBUG:__main__:Batch 2310/2500 complete
# DEBUG:__main__:Batch 2311/2500 complete
# DEBUG:__main__:Batch 2312/2500 complete
# DEBUG:__main__:Batch 2313/2500 complete
# DEBUG:__main__:Batch 2314/2500 complete
# DEBUG:__main__:Batch 2315/2500 complete
# DEBUG:__main__:Batch 2316/2500 complete
# DEBUG:__main__:Batch 2317/2500 complete
# DEBUG:__main__:Batch 2318/2500 complete
# DEBUG:__main__:Batch 2319/2500 complete
# DEBUG:__main__:Batch 2320/2500 complete
# DEBUG:__main__:Batch 2321/2500 complete
# DEBUG:__main__:Batch 2322/2500 complete
# DEBUG:__main__:Batch 2323/2500 complete
# DEBUG:__main__:Batch 2324/2500 complete
# DEBUG:__main__:Batch 2325/2500 complete
# DEBUG:__main__:Batch 2326/2500 complete
# DEBUG:__main__:Batch 2327/2500 complete
# DEBUG:__main__:Batch 2328/2500 complete
# DEBUG:__main__:Batch 2329/2500 complete
# DEBUG:__main__:Batch 2330/2500 complete
# DEBUG:__main__:Batch 2331/2500 complete
# DEBUG:__main__:Batch 2332/2500 complete
# DEBUG:__main__:Batch 2333/2500 complete
# DEBUG:__main__:Batch 2334/2500 complete
# DEBUG:__main__:Batch 2335/2500 complete
# DEBUG:__main__:Batch 2336/2500 complete
# DEBUG:__main__:Batch 2337/2500 complete
# DEBUG:__main__:Batch 2338/2500 complete
# DEBUG:__main__:Batch 2339/2500 complete
# DEBUG:__main__:Batch 2340/2500 complete
# DEBUG:__main__:Batch 2341/2500 complete
# DEBUG:__main__:Batch 2342/2500 complete
# DEBUG:__main__:Batch 2343/2500 complete
# DEBUG:__main__:Batch 2344/2500 complete
# DEBUG:__main__:Batch 2345/2500 complete
# DEBUG:__main__:Batch 2346/2500 complete
# DEBUG:__main__:Batch 2347/2500 complete
# DEBUG:__main__:Batch 2348/2500 complete
# DEBUG:__main__:Batch 2349/2500 complete
# DEBUG:__main__:Batch 2350/2500 complete
# DEBUG:__main__:Batch 2351/2500 complete
# DEBUG:__main__:Batch 2352/2500 complete
# DEBUG:__main__:Batch 2353/2500 complete
# DEBUG:__main__:Batch 2354/2500 complete
# DEBUG:__main__:Batch 2355/2500 complete
# DEBUG:__main__:Batch 2356/2500 complete
# DEBUG:__main__:Batch 2357/2500 complete
# DEBUG:__main__:Batch 2358/2500 complete
# DEBUG:__main__:Batch 2359/2500 complete
# DEBUG:__main__:Batch 2360/2500 complete
# DEBUG:__main__:Batch 2361/2500 complete
# DEBUG:__main__:Batch 2362/2500 complete
# DEBUG:__main__:Batch 2363/2500 complete
# DEBUG:__main__:Batch 2364/2500 complete
# DEBUG:__main__:Batch 2365/2500 complete
# DEBUG:__main__:Batch 2366/2500 complete
# DEBUG:__main__:Batch 2367/2500 complete
# DEBUG:__main__:Batch 2368/2500 complete
# DEBUG:__main__:Batch 2369/2500 complete
# DEBUG:__main__:Batch 2370/2500 complete
# DEBUG:__main__:Batch 2371/2500 complete
# DEBUG:__main__:Batch 2372/2500 complete
# DEBUG:__main__:Batch 2373/2500 complete
# DEBUG:__main__:Batch 2374/2500 complete
# DEBUG:__main__:Batch 2375/2500 complete
# DEBUG:__main__:Batch 2376/2500 complete
# DEBUG:__main__:Batch 2377/2500 complete
# DEBUG:__main__:Batch 2378/2500 complete
# DEBUG:__main__:Batch 2379/2500 complete
# DEBUG:__main__:Batch 2380/2500 complete
# DEBUG:__main__:Batch 2381/2500 complete
# DEBUG:__main__:Batch 2382/2500 complete
# DEBUG:__main__:Batch 2383/2500 complete
# DEBUG:__main__:Batch 2384/2500 complete
# DEBUG:__main__:Batch 2385/2500 complete
# DEBUG:__main__:Batch 2386/2500 complete
# DEBUG:__main__:Batch 2387/2500 complete
# DEBUG:__main__:Batch 2388/2500 complete
# DEBUG:__main__:Batch 2389/2500 complete
# DEBUG:__main__:Batch 2390/2500 complete
# DEBUG:__main__:Batch 2391/2500 complete
# DEBUG:__main__:Batch 2392/2500 complete
# DEBUG:__main__:Batch 2393/2500 complete
# DEBUG:__main__:Batch 2394/2500 complete
# DEBUG:__main__:Batch 2395/2500 complete
# DEBUG:__main__:Batch 2396/2500 complete
# DEBUG:__main__:Batch 2397/2500 complete
# DEBUG:__main__:Batch 2398/2500 complete
# DEBUG:__main__:Batch 2399/2500 complete
# DEBUG:__main__:Batch 2400/2500 complete
# DEBUG:__main__:Batch 2401/2500 complete
# DEBUG:__main__:Batch 2402/2500 complete
# DEBUG:__main__:Batch 2403/2500 complete
# DEBUG:__main__:Batch 2404/2500 complete
# DEBUG:__main__:Batch 2405/2500 complete
# DEBUG:__main__:Batch 2406/2500 complete
# DEBUG:__main__:Batch 2407/2500 complete
# DEBUG:__main__:Batch 2408/2500 complete
# DEBUG:__main__:Batch 2409/2500 complete
# DEBUG:__main__:Batch 2410/2500 complete
# DEBUG:__main__:Batch 2411/2500 complete
# DEBUG:__main__:Batch 2412/2500 complete
# DEBUG:__main__:Batch 2413/2500 complete
# DEBUG:__main__:Batch 2414/2500 complete
# DEBUG:__main__:Batch 2415/2500 complete
# DEBUG:__main__:Batch 2416/2500 complete
# DEBUG:__main__:Batch 2417/2500 complete
# DEBUG:__main__:Batch 2418/2500 complete
# DEBUG:__main__:Batch 2419/2500 complete
# DEBUG:__main__:Batch 2420/2500 complete
# DEBUG:__main__:Batch 2421/2500 complete
# DEBUG:__main__:Batch 2422/2500 complete
# DEBUG:__main__:Batch 2423/2500 complete
# DEBUG:__main__:Batch 2424/2500 complete
# DEBUG:__main__:Batch 2425/2500 complete
# DEBUG:__main__:Batch 2426/2500 complete
# DEBUG:__main__:Batch 2427/2500 complete
# DEBUG:__main__:Batch 2428/2500 complete
# DEBUG:__main__:Batch 2429/2500 complete
# DEBUG:__main__:Batch 2430/2500 complete
# DEBUG:__main__:Batch 2431/2500 complete
# DEBUG:__main__:Batch 2432/2500 complete
# DEBUG:__main__:Batch 2433/2500 complete
# DEBUG:__main__:Batch 2434/2500 complete
# DEBUG:__main__:Batch 2435/2500 complete
# DEBUG:__main__:Batch 2436/2500 complete
# DEBUG:__main__:Batch 2437/2500 complete
# DEBUG:__main__:Batch 2438/2500 complete
# DEBUG:__main__:Batch 2439/2500 complete
# DEBUG:__main__:Batch 2440/2500 complete
# DEBUG:__main__:Batch 2441/2500 complete
# DEBUG:__main__:Batch 2442/2500 complete
# DEBUG:__main__:Batch 2443/2500 complete
# DEBUG:__main__:Batch 2444/2500 complete
# DEBUG:__main__:Batch 2445/2500 complete
# DEBUG:__main__:Batch 2446/2500 complete
# DEBUG:__main__:Batch 2447/2500 complete
# DEBUG:__main__:Batch 2448/2500 complete
# DEBUG:__main__:Batch 2449/2500 complete
# DEBUG:__main__:Batch 2450/2500 complete
# DEBUG:__main__:Batch 2451/2500 complete
# DEBUG:__main__:Batch 2452/2500 complete
# DEBUG:__main__:Batch 2453/2500 complete
# DEBUG:__main__:Batch 2454/2500 complete
# DEBUG:__main__:Batch 2455/2500 complete
# DEBUG:__main__:Batch 2456/2500 complete
# DEBUG:__main__:Batch 2457/2500 complete
# DEBUG:__main__:Batch 2458/2500 complete
# DEBUG:__main__:Batch 2459/2500 complete
# DEBUG:__main__:Batch 2460/2500 complete
# DEBUG:__main__:Batch 2461/2500 complete
# DEBUG:__main__:Batch 2462/2500 complete
# DEBUG:__main__:Batch 2463/2500 complete
# DEBUG:__main__:Batch 2464/2500 complete
# DEBUG:__main__:Batch 2465/2500 complete
# DEBUG:__main__:Batch 2466/2500 complete
# DEBUG:__main__:Batch 2467/2500 complete
# DEBUG:__main__:Batch 2468/2500 complete
# DEBUG:__main__:Batch 2469/2500 complete
# DEBUG:__main__:Batch 2470/2500 complete
# DEBUG:__main__:Batch 2471/2500 complete
# DEBUG:__main__:Batch 2472/2500 complete
# DEBUG:__main__:Batch 2473/2500 complete
# DEBUG:__main__:Batch 2474/2500 complete
# DEBUG:__main__:Batch 2475/2500 complete
# DEBUG:__main__:Batch 2476/2500 complete
# DEBUG:__main__:Batch 2477/2500 complete
# DEBUG:__main__:Batch 2478/2500 complete
# DEBUG:__main__:Batch 2479/2500 complete
# DEBUG:__main__:Batch 2480/2500 complete
# DEBUG:__main__:Batch 2481/2500 complete
# DEBUG:__main__:Batch 2482/2500 complete
# DEBUG:__main__:Batch 2483/2500 complete
# DEBUG:__main__:Batch 2484/2500 complete
# DEBUG:__main__:Batch 2485/2500 complete
# DEBUG:__main__:Batch 2486/2500 complete
# DEBUG:__main__:Batch 2487/2500 complete
# DEBUG:__main__:Batch 2488/2500 complete
# DEBUG:__main__:Batch 2489/2500 complete
# DEBUG:__main__:Batch 2490/2500 complete
# DEBUG:__main__:Batch 2491/2500 complete
# DEBUG:__main__:Batch 2492/2500 complete
# DEBUG:__main__:Batch 2493/2500 complete
# DEBUG:__main__:Batch 2494/2500 complete
# DEBUG:__main__:Batch 2495/2500 complete
# DEBUG:__main__:Batch 2496/2500 complete
# DEBUG:__main__:Batch 2497/2500 complete
# DEBUG:__main__:Batch 2498/2500 complete
# DEBUG:__main__:Batch 2499/2500 complete
# DEBUG:__main__:Batch 2500/2500 complete
# INFO:__main__:Done

# %%
import shutil, glob, random

train_dir = "/content/vicky_output/vicky/positive_train"
test_dir = "/content/vicky_output/vicky/positive_test"

fr_clips = glob.glob("/content/vicky_fr_1/*.wav") + glob.glob("/content/vicky_fr_2/*.wav") + glob.glob("/content/vicky_fr_3/*.wav")
random.shuffle(fr_clips)
split = int(len(fr_clips) * 0.8)

for i, f in enumerate(fr_clips[:split]):
    shutil.copy(f, f"{train_dir}/fr_{i}.wav")
for i, f in enumerate(fr_clips[split:]):
    shutil.copy(f, f"{test_dir}/fr_{i}.wav")

print(f"{split} clips FR ajoutés à positive_train, {len(fr_clips)-split} à positive_test")
# Out:
# 6000 clips FR ajoutés à positive_train, 1500 à positive_test

# %%
import soundfile as sf
info = sf.info('/content/vicky_output/vicky/positive_train/fr_0.wav')
print(f'Sample rate: {info.samplerate} Hz')
# Out:
# Sample rate: 22050 Hz

# %%
import soundfile as sf
import librosa
import glob
import os

for folder in ["/content/vicky_output/vicky/positive_train", "/content/vicky_output/vicky/positive_test"]:
    for path in glob.glob(f"{folder}/*.wav"):
        info = sf.info(path)
        if info.samplerate != 16000:
            audio, sr = librosa.load(path, sr=16000)
            sf.write(path, audio, 16000)

print("Resampling terminé")
# Out:
# Resampling terminé

# %%
import os, glob, soundfile as sf, yaml
from scipy.signal import resample_poly
from tqdm.auto import tqdm
TARGET_SR = 16000
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
ROOT = cfg['output_dir']
wav_dirs = sorted({os.path.dirname(f)
                   for f in glob.glob(f'{ROOT}/**/*.wav', recursive=True)})
for d in wav_dirs:
    files = [f for f in os.listdir(d) if f.endswith('.wav')]
    if not files: continue
    sr_counts = {}
    for f in files[:20]:
        sr = sf.info(f'{d}/{f}').samplerate
        sr_counts[sr] = sr_counts.get(sr, 0) + 1
    if all(k == TARGET_SR for k in sr_counts):
        print(f'  ok {d}: {len(files)} files at 16 kHz (skip)')
        continue
    print(f'  resampling {d}: {len(files)} files, SRs {sr_counts}')
    n = 0
    for f in tqdm(files, desc=os.path.basename(d) or d, leave=False):
        p = f'{d}/{f}'
        data, sr = sf.read(p)
        if sr == TARGET_SR: continue
        new_data = resample_poly(data.astype('float32'), TARGET_SR, sr)
        sf.write(p, new_data, TARGET_SR); n += 1
    print(f'  ok {d}: resampled {n}/{len(files)}')
# Clear stale .npy features so augment re-runs cleanly
for f in glob.glob(f'{ROOT}/**/*.npy', recursive=True):
    os.remove(f)
print('\n  cleared stale features (will be regenerated by augment)')
# Out:
#   ok /content/vicky_output/vicky/negative_test: 1000 files at 16 kHz (skip)
#   resampling /content/vicky_output/vicky/negative_train: 5000 files, SRs {22050: 20}
# negative_train:   0%|          | 0/5000 [00:00<?, ?it/s]
#   ok /content/vicky_output/vicky/negative_train: resampled 5000/5000
#   ok /content/vicky_output/vicky/positive_test: 2500 files at 16 kHz (skip)
#   ok /content/vicky_output/vicky/positive_train: 11000 files at 16 kHz (skip)
#
#   cleared stale features (will be regenerated by augment)

# %% [markdown]
# ## 13. Augment + featurise (~10 min)
#
# Outputs `(N, 16, 96)` feature .npy files that the hand-rolled trainer reads.

# %%
import sys, os, glob, yaml
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
FEAT = cfg['feature_save_dir']
needed = ['positive_features_train.npy', 'negative_features_train.npy',
          'positive_features_test.npy',  'negative_features_test.npy']
if all(os.path.exists(f'{FEAT}/{n}') for n in needed):
    print('  cached: all 4 feature .npy files exist')
else:
    # !{sys.executable} /content/openwakeword/openwakeword/train.py \
        --training_config /content/my_model.yaml \
        --augment_clips
for f in sorted(glob.glob(f'{FEAT}/*.npy')):
    print(f'  {f}: {os.path.getsize(f)/1e6:.1f} MB')
for n in needed:
    assert os.path.exists(f'{FEAT}/{n}'), f"augment didn't produce {n}"
print('  PASS all 4 feature files present')
# Out:
# INFO:root:##################################################
# Computing openwakeword features for generated samples
# ##################################################
# /usr/local/lib/python3.13/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:153: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = PitchShift(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = BandStopFilter(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddColoredNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddBackgroundNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Gain(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/composition.py:42: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Compose(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/audiomentations/core/transforms_interface.py:107: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# Computing features:  11% 76/687 [01:15<11:26,  1.12s/it]

# %% [markdown]
# ## 14. Hand-rolled trainer (~30-40 min on L4 / A100)
#
# Mirrors openWakeWord's `auto_train`: 3-stage lr schedule (1e-4 â†’ 1e-5 â†’ 1e-6), neg_weight ramp 1â†’1500, hard-negative mining, FP/hour validation against ACAV val, percentile-based checkpoint saves.

# %%
import os, copy, math, time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import yaml
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {DEVICE}')
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
FEAT = cfg['feature_save_dir']
pos_train = torch.from_numpy(np.load(f'{FEAT}/positive_features_train.npy').astype(np.float32)).to(DEVICE)
neg_train = torch.from_numpy(np.load(f'{FEAT}/negative_features_train.npy').astype(np.float32)).to(DEVICE)
pos_test  = torch.from_numpy(np.load(f'{FEAT}/positive_features_test.npy').astype(np.float32)).to(DEVICE)
neg_test  = torch.from_numpy(np.load(f'{FEAT}/negative_features_test.npy').astype(np.float32)).to(DEVICE)
print(f'  pos_train={tuple(pos_train.shape)}  neg_train={tuple(neg_train.shape)}')
print(f'  pos_test={tuple(pos_test.shape)}  neg_test={tuple(neg_test.shape)}')

acav_train_np = np.load(cfg['feature_data_files']['ACAV100M_sample'], mmap_mode='r')
print(f'  acav_train (mmap): {acav_train_np.shape}')
acav_val_np = np.load(cfg['false_positive_validation_data_path'])
M = acav_val_np.shape[0]
val_listen_hours = M * 0.08 / 3600.0
print(f'  acav_val: {acav_val_np.shape}  â†’ {val_listen_hours:.2f} hr listening time')
n_win_val = M - 16
acav_val_windows = np.lib.stride_tricks.sliding_window_view(acav_val_np, (16, 96))[:, 0, :, :]
acav_val_windows = np.ascontiguousarray(acav_val_windows.astype(np.float32))
print(f'  acav_val_windows: {acav_val_windows.shape} ({acav_val_windows.nbytes/1e6:.0f} MB)')
VAL_BATCH = 4096

class WakewordModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(16 * 96, 128)
        self.layernorm1 = nn.LayerNorm(128)
        self.relu1 = nn.ReLU()
        self.layer2 = nn.Linear(128, 1)
    def forward(self, x):
        return self.layer2(self.relu1(self.layernorm1(self.layer1(self.flatten(x)))))

model = WakewordModel().to(DEVICE)
loss_fn = nn.BCEWithLogitsLoss(reduction='none')
TOTAL_STEPS = cfg['steps']
MAX_NEG_W   = cfg['max_negative_weight']
TARGET_FP_PER_HR = cfg['target_false_positives_per_hour']
THRESH = 0.5
history = {'val_recall': [], 'val_accuracy': [], 'val_fp_per_hour': [], 'val_n_fp': [], 'loss': []}
best_models = []

B_POS, B_ANEG, B_ACAV = 32, 32, 64
def random_acav_window_batch(k):
    N, T, F = acav_train_np.shape
    rows = np.random.randint(0, N, size=k)
    starts = np.random.randint(0, T - 16 + 1, size=k)
    out = np.empty((k, 16, F), dtype=np.float32)
    for i, (r, s) in enumerate(zip(rows, starts)):
        out[i] = acav_train_np[r, s:s+16, :].astype(np.float32)
    return out

def build_batch():
    p_idx = torch.randint(0, pos_train.shape[0], (B_POS,), device=DEVICE)
    aneg_idx = torch.randint(0, neg_train.shape[0], (B_ANEG,), device=DEVICE)
    p, an = pos_train[p_idx], neg_train[aneg_idx]
    acav = torch.from_numpy(random_acav_window_batch(B_ACAV)).to(DEVICE)
    x = torch.cat([p, an, acav], dim=0)
    y = torch.cat([torch.ones(B_POS, device=DEVICE),
                   torch.zeros(B_ANEG + B_ACAV, device=DEVICE)])
    return x, y

@torch.no_grad()
def validate(step_label):
    model.eval()
    p_preds = torch.sigmoid(model(pos_test)).squeeze(-1)
    n_preds = torch.sigmoid(model(neg_test)).squeeze(-1)
    recall = (p_preds >= THRESH).float().mean().item()
    accuracy = (((p_preds >= THRESH).sum() + (n_preds < THRESH).sum()).item()
                / (pos_test.shape[0] + neg_test.shape[0]))
    n_fp = 0
    for i in range(0, n_win_val, VAL_BATCH):
        chunk = torch.from_numpy(acav_val_windows[i:i+VAL_BATCH]).to(DEVICE)
        n_fp += (torch.sigmoid(model(chunk)).squeeze(-1) >= THRESH).sum().item()
    fp_per_hour = n_fp / max(val_listen_hours, 1e-6)
    history['val_recall'].append(recall)
    history['val_accuracy'].append(accuracy)
    history['val_fp_per_hour'].append(fp_per_hour)
    history['val_n_fp'].append(n_fp)
    save = False
    if len(history['val_n_fp']) >= 3:
        fp_p50 = np.percentile(history['val_n_fp'], 50)
        rc_p5  = np.percentile(history['val_recall'], 5)
        if n_fp <= fp_p50 and recall >= rc_p5:
            best_models.append((copy.deepcopy(model.state_dict()),
                                {'val_recall': recall, 'val_accuracy': accuracy,
                                 'val_fp_per_hour': fp_per_hour, 'val_n_fp': n_fp}))
            save = True
    print(f'  [{step_label}] recall={recall:.3f}  acc={accuracy:.3f}  fp/hr={fp_per_hour:.2f}  saved={"+" if save else "-"}', flush=True)
    model.train()

def run_stage(stage_idx, n_steps, lr, max_neg_w, val_window_frac=1.0):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    weight_schedule = np.linspace(1.0, max_neg_w, n_steps)
    val_start = int(n_steps * (1.0 - val_window_frac))
    val_steps = set(np.linspace(val_start, n_steps - 1, 20).astype(int))
    warmup = max(1, n_steps // 5)
    hold   = n_steps // 3
    accumulated = []
    print(f'\n=== Stage {stage_idx}: {n_steps} steps, lr={lr}, max_neg_w={max_neg_w} ===', flush=True)
    t0 = time.time()
    for step in range(n_steps):
        if step < warmup:
            lr_now = lr * (step + 1) / warmup
        elif step < warmup + hold:
            lr_now = lr
        else:
            decay_t = (step - warmup - hold) / max(1, n_steps - warmup - hold)
            lr_now = lr * 0.5 * (1.0 + math.cos(math.pi * min(1.0, decay_t)))
        for pg in optimizer.param_groups: pg['lr'] = lr_now
        x, y = build_batch()
        logits = model(x).squeeze(-1)
        preds = torch.sigmoid(logits)
        keep = ((y == 0) & (preds >= 0.001)) | ((y == 1) & (preds < 0.999))
        if keep.sum() == 0:
            if step in val_steps: validate(f'stage{stage_idx} step {step}/{n_steps}')
            continue
        kept_logits = logits[keep]
        kept_y = y[keep]
        neg_w = weight_schedule[step]
        w = torch.where(kept_y > 0.5,
                        torch.tensor(1.0, device=DEVICE),
                        torch.tensor(neg_w, device=DEVICE, dtype=torch.float32))
        accumulated.append((kept_logits, kept_y, w))
        if sum(t[0].shape[0] for t in accumulated) >= 128:
            cat_logits = torch.cat([t[0] for t in accumulated])
            cat_y = torch.cat([t[1] for t in accumulated])
            cat_w = torch.cat([t[2] for t in accumulated])
            loss = (loss_fn(cat_logits, cat_y) * cat_w).mean()
            optimizer.zero_grad(); loss.backward(); optimizer.step()
            history['loss'].append(loss.item())
            accumulated.clear()
        if step in val_steps:
            elapsed = (time.time() - t0) / 60
            validate(f'stage{stage_idx} step {step}/{n_steps} ({elapsed:.1f}m, lr={lr_now:.6f}, neg_w={neg_w:.0f})')
    print(f'  Stage {stage_idx} done in {(time.time()-t0)/60:.1f} min', flush=True)

stage1_steps = TOTAL_STEPS
stage2_steps = max(2000, TOTAL_STEPS // 10)
stage3_steps = max(2000, TOTAL_STEPS // 10)
max_neg_w_now = MAX_NEG_W
run_stage(1, stage1_steps, lr=1e-4, max_neg_w=max_neg_w_now, val_window_frac=0.25)
if (history['val_fp_per_hour'] and min(history['val_fp_per_hour']) > TARGET_FP_PER_HR):
    max_neg_w_now *= 2
    print(f'\n[adapt] stage1 best FP/hr > target â†’ max_neg_w doubled to {max_neg_w_now}')
run_stage(2, stage2_steps, lr=1e-5, max_neg_w=max_neg_w_now, val_window_frac=1.0)
if (history['val_fp_per_hour'] and min(history['val_fp_per_hour']) > TARGET_FP_PER_HR):
    max_neg_w_now *= 2
    print(f'\n[adapt] stage2 best FP/hr > target â†’ max_neg_w doubled to {max_neg_w_now}')
run_stage(3, stage3_steps, lr=1e-6, max_neg_w=max_neg_w_now, val_window_frac=1.0)
print(f'\n=== Training done. {len(best_models)} checkpoints saved. ===')
print(f'  best val_fp_per_hour: {min(history["val_fp_per_hour"]):.2f}')
print(f'  best val_recall:      {max(history["val_recall"]):.3f}')
print(f'  best val_accuracy:    {max(history["val_accuracy"]):.3f}')

# %% [markdown]
# ## 15. Ensemble best checkpoints + ONNX export + download
#
# 90/90/10 percentile filter on saved checkpoints, average state_dicts, export ONNX with sigmoid baked in, sanity-check, browser-download.

# %%
import copy, os
import numpy as np
import torch
if not best_models:
    print('  no saved checkpoints â€” using current model state')
    final_state = {k: v.clone() for k, v in model.state_dict().items()}
else:
    accs = [s['val_accuracy'] for _, s in best_models]
    rcs  = [s['val_recall']   for _, s in best_models]
    fps  = [s['val_fp_per_hour'] for _, s in best_models]
    acc_p90 = np.percentile(accs, 90)
    rc_p90  = np.percentile(rcs, 90)
    fp_p10  = np.percentile(fps, 10)
    print(f'  thresholds: accâ‰¥{acc_p90:.3f}  recallâ‰¥{rc_p90:.3f}  fp/hrâ‰¤{fp_p10:.2f}')
    qualified = [(sd, sc) for sd, sc in best_models
                 if sc['val_accuracy'] >= acc_p90 and sc['val_recall'] >= rc_p90
                 and sc['val_fp_per_hour'] <= fp_p10]
    print(f'  qualified: {len(qualified)} of {len(best_models)} checkpoints')
    if not qualified:
        sorted_models = sorted(best_models, key=lambda t: (t[1]['val_fp_per_hour'], -t[1]['val_recall']))
        qualified = [sorted_models[0]]
        print('  no checkpoint qualified â€” fell back to single best')
    keys = qualified[0][0].keys()
    final_state = {k: torch.stack([sd[k].float() for sd, _ in qualified]).mean(dim=0) for k in keys}
    qa = np.mean([s['val_accuracy'] for _, s in qualified])
    qr = np.mean([s['val_recall'] for _, s in qualified])
    qf = np.mean([s['val_fp_per_hour'] for _, s in qualified])
    print(f'  ensemble averaged: mean acc={qa:.3f}, recall={qr:.3f}, fp/hr={qf:.2f}')
model.load_state_dict(final_state)
model.eval()

# Export with sigmoid baked in so APK runtime sees [0, 1]
out_path = f"{cfg['feature_save_dir']}/{cfg['model_name']}.onnx"
os.makedirs(os.path.dirname(out_path), exist_ok=True)
class WakewordExportable(torch.nn.Module):
    def __init__(self, base): super().__init__(); self.base = base
    def forward(self, x): return torch.sigmoid(self.base(x))
export_model = WakewordExportable(model).to(DEVICE).eval()
dummy = torch.randn(1, 16, 96, device=DEVICE)
torch.onnx.export(export_model, dummy, out_path,
                  input_names=['onnx::Flatten_0'], output_names=['output'],
                  dynamic_axes={'onnx::Flatten_0': {0: 'batch'}, 'output': {0: 'batch'}},
                  opset_version=14, dynamo=False)
print(f'  âœ“ wrote {out_path} ({os.path.getsize(out_path)/1e3:.0f} KB)')

import onnxruntime as ort
sess = ort.InferenceSession(out_path)
print(f'  input:  {sess.get_inputs()[0].name} {sess.get_inputs()[0].shape}')
print(f'  output: {sess.get_outputs()[0].name} {sess.get_outputs()[0].shape}')
with torch.no_grad():
    p_test_np = pos_test.cpu().numpy()
    p_scores = sess.run(None, {sess.get_inputs()[0].name: p_test_np})[0].flatten()
    print(f'  positive test set: mean={p_scores.mean():.3f}, recall@0.5={(p_scores>=0.5).mean():.3f}')
print(f'  ACAV val FP/hour at 0.5: {history["val_fp_per_hour"][-1]:.2f}')

from google.colab import files
files.download(out_path)
print(f'\nDONE. Wake word "{cfg["model_name"]}" trained.')
print('Drop the downloaded .onnx into your APK / on-device app at:')
print(f'  android/app/src/main/assets/wakewords/{cfg["model_name"]}.onnx  (or wherever your APK looks)')
