# %% [markdown]
# # Custom wake-word trainer — bulletproof Colab notebook (2026 edition)
#
# Train your own openWakeWord model in ~75-90 minutes on Colab Pro. **Run all → walk away → download `.onnx`** at the end.
#
# ## Why this notebook exists
#
# openWakeWord's official Colab notebook bit-rotted hard against Python 3.12 (no piper-phonemize wheels), against torchaudio 2.x (`set_audio_backend` removed), against newer Colab images (HF Hub timeouts, namespace-package edge cases), and against its own internal config schema (4 keys silently moved to required-or-`KeyError` over the past year).
#
# This notebook is patched against all of that. Every cell is **self-healing** — checks its own outputs, re-creates what's missing. There's a hard pre-flight gate (cell 4) that catches every dep/file issue before any of the slow downloads start.
#
# It also **replaces openwakeword's `auto_train` with a faithful hand-rolled PyTorch loop** that mirrors auto_train's curriculum exactly: 3-stage learning rate (1e-4 → 1e-5 → 1e-6), negative-weight ramp 1→1500, hard-negative mining, FP-per-hour validation against an ACAV100M continuous-audio slice, 90/90/10 percentile checkpoint ensemble averaging. The upstream `auto_train` path keeps surfacing bugs against `mmap_batch_generator` shape handling on current openwakeword `master`; the hand-rolled trainer in cell 14 is small enough to read in one sitting and debug if anything ever changes.
#
# ## Run order
#
# 1. **Runtime → Change runtime type → L4 GPU + High RAM** (Colab Pro, $10/mo). Free T4 also works but is ~2× slower.
# 2. **Cell 10 — edit `TARGET_PHRASE` and `MODEL_NAME`** for your wake word. (Default = `mr graves`, the example we trained with.)
# 3. **Runtime → Run all**
# 4. Walk away ~75-90 min. Last cell downloads `<MODEL_NAME>.onnx`.
#
# ## Validated example (Mr Graves, 2026-05-09)
#
# 13 real-world utterances on a Pixel — every utterance fired:
#
# ```
# WAKE — score=0.99664426
# WAKE — score=0.59243464
# WAKE — score=0.65439160
# WAKE — score=0.77693284
# WAKE — score=0.85433600
# WAKE — score=0.64701974
# WAKE — score=0.80747485
# WAKE — score=0.95243360
# WAKE — score=0.99938180
# WAKE — score=0.90104705
# WAKE — score=0.99639570
# WAKE — score=0.98879445
# WAKE — score=0.51673140
# ```
#
# 13/13 fires, scores 0.52-0.999, **zero phantom fires** during 30 min of normal phone use (TV, music, conversation, kitchen noise). Matches openwakeword's pretrained Hey Jarvis baseline (0.984/0.989) on clear utterances.
#
# For deeper context on what auto_train actually does and why every part of the curriculum matters, the comments in cell 14 walk through each piece.

# %% [markdown]
# ## 1. Comprehensive install — apt + pip + verify
#
# Every dep + transitive we've discovered. `piper-tts` goes LAST via `--no-deps` so no later install can clobber it (piper-tts pulls regular `piper-phonemize` which has no Py 3.12 wheel; `piper-phonemize-cross` provides the same module name and is installed first).

# %%
20# Native deps
# !apt-get install -y -qq cmake espeak-ng espeak-ng-data libespeak-ng-dev libsndfile1 pkg-config build-essential ffmpeg unzip 2>&1 | tail -3

# Python deps — installed in this exact order:
#   (a) piper-phonemize-cross FIRST (Py3.12-compatible fork; same module name as piper-phonemize)
#   (b) Everything openwakeword.train / data.py / utils.py touch (ALL transitives, not just direct)
#   (c) piper-tts LAST via --no-deps (so nothing later can downgrade/clobber it)
# !pip install -q piper-phonemize-fix
# !pip install -q \
    webrtcvad \
    mutagen==1.47.0 \
    torchinfo \
    torchmetrics \
    pyyaml \
    tqdm \
    datasets \
    soundfile \
    audiomentations \
    torch_audiomentations \
    pronouncing \
    onnxruntime \
    onnx \
    speechbrain \
    acoustics \
    scipy \
    requests \
    huggingface_hub
# !pip install -q --no-deps piper-tts

# Verify imports — every module openwakeword's train.py, data.py and utils.py
# touch. If anything's missing this surfaces NOW, before any 75-min run.
import sys
print('Python:', sys.version)
import torch, torchinfo, torchmetrics, scipy, numpy
print(f'  torch: {torch.__version__}  cuda: {torch.cuda.is_available()}')
from tqdm import tqdm
import yaml, mutagen, pronouncing
import torchaudio, audiomentations, torch_audiomentations
import speechbrain, acoustics
import onnx, onnxruntime, soundfile, requests
from piper_phonemize import phonemize_espeak
print(phonemize_espeak("test", "en-us"))
from piper import PiperVoice, SynthesisConfig
print('  All openwakeword deps (incl. piper-tts) import cleanly.')

# %% [markdown]
# ## 2. Clone repos + download model (self-healing)
#
# Each piece (piper-sample-generator clone, libritts .pt model, openwakeword clone) is checked individually and re-created if missing or partial. Pin piper-sample-generator to commit `1a8c49bd^` — the parent of "Move to package", which is the last revision with flat-layout `generate_samples.py` at the root that openwakeword's train.py expects to import.

# %%
import os, sys
os.chdir('/content')

# ── piper-sample-generator (pinned to flat-layout commit) ─────────────
PSG_DIR = '/content/piper-sample-generator'
PSG_PIN = '1a8c49bd29b3a132721086ee88f2253f788594a8^'
PSG_GS  = f'{PSG_DIR}/generate_samples.py'
if not os.path.exists(PSG_GS):
    print('  piper-sample-generator missing or broken — re-cloning')
    # !rm -rf {PSG_DIR}
    # !git clone -q https://github.com/rhasspy/piper-sample-generator {PSG_DIR}
# !cd {PSG_DIR} && git fetch -q --all && git checkout -q {PSG_PIN}
assert os.path.exists(PSG_GS), 'piper-sample-generator pin did not yield generate_samples.py'
print(f'  ✓ piper-sample-generator pinned: {PSG_GS} ({os.path.getsize(PSG_GS)} bytes)')

# ── libritts model (~200 MB) ────────────────────────────────────────────
PIPER_MODEL = f'{PSG_DIR}/models/en_US-libritts_r-medium.pt'
PIPER_MODEL_URL = 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
if not os.path.exists(PIPER_MODEL) or os.path.getsize(PIPER_MODEL) < 100_000_000:
    print(f'  libritts model missing/partial — downloading (~200 MB)')
    # !mkdir -p {PSG_DIR}/models
    # !wget -q --tries=5 --timeout=300 -O {PIPER_MODEL} {PIPER_MODEL_URL}
assert os.path.getsize(PIPER_MODEL) > 100_000_000, f'libritts model only {os.path.getsize(PIPER_MODEL)} bytes — download failed'
print(f'  ✓ libritts model: {os.path.getsize(PIPER_MODEL)/1e6:.0f} MB')

# ── openwakeword (master) ───────────────────────────────────────────────
OWW_DIR = '/content/openwakeword'
OWW_TRAIN = f'{OWW_DIR}/openwakeword/train.py'
if not os.path.exists(OWW_TRAIN):
    print('  openwakeword missing or gutted — re-cloning')
    # !rm -rf {OWW_DIR}
    # !git clone -q https://github.com/dscripka/openwakeword {OWW_DIR}
    # !pip install -q -e {OWW_DIR}
assert os.path.exists(OWW_TRAIN), 'openwakeword train.py missing after clone'
print(f'  ✓ openwakeword: {OWW_TRAIN} ({os.path.getsize(OWW_TRAIN)/1e3:.0f} KB)')

# ── Make sure openwakeword's PARENT dir is on sys.path so the package
# resolves correctly. /content is also on sys.path by default in Colab,
# which would resolve `import openwakeword` to /content/openwakeword/
# (the editable-install ROOT, no __init__.py) instead of the package
# at /content/openwakeword/openwakeword/. That would treat openwakeword
# as a namespace package and submodule imports (.data, .utils) would fail.
if OWW_DIR not in sys.path:
    sys.path.insert(0, OWW_DIR)
# Wipe any stale namespace-package state in sys.modules
for _m in list(sys.modules):
    if _m.startswith('openwakeword'):
        del sys.modules[_m]
import openwakeword
assert openwakeword.__file__ is not None, (
    f'openwakeword still loaded as namespace package — '
    f'__file__ is None, __path__={openwakeword.__path__}. '
    f'Check sys.path for stray /content entries.'
)
print(f'  ✓ openwakeword importable: {openwakeword.__file__}')

# %% [markdown]
# ## 3. Apply runtime patches (idempotent)
#
# Six patches. Each is a string check + targeted modification — re-running this cell after a partial install reapplies cleanly without double-patching.

# %%
import os, glob

# Patch A: torch_audiomentations 0.11 calls torchaudio.set_audio_backend
# which torchaudio 2.x removed. sed-replace the bad line with no-op.
for path in glob.glob('/usr/local/lib/python*/dist-packages/torch_audiomentations/utils/io.py'):
    # !sed -i 's|torchaudio.set_audio_backend("soundfile")|pass  # patched|' "{path}"
    print(f'  Patch A (set_audio_backend): {path}')

# Patch B: copy generate_samples.py into openwakeword's package dir.
src = '/content/piper-sample-generator/generate_samples.py'
dst = '/content/openwakeword/openwakeword/generate_samples.py'
assert os.path.exists(src), 'piper-sample-generator/generate_samples.py missing — cell 2 failed'
if (not os.path.exists(dst)) or os.path.getsize(dst) != os.path.getsize(src):
    # !cp "{src}" "{dst}"
print(f'  Patch B (generate_samples copy): {dst}')

# Patch C: HF Hub default 10s timeouts → 120s
os.environ['HF_HUB_ETAG_TIMEOUT'] = '120'
os.environ['HF_HUB_DOWNLOAD_TIMEOUT'] = '120'
import huggingface_hub.constants as hfc
for attr in ['DEFAULT_ETAG_TIMEOUT', 'DEFAULT_DOWNLOAD_TIMEOUT',
             'HF_HUB_ETAG_TIMEOUT', 'HF_HUB_DOWNLOAD_TIMEOUT']:
    if hasattr(hfc, attr): setattr(hfc, attr, 120)
print('  Patch C (HF Hub timeouts → 120s)')

# Patch D: torchaudio.info shim (removed in torchaudio 2.x)
import torchaudio
init_path = torchaudio.__file__
SHIM_MARKER = '# ── PATCH: info() shim for torchaudio 2.x ──'
with open(init_path) as f:
    content = f.read()
if SHIM_MARKER not in content:
    shim = (f'\n\n{SHIM_MARKER}\n'
            'def info(file_path, *args, **kwargs):\n'
            '    import soundfile as _sf\n'
            '    si = _sf.info(str(file_path))\n'
            '    return type("_TorchaudioInfo", (), {\n'
            '        "num_frames": si.frames, "sample_rate": si.samplerate,\n'
            '        "num_channels": si.channels, "bits_per_sample": 16,\n'
            '        "encoding": "PCM_S",\n'
            '    })()\n')
    with open(init_path, 'a') as f: f.write(shim)
    import importlib; importlib.reload(torchaudio)
print(f'  Patch D (torchaudio.info shim): {hasattr(torchaudio, "info")}')

# Patch E: openwakeword's generate_samples requires `model` arg but train.py
# doesn't pass it — default to the libritts model we already downloaded.
TARGET = '/content/piper-sample-generator/generate_samples.py'
# !sed -i 's|model: Union\[str, Path\],|model: Union[str, Path] = "/content/piper-sample-generator/models/en_US-libritts_r-medium.pt",|' "{TARGET}"
# !cp "{TARGET}" /content/openwakeword/openwakeword/generate_samples.py
print('  Patch E (generate_samples model arg default)')

# Patch F: train.py val dtype cast (line ~519 + ~547)
TRAIN_PY = '/content/openwakeword/openwakeword/train.py'
# !sed -i 's|val_predictions = self.model(x_val)$|val_predictions = self.model(x_val.float())|' "{TRAIN_PY}"
print('  Patch F (train.py val dtype cast)')

# Patch G: torch.load strict depuis torch 2.6+ (weights_only=True par défaut)
# casse le chargement des checkpoints .pt piper. Appliqué aux DEUX copies
# de generate_samples.py, sans dépendre de fr_enabled.
for p in ['/content/piper-sample-generator/generate_samples.py',
          '/content/openwakeword/openwakeword/generate_samples.py']:
    with open(p) as f:
        c = f.read()
    if 'torch.load(model_path, weights_only=False)' not in c:
        c = c.replace('torch.load(model_path)', 'torch.load(model_path, weights_only=False)')
        with open(p, 'w') as f:
            f.write(c)
        print(f'  Patch G (weights_only=False) appliqué: {p}')
    else:
        print(f'  Patch G déjà appliqué: {p}')

print()
print('All 7 patches applied (idempotent).')

# %% [markdown]
# ## 4. Pre-flight — every dep imports + every external file exists
#
# Hard-fails if anything's wrong. This is the gate before slow downloads start. Catches new failure modes future Colab updates introduce.

# %%
import os, importlib

# Files
expected = {
    'piper-sample-generator/generate_samples.py': '/content/piper-sample-generator/generate_samples.py',
    'openwakeword/generate_samples.py':            '/content/openwakeword/openwakeword/generate_samples.py',
    'libritts model':                              '/content/piper-sample-generator/models/en_US-libritts_r-medium.pt',
    'openwakeword/train.py':                       '/content/openwakeword/openwakeword/train.py',
    'openwakeword/data.py':                        '/content/openwakeword/openwakeword/data.py',
    'openwakeword/utils.py':                       '/content/openwakeword/openwakeword/utils.py',
}
missing_files = []
for name, p in expected.items():
    if os.path.exists(p):
        size = os.path.getsize(p)
        unit = 'MB' if size > 1e6 else 'KB'
        denom = 1e6 if unit == 'MB' else 1e3
        print(f'  ✓ {name}: {size/denom:.1f} {unit}')
    else:
        missing_files.append((name, p))
        print(f'  ✗ MISSING: {name} ({p})')

# Imports
missing_mods = []
for mod in ['torch', 'torchinfo', 'torchmetrics', 'scipy', 'numpy', 'tqdm',
            'yaml', 'mutagen', 'pronouncing', 'torchaudio', 'audiomentations',
            'torch_audiomentations', 'speechbrain', 'acoustics', 'onnx',
            'onnxruntime', 'soundfile', 'requests', 'huggingface_hub',
            'piper_phonemize', 'piper', 'openwakeword']:
    try:
        importlib.import_module(mod)
    except Exception as e:
        missing_mods.append((mod, str(e)))
        print(f'  ✗ IMPORT FAIL: {mod} ({type(e).__name__}: {e})')

# Dry-run openwakeword.data + utils — catches weird internal import bugs
try:
    from openwakeword.data import generate_adversarial_texts, augment_clips, mmap_batch_generator
    from openwakeword.utils import compute_features_from_generator, AudioFeatures
    print('  ✓ openwakeword.data + .utils dry-import OK')
except Exception as e:
    print(f'  ✗ openwakeword internal import: {type(e).__name__}: {e}')
    missing_mods.append(('openwakeword.data/utils', str(e)))

import torch
print(f'\n  CUDA: {torch.cuda.is_available()}, GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "-"}')
if missing_files or missing_mods:
    raise RuntimeError(f'Pre-flight failed — {len(missing_files)} missing files, {len(missing_mods)} import errors. Re-run cells 1-3.')
print('\n  Pre-flight PASSED. Safe to proceed with downloads + training.')

# %% [markdown]
# ## 5. Download openwakeword shared models (mel + embedding)
#
# Required by augment_clips' feature-extraction step. Idempotent — skips files already cached.

# %%
import os
models_dir = '/content/openwakeword/openwakeword/resources/models'
os.makedirs(models_dir, exist_ok=True)
BASE = 'https://github.com/dscripka/openWakeWord/releases/download/v0.5.1'
for fname in ['embedding_model.onnx', 'embedding_model.tflite',
              'melspectrogram.onnx', 'melspectrogram.tflite']:
    out = f'{models_dir}/{fname}'
    if os.path.exists(out) and os.path.getsize(out) > 1000:
        print(f'  cached: {fname} ({os.path.getsize(out)/1e3:.0f} KB)')
    else:
        # !wget -q --tries=5 --timeout=120 "{BASE}/{fname}" -O "{out}"
        print(f'  ✓ downloaded: {fname} ({os.path.getsize(out)/1e3:.0f} KB)')

# %% [markdown]
# ## 6. MIT impulse responses → 16-kHz WAVs (~1 min)
#
# Caches the HF dataset, then converts to WAV. Both halves idempotent.

# %%
import os, time, numpy as np
import scipy.io.wavfile as wavfile
from huggingface_hub import snapshot_download
import datasets

output_dir = '/content/mit_rirs'
os.makedirs(output_dir, exist_ok=True)
if len([f for f in os.listdir(output_dir) if f.endswith('.wav')]) >= 250:
    print(f'  cached: {len(os.listdir(output_dir))} MIT IR WAVs')
else:
    # Pre-cache via snapshot_download (more reliable than load_dataset's internal
    # 10s timeout on 270 file metadata calls).
    for i in range(6):
        try:
            snapshot_download(repo_id='davidscripka/MIT_environmental_impulse_responses',
                              repo_type='dataset', etag_timeout=120, max_workers=4)
            break
        except Exception as e:
            wait = 15 * (i+1)
            print(f'  snapshot_download attempt {i+1}/6: {type(e).__name__}: {str(e)[:80]} — sleep {wait}s')
            time.sleep(wait)
    # Load + convert
    for attempt in range(4):
        try:
            rir_dataset = datasets.load_dataset('davidscripka/MIT_environmental_impulse_responses',
                                                split='train', streaming=False)
            break
        except Exception as e:
            print(f'  load_dataset attempt {attempt+1}: {type(e).__name__}: {str(e)[:120]}')
            time.sleep(20 * (attempt + 1))
    else:
        raise RuntimeError('load_dataset failed for MIT IRs')
    n = 0
    for i, row in enumerate(rir_dataset):
        out = f'{output_dir}/{i:04d}.wav'
        if os.path.exists(out): continue
        audio = row['audio']
        sr = audio['sampling_rate']
        arr = np.asarray(audio['array'])
        if sr != 16000:
            from scipy.signal import resample_poly
            arr = resample_poly(arr, 16000, sr)
        arr = (arr * 32767).clip(-32768, 32767).astype(np.int16)
        wavfile.write(out, 16000, arr); n += 1
    print(f'  ✓ wrote {n} new WAVs (total {len(os.listdir(output_dir))})')

# %% [markdown]
# ## 7. Download FMA + ACAV features (~10-15 min)
#
# FMA = ~8 GB zip of MP3s for background-noise mixing. ACAV = ~17 GB .npy of pre-computed features (becomes negative training corpus). Both use stream + resume so a session restart picks up where it left off.

# %%
import os, requests, zipfile
from tqdm.auto import tqdm
os.chdir('/content')

# ── ACAV features (17 GB) ────────────────────────────────────────────────
ACAV_FULL = '/content/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
ACAV_URL = 'https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
if os.path.exists(ACAV_FULL) and os.path.getsize(ACAV_FULL) > 16_000_000_000:
    print(f'  cached: ACAV {os.path.getsize(ACAV_FULL)/1e9:.1f} GB')
else:
    resume_byte = os.path.getsize(ACAV_FULL) if os.path.exists(ACAV_FULL) else 0
    headers = {'Range': f'bytes={resume_byte}-'} if resume_byte else {}
    mode = 'ab' if resume_byte else 'wb'
    print(f'  ACAV: {"resuming from" if resume_byte else "fetching"} {resume_byte/1e9:.1f} GB')
    with requests.get(ACAV_URL, stream=True, headers=headers, timeout=120) as r:
        r.raise_for_status()
        total = int(r.headers.get('content-length', 0)) + resume_byte
        with open(ACAV_FULL, mode) as f, tqdm(total=total, initial=resume_byte,
                                              unit='B', unit_scale=True, unit_divisor=1024,
                                              desc='ACAV') as pbar:
            for chunk in r.iter_content(chunk_size=4*1024*1024):
                if chunk: f.write(chunk); pbar.update(len(chunk))
    print(f'  ✓ ACAV: {os.path.getsize(ACAV_FULL)/1e9:.1f} GB')

# ── FMA small (~8 GB zip) with resume + extract ────────────────────────
FMA_DIR = '/content/fma'
FMA_ZIP = '/content/fma_small.zip'
os.makedirs(FMA_DIR, exist_ok=True)
if os.path.isdir(FMA_DIR) and len(os.listdir(FMA_DIR)) > 100:
    print(f'  cached: FMA {len(os.listdir(FMA_DIR))} entries')
else:
    fma_url = 'https://os.unil.cloud.switch.ch/fma/fma_small.zip'
    resume_byte = os.path.getsize(FMA_ZIP) if os.path.exists(FMA_ZIP) else 0
    headers = {'Range': f'bytes={resume_byte}-'} if resume_byte else {}
    mode = 'ab' if resume_byte else 'wb'
    print(f'  FMA: {"resuming from" if resume_byte else "fetching"} {resume_byte/1e9:.1f} GB')
    with requests.get(fma_url, stream=True, headers=headers, timeout=120) as r:
        r.raise_for_status()
        total = int(r.headers.get('content-length', 0)) + resume_byte
        with open(FMA_ZIP, mode) as f, tqdm(total=total, initial=resume_byte,
                                            unit='B', unit_scale=True, unit_divisor=1024,
                                            desc='FMA') as pbar:
            for chunk in r.iter_content(chunk_size=4*1024*1024):
                if chunk: f.write(chunk); pbar.update(len(chunk))
    print(f'  extracting FMA...')
    with zipfile.ZipFile(FMA_ZIP) as zf:
        for name in tqdm(zf.namelist(), desc='extract', unit='f'):
            zf.extract(name, FMA_DIR)
    os.remove(FMA_ZIP)
    print(f'  ✓ FMA extracted: {len(os.listdir(FMA_DIR))} entries')
# Out:
#   ACAV: resuming from 15.2 GB
# ACAV:  88%|########7 | 14.1G/16.1G [00:00<?, ?B/s]
#   ✓ ACAV: 17.3 GB
#   FMA: fetching 0.0 GB
# FMA:   0%|          | 0.00/7.15G [00:00<?, ?B/s]
#   extracting FMA...
# extract:   0%|          | 0/8002 [00:00<?, ?f/s]
#   ✓ FMA extracted: 1 entries

# %% [markdown]
# ## 8. FMA MP3s → 16-kHz mono WAVs (~5 min)
#
# audiomentations needs WAV. 1500 conversions = plenty of background-noise variety.

# %%
import os, glob, subprocess
from tqdm.auto import tqdm
out_dir = '/content/fma_wav'
os.makedirs(out_dir, exist_ok=True)
n_existing = len(os.listdir(out_dir))
if n_existing >= 1500:
    print(f'  cached: {n_existing} FMA WAVs')
else:
    mp3s = glob.glob('/content/fma/**/*.mp3', recursive=True)
    if len(mp3s) < 100:
        raise RuntimeError(f'FMA download incomplete — only {len(mp3s)} MP3s found')
    existing = set(os.listdir(out_dir))
    n_target = min(1500, len(mp3s))
    to_convert = [(i, mp3s[i]) for i in range(n_target) if f'{i:05d}.wav' not in existing]
    print(f'  Converting {len(to_convert)} MP3s → 16kHz mono WAVs (skipping {n_target - len(to_convert)} cached)')
    for i, mp3 in tqdm(to_convert):
        out = f'{out_dir}/{i:05d}.wav'
        subprocess.run(['ffmpeg', '-y', '-loglevel', 'error', '-i', mp3,
                        '-ac', '1', '-ar', '16000', out], check=False)
    print(f'  ✓ {len(os.listdir(out_dir))} FMA WAVs ready')
# Out:
#   Converting 1500 MP3s → 16kHz mono WAVs (skipping 0 cached)
#   0%|          | 0/1500 [00:00<?, ?it/s]
#   ✓ 1500 FMA WAVs ready

# %% [markdown]
# ## 9. Subsample ACAV — 1.7 GB train + 170 MB val
#
# Full 17 GB would OOM training pass. **Validation slice stays as raw `(M, 96)`** — the hand-rolled trainer slides a 16-frame window over it itself.

# %%
import numpy as np, os
SRC = '/content/openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
TRAIN_DST = '/content/acav_train_subset.npy'
VAL_DST   = '/content/acav_val_subset.npy'
if os.path.exists(TRAIN_DST) and os.path.exists(VAL_DST):
    train_arr = np.load(TRAIN_DST, mmap_mode='r')
    val_arr = np.load(VAL_DST, mmap_mode='r')
    print(f'  cached: train={train_arr.shape} ({train_arr.nbytes/1e9:.2f} GB), val={val_arr.shape} ({val_arr.nbytes/1e6:.0f} MB)')
else:
    if not os.path.exists(SRC):
        raise RuntimeError(f'ACAV source missing: {SRC} — re-run cell 7')
    arr = np.load(SRC, mmap_mode='r')
    print(f'  source: {arr.shape}, dtype={arr.dtype}')
    n_total = len(arr)
    n_train = n_total // 10
    n_val_rows = n_total // 100
    print(f'  slicing: train=[:{n_train}] (3-D), val=[{n_train}:{n_train+n_val_rows}] (flattened to 2-D)')
    train_chunk = np.array(arr[:n_train])
    np.save(TRAIN_DST, train_chunk)
    print(f'  ✓ train: {train_chunk.shape} ({train_chunk.nbytes/1e9:.2f} GB)')
    del train_chunk
    val_chunk = np.array(arr[n_train:n_train+n_val_rows])
    val_flat = val_chunk.reshape(-1, val_chunk.shape[-1])
    np.save(VAL_DST, val_flat)
    print(f'  ✓ val: {val_flat.shape} ({val_flat.nbytes/1e6:.0f} MB)')
    del val_chunk, val_flat
    os.remove(SRC)
    print('  removed 17 GB original')
# Out:
#   source: (5625000, 16, 96), dtype=float16
#   slicing: train=[:562500] (3-D), val=[562500:618750] (flattened to 2-D)
#   ✓ train: (562500, 16, 96) (1.73 GB)
#   ✓ val: (900000, 96) (173 MB)
#   removed 17 GB original

# %% [markdown]
# ## 10. Build training config (no example-yaml dependency)
#
# Self-contained — every field set explicitly. Doesn't depend on upstream's `examples/` directory which has been renamed/removed across openwakeword versions.

# %%
import yaml, os

TARGET_PHRASE = ['hey vicky', 'okay vicky']
MODEL_NAME    = 'hey_vicky_v2'

FR_ENABLED              = True
FR_TARGET_PHRASES       = ['hé vicky', 'ok vicky', 'dis vicky']
FR_NEGATIVE_PHRASES     = [
    'hey mickey', 'et vicky', 'ok mickey', 'hey nicky',
    'dis whisky', 'ok whisky', 'hey ricky',
    'dis-moi', 'ok google', 'hey siri', 'dis donc',
    'ok alors', 'hey toi',
]
FR_PIPER_MODEL            = '/content/piper-sample-generator/models/fr_FR-mls-medium.pt'
FR_SAMPLES_PER_PHRASE     = 1300
FR_NEG_SAMPLES_PER_PHRASE = 300
FR_TRAIN_SPLIT            = 0.8

config = {
    'target_phrase':   TARGET_PHRASE,
    'model_name':      MODEL_NAME,
    'custom_negative_phrases': [],
    'n_samples':       3200,
    'n_samples_val':   650,
    'tts_batch_size':  50,
    'piper_sample_generator_path': '/content/piper-sample-generator',
    'augmentation_rounds':    1,
    'augmentation_batch_size': 16,
    'steps':           10000,
    'max_negative_weight': 3000,
    'target_accuracy': 0.7,
    'target_recall':   0.5,
    'target_false_positives_per_hour': 0.5,
    'batch_size':      128,
    'learning_rate':   1e-4,
    'model_type':      'dnn',
    'layer_dim':       128,
    'layer_size':      128,
    'n_blocks':        1,
    'model_input_shape': [16, 96],
    'n_classes':       1,
    'batch_n_per_class': {
        'ACAV100M_sample':       1024,
        'adversarial_negative':    50,
        'positive':                50,
    },
    'background_paths': ['/content/fma_wav'],
    'background_paths_duplication_rate': [1],
    'rir_paths':        ['/content/mit_rirs'],
    'false_positive_validation_data_path': '/content/acav_val_subset.npy',
    'feature_data_files': {'ACAV100M_sample': '/content/acav_train_subset.npy'},
    'output_dir':       f'/content/{MODEL_NAME}_output',
    'tflite_export':    False,
    'onnx_export':      True,
    'positive_clips_train_dir': f'/content/{MODEL_NAME}_output/{MODEL_NAME}/positive_train',
    'positive_clips_test_dir':  f'/content/{MODEL_NAME}_output/{MODEL_NAME}/positive_test',
    'negative_clips_train_dir': f'/content/{MODEL_NAME}_output/{MODEL_NAME}/negative_train',
    'negative_clips_test_dir':  f'/content/{MODEL_NAME}_output/{MODEL_NAME}/negative_test',
    'feature_save_dir':         f'/content/{MODEL_NAME}_output/{MODEL_NAME}',

    'fr_enabled':              FR_ENABLED,
    'fr_target_phrases':       FR_TARGET_PHRASES,
    'fr_negative_phrases':     FR_NEGATIVE_PHRASES,
    'fr_piper_model':          FR_PIPER_MODEL,
    'fr_samples_per_phrase':     FR_SAMPLES_PER_PHRASE,
    'fr_neg_samples_per_phrase': FR_NEG_SAMPLES_PER_PHRASE,
    'fr_train_split':          FR_TRAIN_SPLIT,
}
os.makedirs(config['output_dir'], exist_ok=True)
with open('/content/my_model.yaml', 'w') as f:
    yaml.dump(config, f, sort_keys=False)
print(f'  target_phrase (EN): {config["target_phrase"]}')
print(f'  model_name:         {config["model_name"]}')
print(f'  fr_enabled:         {config["fr_enabled"]}')
if config['fr_enabled']:
    print(f'  fr_target_phrases:   {config["fr_target_phrases"]} ({config["fr_samples_per_phrase"]} clips/phrase)')
    print(f'  fr_negative_phrases: {len(config["fr_negative_phrases"])} phrases ({config["fr_neg_samples_per_phrase"]} clips/phrase)')
# Out:
#   target_phrase (EN): ['hey vicky', 'okay vicky']
#   model_name:         hey_vicky_v2
#   fr_enabled:         True
#   fr_target_phrases:   ['hé vicky', 'ok vicky', 'dis vicky'] (1300 clips/phrase)
#   fr_negative_phrases: 13 phrases (300 clips/phrase)

# %%
import shutil, glob, yaml
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)

# Dossiers EN
for d in [cfg['positive_clips_train_dir'], cfg['positive_clips_test_dir'],
          cfg['negative_clips_train_dir'], cfg['negative_clips_test_dir']]:
    shutil.rmtree(d, ignore_errors=True)

# Dossiers FR bruts (générés par 11bis avant fusion)
for phrase in cfg['fr_target_phrases']:
    shutil.rmtree(f"/content/fr_pos_{phrase.replace(' ', '_')}", ignore_errors=True)
for phrase in cfg['fr_negative_phrases']:
    shutil.rmtree(f"/content/fr_neg_{phrase.replace(' ', '_').replace('-', '_')}", ignore_errors=True)

# Cache de features (sinon 13 les considère déjà prêtes et ne régénère rien)
for f in glob.glob(f"{cfg['feature_save_dir']}/*.npy"):
    os.remove(f)

print('  tous les caches (EN, FR, features) vidés — prêt pour régénération à pleine échelle')
# Out:
#   tous les caches (EN, FR, features) vidés — prêt pour régénération à pleine échelle

# %% [markdown]
# ## 11. Generate Piper TTS clips (~10-15 min)
#
# Uses openwakeword's --generate_clips runner which reads from my_model.yaml. Idempotent — re-running finds existing clips and skips.

# %%
import shutil, yaml
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
for d in [cfg['positive_clips_train_dir'], cfg['positive_clips_test_dir'],
          cfg['negative_clips_train_dir'], cfg['negative_clips_test_dir']]:
    shutil.rmtree(d, ignore_errors=True)
print('  dossiers EN vidés')
# Out:
#   dossiers EN vidés

# %%
import sys, os, yaml
os.environ['PYTHONPATH'] = '/content/openwakeword:' + os.environ.get('PYTHONPATH', '')

with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
dirs = {
    'positive_train': (cfg['positive_clips_train_dir'], int(cfg['n_samples'] * 0.75)),
    'positive_test':  (cfg['positive_clips_test_dir'],  int(cfg['n_samples_val'] * 0.75)),
    'negative_train': (cfg['negative_clips_train_dir'], int(cfg['n_samples'] * 0.75)),
    'negative_test':  (cfg['negative_clips_test_dir'],  int(cfg['n_samples_val'] * 0.75)),
}
status = []
for name, (path, expected) in dirs.items():
    n = len(os.listdir(path)) if os.path.isdir(path) else 0
    status.append((name, n, expected, n >= expected))
all_full = all(ok for _, _, _, ok in status)
for name, n, expected, ok in status:
    print(f'  {"PASS" if ok else "MISS"} {name}: {n} clips (expect >={expected})')
if all_full:
    print('\n  cached: all 4 clip dirs already populated')
else:
    print('\n  -> running generate_clips (upstream skips cached dirs internally)')
    # !{sys.executable} /content/openwakeword/openwakeword/train.py \
        --training_config /content/my_model.yaml \
        --generate_clips
    for name, (path, expected) in dirs.items():
        n = len(os.listdir(path)) if os.path.isdir(path) else 0
        assert n >= expected, f'generate_clips left {name} with only {n} clips (expected >={expected})'
    print('\n  PASS all 4 clip dirs now populated')
# Out:
#   MISS positive_train: 0 clips (expect >=2400)
#   MISS positive_test: 0 clips (expect >=487)
#   MISS negative_train: 0 clips (expect >=2400)
#   MISS negative_test: 0 clips (expect >=487)
#
#   -> running generate_clips (upstream skips cached dirs internally)
# INFO:root:##################################################
# Generating positive clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/64 complete
# DEBUG:generate_samples:Batch 2/64 complete
# DEBUG:generate_samples:Batch 3/64 complete
# DEBUG:generate_samples:Batch 4/64 complete
# DEBUG:generate_samples:Batch 5/64 complete
# DEBUG:generate_samples:Batch 6/64 complete
# DEBUG:generate_samples:Batch 7/64 complete
# DEBUG:generate_samples:Batch 8/64 complete
# DEBUG:generate_samples:Batch 9/64 complete
# DEBUG:generate_samples:Batch 10/64 complete
# DEBUG:generate_samples:Batch 11/64 complete
# DEBUG:generate_samples:Batch 12/64 complete
# DEBUG:generate_samples:Batch 13/64 complete
# DEBUG:generate_samples:Batch 14/64 complete
# DEBUG:generate_samples:Batch 15/64 complete
# DEBUG:generate_samples:Batch 16/64 complete
# DEBUG:generate_samples:Batch 17/64 complete
# DEBUG:generate_samples:Batch 18/64 complete
# DEBUG:generate_samples:Batch 19/64 complete
# DEBUG:generate_samples:Batch 20/64 complete
# DEBUG:generate_samples:Batch 21/64 complete
# DEBUG:generate_samples:Batch 22/64 complete
# DEBUG:generate_samples:Batch 23/64 complete
# DEBUG:generate_samples:Batch 24/64 complete
# DEBUG:generate_samples:Batch 25/64 complete
# DEBUG:generate_samples:Batch 26/64 complete
# DEBUG:generate_samples:Batch 27/64 complete
# DEBUG:generate_samples:Batch 28/64 complete
# DEBUG:generate_samples:Batch 29/64 complete
# DEBUG:generate_samples:Batch 30/64 complete
# DEBUG:generate_samples:Batch 31/64 complete
# DEBUG:generate_samples:Batch 32/64 complete
# DEBUG:generate_samples:Batch 33/64 complete
# DEBUG:generate_samples:Batch 34/64 complete
# DEBUG:generate_samples:Batch 35/64 complete
# DEBUG:generate_samples:Batch 36/64 complete
# DEBUG:generate_samples:Batch 37/64 complete
# DEBUG:generate_samples:Batch 38/64 complete
# DEBUG:generate_samples:Batch 39/64 complete
# DEBUG:generate_samples:Batch 40/64 complete
# DEBUG:generate_samples:Batch 41/64 complete
# DEBUG:generate_samples:Batch 42/64 complete
# DEBUG:generate_samples:Batch 43/64 complete
# DEBUG:generate_samples:Batch 44/64 complete
# DEBUG:generate_samples:Batch 45/64 complete
# DEBUG:generate_samples:Batch 46/64 complete
# DEBUG:generate_samples:Batch 47/64 complete
# DEBUG:generate_samples:Batch 48/64 complete
# DEBUG:generate_samples:Batch 49/64 complete
# DEBUG:generate_samples:Batch 50/64 complete
# DEBUG:generate_samples:Batch 51/64 complete
# DEBUG:generate_samples:Batch 52/64 complete
# DEBUG:generate_samples:Batch 53/64 complete
# DEBUG:generate_samples:Batch 54/64 complete
# DEBUG:generate_samples:Batch 55/64 complete
# DEBUG:generate_samples:Batch 56/64 complete
# DEBUG:generate_samples:Batch 57/64 complete
# DEBUG:generate_samples:Batch 58/64 complete
# DEBUG:generate_samples:Batch 59/64 complete
# DEBUG:generate_samples:Batch 60/64 complete
# DEBUG:generate_samples:Batch 61/64 complete
# DEBUG:generate_samples:Batch 62/64 complete
# DEBUG:generate_samples:Batch 63/64 complete
# DEBUG:generate_samples:Batch 64/64 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating positive clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/13 complete
# DEBUG:generate_samples:Batch 2/13 complete
# DEBUG:generate_samples:Batch 3/13 complete
# DEBUG:generate_samples:Batch 4/13 complete
# DEBUG:generate_samples:Batch 5/13 complete
# DEBUG:generate_samples:Batch 6/13 complete
# DEBUG:generate_samples:Batch 7/13 complete
# DEBUG:generate_samples:Batch 8/13 complete
# DEBUG:generate_samples:Batch 9/13 complete
# DEBUG:generate_samples:Batch 10/13 complete
# DEBUG:generate_samples:Batch 11/13 complete
# DEBUG:generate_samples:Batch 12/13 complete
# DEBUG:generate_samples:Batch 13/13 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/457 complete
# DEBUG:generate_samples:Batch 2/457 complete
# DEBUG:generate_samples:Batch 3/457 complete
# DEBUG:generate_samples:Batch 4/457 complete
# DEBUG:generate_samples:Batch 5/457 complete
# DEBUG:generate_samples:Batch 6/457 complete
# DEBUG:generate_samples:Batch 7/457 complete
# DEBUG:generate_samples:Batch 8/457 complete
# DEBUG:generate_samples:Batch 9/457 complete
# DEBUG:generate_samples:Batch 10/457 complete
# DEBUG:generate_samples:Batch 11/457 complete
# DEBUG:generate_samples:Batch 12/457 complete
# DEBUG:generate_samples:Batch 13/457 complete
# DEBUG:generate_samples:Batch 14/457 complete
# DEBUG:generate_samples:Batch 15/457 complete
# DEBUG:generate_samples:Batch 16/457 complete
# DEBUG:generate_samples:Batch 17/457 complete
# DEBUG:generate_samples:Batch 18/457 complete
# DEBUG:generate_samples:Batch 19/457 complete
# DEBUG:generate_samples:Batch 20/457 complete
# DEBUG:generate_samples:Batch 21/457 complete
# DEBUG:generate_samples:Batch 22/457 complete
# DEBUG:generate_samples:Batch 23/457 complete
# DEBUG:generate_samples:Batch 24/457 complete
# DEBUG:generate_samples:Batch 25/457 complete
# DEBUG:generate_samples:Batch 26/457 complete
# DEBUG:generate_samples:Batch 27/457 complete
# DEBUG:generate_samples:Batch 28/457 complete
# DEBUG:generate_samples:Batch 29/457 complete
# DEBUG:generate_samples:Batch 30/457 complete
# DEBUG:generate_samples:Batch 31/457 complete
# DEBUG:generate_samples:Batch 32/457 complete
# DEBUG:generate_samples:Batch 33/457 complete
# DEBUG:generate_samples:Batch 34/457 complete
# DEBUG:generate_samples:Batch 35/457 complete
# DEBUG:generate_samples:Batch 36/457 complete
# DEBUG:generate_samples:Batch 37/457 complete
# DEBUG:generate_samples:Batch 38/457 complete
# DEBUG:generate_samples:Batch 39/457 complete
# DEBUG:generate_samples:Batch 40/457 complete
# DEBUG:generate_samples:Batch 41/457 complete
# DEBUG:generate_samples:Batch 42/457 complete
# DEBUG:generate_samples:Batch 43/457 complete
# DEBUG:generate_samples:Batch 44/457 complete
# DEBUG:generate_samples:Batch 45/457 complete
# DEBUG:generate_samples:Batch 46/457 complete
# DEBUG:generate_samples:Batch 47/457 complete
# DEBUG:generate_samples:Batch 48/457 complete
# DEBUG:generate_samples:Batch 49/457 complete
# DEBUG:generate_samples:Batch 50/457 complete
# DEBUG:generate_samples:Batch 51/457 complete
# DEBUG:generate_samples:Batch 52/457 complete
# DEBUG:generate_samples:Batch 53/457 complete
# DEBUG:generate_samples:Batch 54/457 complete
# DEBUG:generate_samples:Batch 55/457 complete
# DEBUG:generate_samples:Batch 56/457 complete
# DEBUG:generate_samples:Batch 57/457 complete
# DEBUG:generate_samples:Batch 58/457 complete
# DEBUG:generate_samples:Batch 59/457 complete
# DEBUG:generate_samples:Batch 60/457 complete
# DEBUG:generate_samples:Batch 61/457 complete
# DEBUG:generate_samples:Batch 62/457 complete
# DEBUG:generate_samples:Batch 63/457 complete
# DEBUG:generate_samples:Batch 64/457 complete
# DEBUG:generate_samples:Batch 65/457 complete
# DEBUG:generate_samples:Batch 66/457 complete
# DEBUG:generate_samples:Batch 67/457 complete
# DEBUG:generate_samples:Batch 68/457 complete
# DEBUG:generate_samples:Batch 69/457 complete
# DEBUG:generate_samples:Batch 70/457 complete
# DEBUG:generate_samples:Batch 71/457 complete
# DEBUG:generate_samples:Batch 72/457 complete
# DEBUG:generate_samples:Batch 73/457 complete
# DEBUG:generate_samples:Batch 74/457 complete
# DEBUG:generate_samples:Batch 75/457 complete
# DEBUG:generate_samples:Batch 76/457 complete
# DEBUG:generate_samples:Batch 77/457 complete
# DEBUG:generate_samples:Batch 78/457 complete
# DEBUG:generate_samples:Batch 79/457 complete
# DEBUG:generate_samples:Batch 80/457 complete
# DEBUG:generate_samples:Batch 81/457 complete
# DEBUG:generate_samples:Batch 82/457 complete
# DEBUG:generate_samples:Batch 83/457 complete
# DEBUG:generate_samples:Batch 84/457 complete
# DEBUG:generate_samples:Batch 85/457 complete
# DEBUG:generate_samples:Batch 86/457 complete
# DEBUG:generate_samples:Batch 87/457 complete
# DEBUG:generate_samples:Batch 88/457 complete
# DEBUG:generate_samples:Batch 89/457 complete
# DEBUG:generate_samples:Batch 90/457 complete
# DEBUG:generate_samples:Batch 91/457 complete
# DEBUG:generate_samples:Batch 92/457 complete
# DEBUG:generate_samples:Batch 93/457 complete
# DEBUG:generate_samples:Batch 94/457 complete
# DEBUG:generate_samples:Batch 95/457 complete
# DEBUG:generate_samples:Batch 96/457 complete
# DEBUG:generate_samples:Batch 97/457 complete
# DEBUG:generate_samples:Batch 98/457 complete
# DEBUG:generate_samples:Batch 99/457 complete
# DEBUG:generate_samples:Batch 100/457 complete
# DEBUG:generate_samples:Batch 101/457 complete
# DEBUG:generate_samples:Batch 102/457 complete
# DEBUG:generate_samples:Batch 103/457 complete
# DEBUG:generate_samples:Batch 104/457 complete
# DEBUG:generate_samples:Batch 105/457 complete
# DEBUG:generate_samples:Batch 106/457 complete
# DEBUG:generate_samples:Batch 107/457 complete
# DEBUG:generate_samples:Batch 108/457 complete
# DEBUG:generate_samples:Batch 109/457 complete
# DEBUG:generate_samples:Batch 110/457 complete
# DEBUG:generate_samples:Batch 111/457 complete
# DEBUG:generate_samples:Batch 112/457 complete
# DEBUG:generate_samples:Batch 113/457 complete
# DEBUG:generate_samples:Batch 114/457 complete
# DEBUG:generate_samples:Batch 115/457 complete
# DEBUG:generate_samples:Batch 116/457 complete
# DEBUG:generate_samples:Batch 117/457 complete
# DEBUG:generate_samples:Batch 118/457 complete
# DEBUG:generate_samples:Batch 119/457 complete
# DEBUG:generate_samples:Batch 120/457 complete
# DEBUG:generate_samples:Batch 121/457 complete
# DEBUG:generate_samples:Batch 122/457 complete
# DEBUG:generate_samples:Batch 123/457 complete
# DEBUG:generate_samples:Batch 124/457 complete
# DEBUG:generate_samples:Batch 125/457 complete
# DEBUG:generate_samples:Batch 126/457 complete
# DEBUG:generate_samples:Batch 127/457 complete
# DEBUG:generate_samples:Batch 128/457 complete
# DEBUG:generate_samples:Batch 129/457 complete
# DEBUG:generate_samples:Batch 130/457 complete
# DEBUG:generate_samples:Batch 131/457 complete
# DEBUG:generate_samples:Batch 132/457 complete
# DEBUG:generate_samples:Batch 133/457 complete
# DEBUG:generate_samples:Batch 134/457 complete
# DEBUG:generate_samples:Batch 135/457 complete
# DEBUG:generate_samples:Batch 136/457 complete
# DEBUG:generate_samples:Batch 137/457 complete
# DEBUG:generate_samples:Batch 138/457 complete
# DEBUG:generate_samples:Batch 139/457 complete
# DEBUG:generate_samples:Batch 140/457 complete
# DEBUG:generate_samples:Batch 141/457 complete
# DEBUG:generate_samples:Batch 142/457 complete
# DEBUG:generate_samples:Batch 143/457 complete
# DEBUG:generate_samples:Batch 144/457 complete
# DEBUG:generate_samples:Batch 145/457 complete
# DEBUG:generate_samples:Batch 146/457 complete
# DEBUG:generate_samples:Batch 147/457 complete
# DEBUG:generate_samples:Batch 148/457 complete
# DEBUG:generate_samples:Batch 149/457 complete
# DEBUG:generate_samples:Batch 150/457 complete
# DEBUG:generate_samples:Batch 151/457 complete
# DEBUG:generate_samples:Batch 152/457 complete
# DEBUG:generate_samples:Batch 153/457 complete
# DEBUG:generate_samples:Batch 154/457 complete
# DEBUG:generate_samples:Batch 155/457 complete
# DEBUG:generate_samples:Batch 156/457 complete
# DEBUG:generate_samples:Batch 157/457 complete
# DEBUG:generate_samples:Batch 158/457 complete
# DEBUG:generate_samples:Batch 159/457 complete
# DEBUG:generate_samples:Batch 160/457 complete
# DEBUG:generate_samples:Batch 161/457 complete
# DEBUG:generate_samples:Batch 162/457 complete
# DEBUG:generate_samples:Batch 163/457 complete
# DEBUG:generate_samples:Batch 164/457 complete
# DEBUG:generate_samples:Batch 165/457 complete
# DEBUG:generate_samples:Batch 166/457 complete
# DEBUG:generate_samples:Batch 167/457 complete
# DEBUG:generate_samples:Batch 168/457 complete
# DEBUG:generate_samples:Batch 169/457 complete
# DEBUG:generate_samples:Batch 170/457 complete
# DEBUG:generate_samples:Batch 171/457 complete
# DEBUG:generate_samples:Batch 172/457 complete
# DEBUG:generate_samples:Batch 173/457 complete
# DEBUG:generate_samples:Batch 174/457 complete
# DEBUG:generate_samples:Batch 175/457 complete
# DEBUG:generate_samples:Batch 176/457 complete
# DEBUG:generate_samples:Batch 177/457 complete
# DEBUG:generate_samples:Batch 178/457 complete
# DEBUG:generate_samples:Batch 179/457 complete
# DEBUG:generate_samples:Batch 180/457 complete
# DEBUG:generate_samples:Batch 181/457 complete
# DEBUG:generate_samples:Batch 182/457 complete
# DEBUG:generate_samples:Batch 183/457 complete
# DEBUG:generate_samples:Batch 184/457 complete
# DEBUG:generate_samples:Batch 185/457 complete
# DEBUG:generate_samples:Batch 186/457 complete
# DEBUG:generate_samples:Batch 187/457 complete
# DEBUG:generate_samples:Batch 188/457 complete
# DEBUG:generate_samples:Batch 189/457 complete
# DEBUG:generate_samples:Batch 190/457 complete
# DEBUG:generate_samples:Batch 191/457 complete
# DEBUG:generate_samples:Batch 192/457 complete
# DEBUG:generate_samples:Batch 193/457 complete
# DEBUG:generate_samples:Batch 194/457 complete
# DEBUG:generate_samples:Batch 195/457 complete
# DEBUG:generate_samples:Batch 196/457 complete
# DEBUG:generate_samples:Batch 197/457 complete
# DEBUG:generate_samples:Batch 198/457 complete
# DEBUG:generate_samples:Batch 199/457 complete
# DEBUG:generate_samples:Batch 200/457 complete
# DEBUG:generate_samples:Batch 201/457 complete
# DEBUG:generate_samples:Batch 202/457 complete
# DEBUG:generate_samples:Batch 203/457 complete
# DEBUG:generate_samples:Batch 204/457 complete
# DEBUG:generate_samples:Batch 205/457 complete
# DEBUG:generate_samples:Batch 206/457 complete
# DEBUG:generate_samples:Batch 207/457 complete
# DEBUG:generate_samples:Batch 208/457 complete
# DEBUG:generate_samples:Batch 209/457 complete
# DEBUG:generate_samples:Batch 210/457 complete
# DEBUG:generate_samples:Batch 211/457 complete
# DEBUG:generate_samples:Batch 212/457 complete
# DEBUG:generate_samples:Batch 213/457 complete
# DEBUG:generate_samples:Batch 214/457 complete
# DEBUG:generate_samples:Batch 215/457 complete
# DEBUG:generate_samples:Batch 216/457 complete
# DEBUG:generate_samples:Batch 217/457 complete
# DEBUG:generate_samples:Batch 218/457 complete
# DEBUG:generate_samples:Batch 219/457 complete
# DEBUG:generate_samples:Batch 220/457 complete
# DEBUG:generate_samples:Batch 221/457 complete
# DEBUG:generate_samples:Batch 222/457 complete
# DEBUG:generate_samples:Batch 223/457 complete
# DEBUG:generate_samples:Batch 224/457 complete
# DEBUG:generate_samples:Batch 225/457 complete
# DEBUG:generate_samples:Batch 226/457 complete
# DEBUG:generate_samples:Batch 227/457 complete
# DEBUG:generate_samples:Batch 228/457 complete
# DEBUG:generate_samples:Batch 229/457 complete
# DEBUG:generate_samples:Batch 230/457 complete
# DEBUG:generate_samples:Batch 231/457 complete
# DEBUG:generate_samples:Batch 232/457 complete
# DEBUG:generate_samples:Batch 233/457 complete
# DEBUG:generate_samples:Batch 234/457 complete
# DEBUG:generate_samples:Batch 235/457 complete
# DEBUG:generate_samples:Batch 236/457 complete
# DEBUG:generate_samples:Batch 237/457 complete
# DEBUG:generate_samples:Batch 238/457 complete
# DEBUG:generate_samples:Batch 239/457 complete
# DEBUG:generate_samples:Batch 240/457 complete
# DEBUG:generate_samples:Batch 241/457 complete
# DEBUG:generate_samples:Batch 242/457 complete
# DEBUG:generate_samples:Batch 243/457 complete
# DEBUG:generate_samples:Batch 244/457 complete
# DEBUG:generate_samples:Batch 245/457 complete
# DEBUG:generate_samples:Batch 246/457 complete
# DEBUG:generate_samples:Batch 247/457 complete
# DEBUG:generate_samples:Batch 248/457 complete
# DEBUG:generate_samples:Batch 249/457 complete
# DEBUG:generate_samples:Batch 250/457 complete
# DEBUG:generate_samples:Batch 251/457 complete
# DEBUG:generate_samples:Batch 252/457 complete
# DEBUG:generate_samples:Batch 253/457 complete
# DEBUG:generate_samples:Batch 254/457 complete
# DEBUG:generate_samples:Batch 255/457 complete
# DEBUG:generate_samples:Batch 256/457 complete
# DEBUG:generate_samples:Batch 257/457 complete
# DEBUG:generate_samples:Batch 258/457 complete
# DEBUG:generate_samples:Batch 259/457 complete
# DEBUG:generate_samples:Batch 260/457 complete
# DEBUG:generate_samples:Batch 261/457 complete
# DEBUG:generate_samples:Batch 262/457 complete
# DEBUG:generate_samples:Batch 263/457 complete
# DEBUG:generate_samples:Batch 264/457 complete
# DEBUG:generate_samples:Batch 265/457 complete
# DEBUG:generate_samples:Batch 266/457 complete
# DEBUG:generate_samples:Batch 267/457 complete
# DEBUG:generate_samples:Batch 268/457 complete
# DEBUG:generate_samples:Batch 269/457 complete
# DEBUG:generate_samples:Batch 270/457 complete
# DEBUG:generate_samples:Batch 271/457 complete
# DEBUG:generate_samples:Batch 272/457 complete
# DEBUG:generate_samples:Batch 273/457 complete
# DEBUG:generate_samples:Batch 274/457 complete
# DEBUG:generate_samples:Batch 275/457 complete
# DEBUG:generate_samples:Batch 276/457 complete
# DEBUG:generate_samples:Batch 277/457 complete
# DEBUG:generate_samples:Batch 278/457 complete
# DEBUG:generate_samples:Batch 279/457 complete
# DEBUG:generate_samples:Batch 280/457 complete
# DEBUG:generate_samples:Batch 281/457 complete
# DEBUG:generate_samples:Batch 282/457 complete
# DEBUG:generate_samples:Batch 283/457 complete
# DEBUG:generate_samples:Batch 284/457 complete
# DEBUG:generate_samples:Batch 285/457 complete
# DEBUG:generate_samples:Batch 286/457 complete
# DEBUG:generate_samples:Batch 287/457 complete
# DEBUG:generate_samples:Batch 288/457 complete
# DEBUG:generate_samples:Batch 289/457 complete
# DEBUG:generate_samples:Batch 290/457 complete
# DEBUG:generate_samples:Batch 291/457 complete
# DEBUG:generate_samples:Batch 292/457 complete
# DEBUG:generate_samples:Batch 293/457 complete
# DEBUG:generate_samples:Batch 294/457 complete
# DEBUG:generate_samples:Batch 295/457 complete
# DEBUG:generate_samples:Batch 296/457 complete
# DEBUG:generate_samples:Batch 297/457 complete
# DEBUG:generate_samples:Batch 298/457 complete
# DEBUG:generate_samples:Batch 299/457 complete
# DEBUG:generate_samples:Batch 300/457 complete
# DEBUG:generate_samples:Batch 301/457 complete
# DEBUG:generate_samples:Batch 302/457 complete
# DEBUG:generate_samples:Batch 303/457 complete
# DEBUG:generate_samples:Batch 304/457 complete
# DEBUG:generate_samples:Batch 305/457 complete
# DEBUG:generate_samples:Batch 306/457 complete
# DEBUG:generate_samples:Batch 307/457 complete
# DEBUG:generate_samples:Batch 308/457 complete
# DEBUG:generate_samples:Batch 309/457 complete
# DEBUG:generate_samples:Batch 310/457 complete
# DEBUG:generate_samples:Batch 311/457 complete
# DEBUG:generate_samples:Batch 312/457 complete
# DEBUG:generate_samples:Batch 313/457 complete
# DEBUG:generate_samples:Batch 314/457 complete
# DEBUG:generate_samples:Batch 315/457 complete
# DEBUG:generate_samples:Batch 316/457 complete
# DEBUG:generate_samples:Batch 317/457 complete
# DEBUG:generate_samples:Batch 318/457 complete
# DEBUG:generate_samples:Batch 319/457 complete
# DEBUG:generate_samples:Batch 320/457 complete
# DEBUG:generate_samples:Batch 321/457 complete
# DEBUG:generate_samples:Batch 322/457 complete
# DEBUG:generate_samples:Batch 323/457 complete
# DEBUG:generate_samples:Batch 324/457 complete
# DEBUG:generate_samples:Batch 325/457 complete
# DEBUG:generate_samples:Batch 326/457 complete
# DEBUG:generate_samples:Batch 327/457 complete
# DEBUG:generate_samples:Batch 328/457 complete
# DEBUG:generate_samples:Batch 329/457 complete
# DEBUG:generate_samples:Batch 330/457 complete
# DEBUG:generate_samples:Batch 331/457 complete
# DEBUG:generate_samples:Batch 332/457 complete
# DEBUG:generate_samples:Batch 333/457 complete
# DEBUG:generate_samples:Batch 334/457 complete
# DEBUG:generate_samples:Batch 335/457 complete
# DEBUG:generate_samples:Batch 336/457 complete
# DEBUG:generate_samples:Batch 337/457 complete
# DEBUG:generate_samples:Batch 338/457 complete
# DEBUG:generate_samples:Batch 339/457 complete
# DEBUG:generate_samples:Batch 340/457 complete
# DEBUG:generate_samples:Batch 341/457 complete
# DEBUG:generate_samples:Batch 342/457 complete
# DEBUG:generate_samples:Batch 343/457 complete
# DEBUG:generate_samples:Batch 344/457 complete
# DEBUG:generate_samples:Batch 345/457 complete
# DEBUG:generate_samples:Batch 346/457 complete
# DEBUG:generate_samples:Batch 347/457 complete
# DEBUG:generate_samples:Batch 348/457 complete
# DEBUG:generate_samples:Batch 349/457 complete
# DEBUG:generate_samples:Batch 350/457 complete
# DEBUG:generate_samples:Batch 351/457 complete
# DEBUG:generate_samples:Batch 352/457 complete
# DEBUG:generate_samples:Batch 353/457 complete
# DEBUG:generate_samples:Batch 354/457 complete
# DEBUG:generate_samples:Batch 355/457 complete
# DEBUG:generate_samples:Batch 356/457 complete
# DEBUG:generate_samples:Batch 357/457 complete
# DEBUG:generate_samples:Batch 358/457 complete
# DEBUG:generate_samples:Batch 359/457 complete
# DEBUG:generate_samples:Batch 360/457 complete
# DEBUG:generate_samples:Batch 361/457 complete
# DEBUG:generate_samples:Batch 362/457 complete
# DEBUG:generate_samples:Batch 363/457 complete
# DEBUG:generate_samples:Batch 364/457 complete
# DEBUG:generate_samples:Batch 365/457 complete
# DEBUG:generate_samples:Batch 366/457 complete
# DEBUG:generate_samples:Batch 367/457 complete
# DEBUG:generate_samples:Batch 368/457 complete
# DEBUG:generate_samples:Batch 369/457 complete
# DEBUG:generate_samples:Batch 370/457 complete
# DEBUG:generate_samples:Batch 371/457 complete
# DEBUG:generate_samples:Batch 372/457 complete
# DEBUG:generate_samples:Batch 373/457 complete
# DEBUG:generate_samples:Batch 374/457 complete
# DEBUG:generate_samples:Batch 375/457 complete
# DEBUG:generate_samples:Batch 376/457 complete
# DEBUG:generate_samples:Batch 377/457 complete
# DEBUG:generate_samples:Batch 378/457 complete
# DEBUG:generate_samples:Batch 379/457 complete
# DEBUG:generate_samples:Batch 380/457 complete
# DEBUG:generate_samples:Batch 381/457 complete
# DEBUG:generate_samples:Batch 382/457 complete
# DEBUG:generate_samples:Batch 383/457 complete
# DEBUG:generate_samples:Batch 384/457 complete
# DEBUG:generate_samples:Batch 385/457 complete
# DEBUG:generate_samples:Batch 386/457 complete
# DEBUG:generate_samples:Batch 387/457 complete
# DEBUG:generate_samples:Batch 388/457 complete
# DEBUG:generate_samples:Batch 389/457 complete
# DEBUG:generate_samples:Batch 390/457 complete
# DEBUG:generate_samples:Batch 391/457 complete
# DEBUG:generate_samples:Batch 392/457 complete
# DEBUG:generate_samples:Batch 393/457 complete
# DEBUG:generate_samples:Batch 394/457 complete
# DEBUG:generate_samples:Batch 395/457 complete
# DEBUG:generate_samples:Batch 396/457 complete
# DEBUG:generate_samples:Batch 397/457 complete
# DEBUG:generate_samples:Batch 398/457 complete
# DEBUG:generate_samples:Batch 399/457 complete
# DEBUG:generate_samples:Batch 400/457 complete
# DEBUG:generate_samples:Batch 401/457 complete
# DEBUG:generate_samples:Batch 402/457 complete
# DEBUG:generate_samples:Batch 403/457 complete
# DEBUG:generate_samples:Batch 404/457 complete
# DEBUG:generate_samples:Batch 405/457 complete
# DEBUG:generate_samples:Batch 406/457 complete
# DEBUG:generate_samples:Batch 407/457 complete
# DEBUG:generate_samples:Batch 408/457 complete
# DEBUG:generate_samples:Batch 409/457 complete
# DEBUG:generate_samples:Batch 410/457 complete
# DEBUG:generate_samples:Batch 411/457 complete
# DEBUG:generate_samples:Batch 412/457 complete
# DEBUG:generate_samples:Batch 413/457 complete
# DEBUG:generate_samples:Batch 414/457 complete
# DEBUG:generate_samples:Batch 415/457 complete
# DEBUG:generate_samples:Batch 416/457 complete
# DEBUG:generate_samples:Batch 417/457 complete
# DEBUG:generate_samples:Batch 418/457 complete
# DEBUG:generate_samples:Batch 419/457 complete
# DEBUG:generate_samples:Batch 420/457 complete
# DEBUG:generate_samples:Batch 421/457 complete
# DEBUG:generate_samples:Batch 422/457 complete
# DEBUG:generate_samples:Batch 423/457 complete
# DEBUG:generate_samples:Batch 424/457 complete
# DEBUG:generate_samples:Batch 425/457 complete
# DEBUG:generate_samples:Batch 426/457 complete
# DEBUG:generate_samples:Batch 427/457 complete
# DEBUG:generate_samples:Batch 428/457 complete
# DEBUG:generate_samples:Batch 429/457 complete
# DEBUG:generate_samples:Batch 430/457 complete
# DEBUG:generate_samples:Batch 431/457 complete
# DEBUG:generate_samples:Batch 432/457 complete
# DEBUG:generate_samples:Batch 433/457 complete
# DEBUG:generate_samples:Batch 434/457 complete
# DEBUG:generate_samples:Batch 435/457 complete
# DEBUG:generate_samples:Batch 436/457 complete
# DEBUG:generate_samples:Batch 437/457 complete
# DEBUG:generate_samples:Batch 438/457 complete
# DEBUG:generate_samples:Batch 439/457 complete
# DEBUG:generate_samples:Batch 440/457 complete
# DEBUG:generate_samples:Batch 441/457 complete
# DEBUG:generate_samples:Batch 442/457 complete
# DEBUG:generate_samples:Batch 443/457 complete
# DEBUG:generate_samples:Batch 444/457 complete
# DEBUG:generate_samples:Batch 445/457 complete
# DEBUG:generate_samples:Batch 446/457 complete
# DEBUG:generate_samples:Batch 447/457 complete
# DEBUG:generate_samples:Batch 448/457 complete
# DEBUG:generate_samples:Batch 449/457 complete
# DEBUG:generate_samples:Batch 450/457 complete
# DEBUG:generate_samples:Batch 451/457 complete
# DEBUG:generate_samples:Batch 452/457 complete
# DEBUG:generate_samples:Batch 453/457 complete
# DEBUG:generate_samples:Batch 454/457 complete
# DEBUG:generate_samples:Batch 455/457 complete
# DEBUG:generate_samples:Batch 456/457 complete
# DEBUG:generate_samples:Batch 457/457 complete
# DEBUG:generate_samples:Batch 458/457 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/92 complete
# DEBUG:generate_samples:Batch 2/92 complete
# DEBUG:generate_samples:Batch 3/92 complete
# DEBUG:generate_samples:Batch 4/92 complete
# DEBUG:generate_samples:Batch 5/92 complete
# DEBUG:generate_samples:Batch 6/92 complete
# DEBUG:generate_samples:Batch 7/92 complete
# DEBUG:generate_samples:Batch 8/92 complete
# DEBUG:generate_samples:Batch 9/92 complete
# DEBUG:generate_samples:Batch 10/92 complete
# DEBUG:generate_samples:Batch 11/92 complete
# DEBUG:generate_samples:Batch 12/92 complete
# DEBUG:generate_samples:Batch 13/92 complete
# DEBUG:generate_samples:Batch 14/92 complete
# DEBUG:generate_samples:Batch 15/92 complete
# DEBUG:generate_samples:Batch 16/92 complete
# DEBUG:generate_samples:Batch 17/92 complete
# DEBUG:generate_samples:Batch 18/92 complete
# DEBUG:generate_samples:Batch 19/92 complete
# DEBUG:generate_samples:Batch 20/92 complete
# DEBUG:generate_samples:Batch 21/92 complete
# DEBUG:generate_samples:Batch 22/92 complete
# DEBUG:generate_samples:Batch 23/92 complete
# DEBUG:generate_samples:Batch 24/92 complete
# DEBUG:generate_samples:Batch 25/92 complete
# DEBUG:generate_samples:Batch 26/92 complete
# DEBUG:generate_samples:Batch 27/92 complete
# DEBUG:generate_samples:Batch 28/92 complete
# DEBUG:generate_samples:Batch 29/92 complete
# DEBUG:generate_samples:Batch 30/92 complete
# DEBUG:generate_samples:Batch 31/92 complete
# DEBUG:generate_samples:Batch 32/92 complete
# DEBUG:generate_samples:Batch 33/92 complete
# DEBUG:generate_samples:Batch 34/92 complete
# DEBUG:generate_samples:Batch 35/92 complete
# DEBUG:generate_samples:Batch 36/92 complete
# DEBUG:generate_samples:Batch 37/92 complete
# DEBUG:generate_samples:Batch 38/92 complete
# DEBUG:generate_samples:Batch 39/92 complete
# DEBUG:generate_samples:Batch 40/92 complete
# DEBUG:generate_samples:Batch 41/92 complete
# DEBUG:generate_samples:Batch 42/92 complete
# DEBUG:generate_samples:Batch 43/92 complete
# DEBUG:generate_samples:Batch 44/92 complete
# DEBUG:generate_samples:Batch 45/92 complete
# DEBUG:generate_samples:Batch 46/92 complete
# DEBUG:generate_samples:Batch 47/92 complete
# DEBUG:generate_samples:Batch 48/92 complete
# DEBUG:generate_samples:Batch 49/92 complete
# DEBUG:generate_samples:Batch 50/92 complete
# DEBUG:generate_samples:Batch 51/92 complete
# DEBUG:generate_samples:Batch 52/92 complete
# DEBUG:generate_samples:Batch 53/92 complete
# DEBUG:generate_samples:Batch 54/92 complete
# DEBUG:generate_samples:Batch 55/92 complete
# DEBUG:generate_samples:Batch 56/92 complete
# DEBUG:generate_samples:Batch 57/92 complete
# DEBUG:generate_samples:Batch 58/92 complete
# DEBUG:generate_samples:Batch 59/92 complete
# DEBUG:generate_samples:Batch 60/92 complete
# DEBUG:generate_samples:Batch 61/92 complete
# DEBUG:generate_samples:Batch 62/92 complete
# DEBUG:generate_samples:Batch 63/92 complete
# DEBUG:generate_samples:Batch 64/92 complete
# DEBUG:generate_samples:Batch 65/92 complete
# DEBUG:generate_samples:Batch 66/92 complete
# DEBUG:generate_samples:Batch 67/92 complete
# DEBUG:generate_samples:Batch 68/92 complete
# DEBUG:generate_samples:Batch 69/92 complete
# DEBUG:generate_samples:Batch 70/92 complete
# DEBUG:generate_samples:Batch 71/92 complete
# DEBUG:generate_samples:Batch 72/92 complete
# DEBUG:generate_samples:Batch 73/92 complete
# DEBUG:generate_samples:Batch 74/92 complete
# DEBUG:generate_samples:Batch 75/92 complete
# DEBUG:generate_samples:Batch 76/92 complete
# DEBUG:generate_samples:Batch 77/92 complete
# DEBUG:generate_samples:Batch 78/92 complete
# DEBUG:generate_samples:Batch 79/92 complete
# DEBUG:generate_samples:Batch 80/92 complete
# DEBUG:generate_samples:Batch 81/92 complete
# DEBUG:generate_samples:Batch 82/92 complete
# DEBUG:generate_samples:Batch 83/92 complete
# DEBUG:generate_samples:Batch 84/92 complete
# DEBUG:generate_samples:Batch 85/92 complete
# DEBUG:generate_samples:Batch 86/92 complete
# DEBUG:generate_samples:Batch 87/92 complete
# DEBUG:generate_samples:Batch 88/92 complete
# DEBUG:generate_samples:Batch 89/92 complete
# DEBUG:generate_samples:Batch 90/92 complete
# DEBUG:generate_samples:Batch 91/92 complete
# DEBUG:generate_samples:Batch 92/92 complete
# DEBUG:generate_samples:Batch 93/92 complete
# INFO:generate_samples:Done
#
#   PASS all 4 clip dirs now populated

# %% [markdown]
# ## 11bis. Génération des clips FR (positifs + négatifs)
#
# Section entièrement pilotée par les variables `FR_*` de la section 10 (voir la cellule de config). Désactivable via `FR_ENABLED = False`.
#
# Génère :
# - des clips **positifs** pour chaque phrase de `fr_target_phrases` (ex. "hey vicky", "ok vicky", "dis vicky") ;
# - des clips **négatifs** pour chaque phrase de `fr_negative_phrases` (mots proches/piégeurs en français) — sans ça le modèle associe "parler français" au réveil au lieu de la phrase précise.
#
# Puis fusionne le tout dans les mêmes dossiers `positive_train/test` et `negative_train/test` que le pipeline EN officiel, avant le resampling (section 12) qui s'applique donc automatiquement à ces clips aussi.

# %%
import os, yaml
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)

if cfg.get('fr_enabled', False):
    model_path = cfg['fr_piper_model']
    os.makedirs(os.path.dirname(model_path), exist_ok=True)
    if not os.path.exists(model_path) or os.path.getsize(model_path) < 50_000_000:
        print('  modèle FR manquant/partiel — téléchargement (~130 MB)')
        # !wget -q --tries=5 --timeout=300 -O "{model_path}" 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/fr_FR-mls-medium.pt'
    assert os.path.getsize(model_path) > 50_000_000, f'modèle FR téléchargé mais trop petit ({os.path.getsize(model_path)} bytes) — téléchargement raté'
    print(f'  ✓ modèle piper FR: {model_path} ({os.path.getsize(model_path)/1e6:.0f} MB)')

    # torch.load strict depuis torch 2.6 (weights_only=True par défaut) casse le
    # chargement du .pt piper — patch idempotent (vérifie avant de sed).
    # GEN_PY = '/content/piper-sample-generator/generate_samples.py'
    #with open(GEN_PY) as f:
    #    content = f.read()
    #if 'torch.load(model_path, weights_only=False)' not in content:
    #    !sed -i 's/torch.load(model_path)/torch.load(model_path, weights_only=False)/' "{GEN_PY}"
    #    print('  ✓ patch torch.load(weights_only=False) appliqué')
    #else:
    #    print('  ✓ patch torch.load déjà appliqué')
else:
    print('  FR désactivé (fr_enabled=False dans la config) — skip')
# Out:
#   ✓ modèle piper FR: /content/piper-sample-generator/models/fr_FR-mls-medium.pt (202 MB)

# %%
# !find /content -maxdepth 4 -type d -name "positive_train"
# Out:
# /content/hey_vicky_v2_output/hey_vicky_v2/positive_train

# %%
import os, yaml
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)

if cfg.get('fr_enabled', False):
    os.chdir('/content/piper-sample-generator')

    def gen(phrase, n, out_dir, kind):
        n_existing = len(os.listdir(out_dir)) if os.path.isdir(out_dir) else 0
        if n_existing >= int(n * 0.9):
            print(f'  cached: {kind} "{phrase}" — {n_existing} clips')
            return
        print(f'  génération {kind} FR: "{phrase}" → {out_dir} ({n} clips)')
        # !python3 generate_samples.py "{phrase}" --model "{cfg['fr_piper_model']}" \
            --max-samples {n} --output-dir "{out_dir}/" \
            --batch-size {cfg['tts_batch_size']} \
            --noise-scales 0.333 --noise-scale-ws 0.333

    for phrase in cfg['fr_target_phrases']:
        out_dir = f"/content/fr_pos_{phrase.replace(' ', '_')}"
        gen(phrase, cfg['fr_samples_per_phrase'], out_dir, 'positif')

    for phrase in cfg['fr_negative_phrases']:
        out_dir = f"/content/fr_neg_{phrase.replace(' ', '_').replace('-', '_')}"
        gen(phrase, cfg['fr_neg_samples_per_phrase'], out_dir, 'négatif')

    os.chdir('/content')
else:
    print('  FR désactivé — skip génération clips FR')
# Out:
#   génération positif FR: "hé vicky" → /content/fr_pos_hé_vicky (1300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/26 complete
# DEBUG:__main__:Batch 2/26 complete
# DEBUG:__main__:Batch 3/26 complete
# DEBUG:__main__:Batch 4/26 complete
# DEBUG:__main__:Batch 5/26 complete
# DEBUG:__main__:Batch 6/26 complete
# DEBUG:__main__:Batch 7/26 complete
# DEBUG:__main__:Batch 8/26 complete
# DEBUG:__main__:Batch 9/26 complete
# DEBUG:__main__:Batch 10/26 complete
# DEBUG:__main__:Batch 11/26 complete
# DEBUG:__main__:Batch 12/26 complete
# DEBUG:__main__:Batch 13/26 complete
# DEBUG:__main__:Batch 14/26 complete
# DEBUG:__main__:Batch 15/26 complete
# DEBUG:__main__:Batch 16/26 complete
# DEBUG:__main__:Batch 17/26 complete
# DEBUG:__main__:Batch 18/26 complete
# DEBUG:__main__:Batch 19/26 complete
# DEBUG:__main__:Batch 20/26 complete
# DEBUG:__main__:Batch 21/26 complete
# DEBUG:__main__:Batch 22/26 complete
# DEBUG:__main__:Batch 23/26 complete
# DEBUG:__main__:Batch 24/26 complete
# DEBUG:__main__:Batch 25/26 complete
# DEBUG:__main__:Batch 26/26 complete
# INFO:__main__:Done
#   génération positif FR: "ok vicky" → /content/fr_pos_ok_vicky (1300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/26 complete
# DEBUG:__main__:Batch 2/26 complete
# DEBUG:__main__:Batch 3/26 complete
# DEBUG:__main__:Batch 4/26 complete
# DEBUG:__main__:Batch 5/26 complete
# DEBUG:__main__:Batch 6/26 complete
# DEBUG:__main__:Batch 7/26 complete
# DEBUG:__main__:Batch 8/26 complete
# DEBUG:__main__:Batch 9/26 complete
# DEBUG:__main__:Batch 10/26 complete
# DEBUG:__main__:Batch 11/26 complete
# DEBUG:__main__:Batch 12/26 complete
# DEBUG:__main__:Batch 13/26 complete
# DEBUG:__main__:Batch 14/26 complete
# DEBUG:__main__:Batch 15/26 complete
# DEBUG:__main__:Batch 16/26 complete
# DEBUG:__main__:Batch 17/26 complete
# DEBUG:__main__:Batch 18/26 complete
# DEBUG:__main__:Batch 19/26 complete
# DEBUG:__main__:Batch 20/26 complete
# DEBUG:__main__:Batch 21/26 complete
# DEBUG:__main__:Batch 22/26 complete
# DEBUG:__main__:Batch 23/26 complete
# DEBUG:__main__:Batch 24/26 complete
# DEBUG:__main__:Batch 25/26 complete
# DEBUG:__main__:Batch 26/26 complete
# INFO:__main__:Done
#   génération positif FR: "dis vicky" → /content/fr_pos_dis_vicky (1300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/26 complete
# DEBUG:__main__:Batch 2/26 complete
# DEBUG:__main__:Batch 3/26 complete
# DEBUG:__main__:Batch 4/26 complete
# DEBUG:__main__:Batch 5/26 complete
# DEBUG:__main__:Batch 6/26 complete
# DEBUG:__main__:Batch 7/26 complete
# DEBUG:__main__:Batch 8/26 complete
# DEBUG:__main__:Batch 9/26 complete
# DEBUG:__main__:Batch 10/26 complete
# DEBUG:__main__:Batch 11/26 complete
# DEBUG:__main__:Batch 12/26 complete
# DEBUG:__main__:Batch 13/26 complete
# DEBUG:__main__:Batch 14/26 complete
# DEBUG:__main__:Batch 15/26 complete
# DEBUG:__main__:Batch 16/26 complete
# DEBUG:__main__:Batch 17/26 complete
# DEBUG:__main__:Batch 18/26 complete
# DEBUG:__main__:Batch 19/26 complete
# DEBUG:__main__:Batch 20/26 complete
# DEBUG:__main__:Batch 21/26 complete
# DEBUG:__main__:Batch 22/26 complete
# DEBUG:__main__:Batch 23/26 complete
# DEBUG:__main__:Batch 24/26 complete
# DEBUG:__main__:Batch 25/26 complete
# DEBUG:__main__:Batch 26/26 complete
# INFO:__main__:Done
#   génération négatif FR: "hey mickey" → /content/fr_neg_hey_mickey (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "et vicky" → /content/fr_neg_et_vicky (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "ok mickey" → /content/fr_neg_ok_mickey (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "hey nicky" → /content/fr_neg_hey_nicky (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "dis whisky" → /content/fr_neg_dis_whisky (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "ok whisky" → /content/fr_neg_ok_whisky (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "hey ricky" → /content/fr_neg_hey_ricky (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "dis-moi" → /content/fr_neg_dis_moi (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "ok google" → /content/fr_neg_ok_google (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "hey siri" → /content/fr_neg_hey_siri (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "dis donc" → /content/fr_neg_dis_donc (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "ok alors" → /content/fr_neg_ok_alors (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done
#   génération négatif FR: "hey toi" → /content/fr_neg_hey_toi (300 clips)
# DEBUG:__main__:Loading /content/piper-sample-generator/models/fr_FR-mls-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/6 complete
# DEBUG:__main__:Batch 2/6 complete
# DEBUG:__main__:Batch 3/6 complete
# DEBUG:__main__:Batch 4/6 complete
# DEBUG:__main__:Batch 5/6 complete
# DEBUG:__main__:Batch 6/6 complete
# INFO:__main__:Done

# %%
import shutil, glob, random, os, yaml

with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)

if cfg.get('fr_enabled', False):
    split = cfg['fr_train_split']
    random.seed(0)

    def merge(glob_pattern, dst_train, dst_test, prefix):
        clips = glob.glob(glob_pattern)
        random.shuffle(clips)
        cut = int(len(clips) * split)
        for i, f in enumerate(clips[:cut]):
            shutil.copy(f, f"{dst_train}/{prefix}_{i}.wav")
        for i, f in enumerate(clips[cut:]):
            shutil.copy(f, f"{dst_test}/{prefix}_{i}.wav")
        return cut, len(clips) - cut

    n_pos_train = n_pos_test = 0
    for phrase in cfg['fr_target_phrases']:
        tag = phrase.replace(' ', '_')
        src = f"/content/fr_pos_{tag}/*.wav"
        a, b = merge(src, cfg['positive_clips_train_dir'], cfg['positive_clips_test_dir'], f"fr_{tag}")
        n_pos_train += a; n_pos_test += b

    n_neg_train = n_neg_test = 0
    for phrase in cfg['fr_negative_phrases']:
        tag = phrase.replace(' ', '_').replace('-', '_')
        src = f"/content/fr_neg_{tag}/*.wav"
        a, b = merge(src, cfg['negative_clips_train_dir'], cfg['negative_clips_test_dir'], f"frneg_{tag}")
        n_neg_train += a; n_neg_test += b

    print(f"  positifs FR : {n_pos_train} → train, {n_pos_test} → test")
    print(f"  négatifs FR : {n_neg_train} → train, {n_neg_test} → test")

    # Les clips FR sont ajoutés APRÈS coup dans des dossiers que la section 13
    # (augment + featurise) a peut-être déjà traités lors d'un run précédent.
    # Sans ça, la cellule d'augmentation détecte les .npy existants et les
    # saute silencieusement — les clips FR ne seraient alors jamais pris en
    # compte. On invalide donc le cache de features ici pour forcer le recalcul.
    stale = glob.glob(f"{cfg['feature_save_dir']}/*.npy")
    for f in stale:
        os.remove(f)
    if stale:
        print(f"  cache de features invalidé ({len(stale)} fichiers .npy supprimés) — sera régénéré section 13")
else:
    print('  FR désactivé — skip fusion clips FR')
# Out:
#   positifs FR : 3120 → train, 780 → test
#   négatifs FR : 3120 → train, 780 → test

# %% [markdown]
# ## 12. Resample TTS clips 22050 → 16000 Hz
#
# Piper TTS outputs at libritts's native 22050 Hz. The augment + feature pipelines expect 16 kHz.

# %%
import os, glob, soundfile as sf, yaml
from scipy.signal import resample_poly
from tqdm.auto import tqdm
TARGET_SR = 16000
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
ROOT = cfg['output_dir']
wav_dirs = sorted({os.path.dirname(f)
                   for f in glob.glob(f'{ROOT}/**/*.wav', recursive=True)})
for d in wav_dirs:
    files = [f for f in os.listdir(d) if f.endswith('.wav')]
    if not files: continue
    sr_counts = {}
    for f in files[:20]:
        sr = sf.info(f'{d}/{f}').samplerate
        sr_counts[sr] = sr_counts.get(sr, 0) + 1
    if all(k == TARGET_SR for k in sr_counts):
        print(f'  ok {d}: {len(files)} files at 16 kHz (skip)')
        continue
    print(f'  resampling {d}: {len(files)} files, SRs {sr_counts}')
    n = 0
    for f in tqdm(files, desc=os.path.basename(d) or d, leave=False):
        p = f'{d}/{f}'
        data, sr = sf.read(p)
        if sr == TARGET_SR: continue
        new_data = resample_poly(data.astype('float32'), TARGET_SR, sr)
        sf.write(p, new_data, TARGET_SR); n += 1
    print(f'  ok {d}: resampled {n}/{len(files)}')
for f in glob.glob(f'{ROOT}/**/*.npy', recursive=True):
    os.remove(f)
print('\n  cleared stale features (will be regenerated by augment)')
# Out:
#   resampling /content/hey_vicky_v2_output/hey_vicky_v2/negative_test: 1430 files, SRs {22050: 20}
# negative_test:   0%|          | 0/1430 [00:00<?, ?it/s]
#   ok /content/hey_vicky_v2_output/hey_vicky_v2/negative_test: resampled 1430/1430
#   resampling /content/hey_vicky_v2_output/hey_vicky_v2/negative_train: 6320 files, SRs {22050: 20}
# negative_train:   0%|          | 0/6320 [00:00<?, ?it/s]
#   ok /content/hey_vicky_v2_output/hey_vicky_v2/negative_train: resampled 6320/6320
#   resampling /content/hey_vicky_v2_output/hey_vicky_v2/positive_test: 1430 files, SRs {22050: 20}
# positive_test:   0%|          | 0/1430 [00:00<?, ?it/s]
#   ok /content/hey_vicky_v2_output/hey_vicky_v2/positive_test: resampled 1430/1430
#   resampling /content/hey_vicky_v2_output/hey_vicky_v2/positive_train: 6320 files, SRs {22050: 20}
# positive_train:   0%|          | 0/6320 [00:00<?, ?it/s]
#   ok /content/hey_vicky_v2_output/hey_vicky_v2/positive_train: resampled 6320/6320
#
#   cleared stale features (will be regenerated by augment)

# %% [markdown]
# ## 13. Augment + featurise (~10 min)
#
# Outputs `(N, 16, 96)` feature .npy files that the hand-rolled trainer reads.

# %%
# !ls -la /content/vicky_output/vicky/*.npy
# Out:
# ls: cannot access '/content/vicky_output/vicky/*.npy': No such file or directory

# %%
import sys, os, glob, yaml
os.environ['PYTHONPATH'] = '/content/openwakeword:' + os.environ.get('PYTHONPATH', '')

with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
FEAT = cfg['feature_save_dir']
needed = ['positive_features_train.npy', 'negative_features_train.npy',
          'positive_features_test.npy',  'negative_features_test.npy']
if all(os.path.exists(f'{FEAT}/{n}') for n in needed):
    print('  cached: all 4 feature .npy files exist')
else:
    # !{sys.executable} /content/openwakeword/openwakeword/train.py \
        --training_config /content/my_model.yaml \
        --augment_clips
for f in sorted(glob.glob(f'{FEAT}/*.npy')):
    print(f'  {f}: {os.path.getsize(f)/1e6:.1f} MB')
for n in needed:
    assert os.path.exists(f'{FEAT}/{n}'), f"augment didn't produce {n}"
print('  PASS all 4 feature files present')
# Out:
# INFO:root:##################################################
# Computing openwakeword features for generated samples
# ##################################################
# /usr/local/lib/python3.13/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:153: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = PitchShift(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = BandStopFilter(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddColoredNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddBackgroundNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Gain(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/composition.py:42: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Compose(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/audiomentations/core/transforms_interface.py:107: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# Computing features: 100% 394/395 [04:48<00:00,  1.37it/s]
# Trimming empty rows: 7it [00:00, 41.10it/s]
# Computing features:  27% 106/395 [01:19<03:21,  1.43it/s]

# %% [markdown]
# ## 14. Hand-rolled trainer (~30-40 min on L4 / A100)

# %%
import os, copy, math, time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import yaml
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {DEVICE}')
with open('/content/my_model.yaml') as f:
    cfg = yaml.safe_load(f)
FEAT = cfg['feature_save_dir']
pos_train = torch.from_numpy(np.load(f'{FEAT}/positive_features_train.npy').astype(np.float32)).to(DEVICE)
neg_train = torch.from_numpy(np.load(f'{FEAT}/negative_features_train.npy').astype(np.float32)).to(DEVICE)
pos_test  = torch.from_numpy(np.load(f'{FEAT}/positive_features_test.npy').astype(np.float32)).to(DEVICE)
neg_test  = torch.from_numpy(np.load(f'{FEAT}/negative_features_test.npy').astype(np.float32)).to(DEVICE)
print(f'  pos_train={tuple(pos_train.shape)}  neg_train={tuple(neg_train.shape)}')
print(f'  pos_test={tuple(pos_test.shape)}  neg_test={tuple(neg_test.shape)}')
acav_train_np = np.load(cfg['feature_data_files']['ACAV100M_sample'], mmap_mode='r')
print(f'  acav_train (mmap): {acav_train_np.shape}')
acav_val_np = np.load(cfg['false_positive_validation_data_path'])
M = acav_val_np.shape[0]
val_listen_hours = M * 0.08 / 3600.0
print(f'  acav_val: {acav_val_np.shape}  → {val_listen_hours:.2f} hr listening time')
n_win_val = M - 16
acav_val_windows = np.lib.stride_tricks.sliding_window_view(acav_val_np, (16, 96))[:, 0, :, :]
acav_val_windows = np.ascontiguousarray(acav_val_windows.astype(np.float32))
print(f'  acav_val_windows: {acav_val_windows.shape} ({acav_val_windows.nbytes/1e6:.0f} MB)')
VAL_BATCH = 4096
class WakewordModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(16 * 96, 128)
        self.layernorm1 = nn.LayerNorm(128)
        self.relu1 = nn.ReLU()
        self.layer2 = nn.Linear(128, 1)
    def forward(self, x):
        return self.layer2(self.relu1(self.layernorm1(self.layer1(self.flatten(x)))))
model = WakewordModel().to(DEVICE)
loss_fn = nn.BCEWithLogitsLoss(reduction='none')
TOTAL_STEPS = cfg['steps']
MAX_NEG_W   = cfg['max_negative_weight']
TARGET_FP_PER_HR = cfg['target_false_positives_per_hour']
THRESH = 0.5
history = {'val_recall': [], 'val_accuracy': [], 'val_fp_per_hour': [], 'val_n_fp': [], 'loss': []}
best_models = []
B_POS, B_ANEG, B_ACAV = 32, 32, 64
def random_acav_window_batch(k):
    N, T, F = acav_train_np.shape
    rows = np.random.randint(0, N, size=k)
    starts = np.random.randint(0, T - 16 + 1, size=k)
    out = np.empty((k, 16, F), dtype=np.float32)
    for i, (r, s) in enumerate(zip(rows, starts)):
        out[i] = acav_train_np[r, s:s+16, :].astype(np.float32)
    return out
def build_batch():
    p_idx = torch.randint(0, pos_train.shape[0], (B_POS,), device=DEVICE)
    aneg_idx = torch.randint(0, neg_train.shape[0], (B_ANEG,), device=DEVICE)
    p, an = pos_train[p_idx], neg_train[aneg_idx]
    acav = torch.from_numpy(random_acav_window_batch(B_ACAV)).to(DEVICE)
    x = torch.cat([p, an, acav], dim=0)
    y = torch.cat([torch.ones(B_POS, device=DEVICE),
                   torch.zeros(B_ANEG + B_ACAV, device=DEVICE)])
    return x, y
@torch.no_grad()
def validate(step_label):
    model.eval()
    p_preds = torch.sigmoid(model(pos_test)).squeeze(-1)
    n_preds = torch.sigmoid(model(neg_test)).squeeze(-1)
    recall = (p_preds >= THRESH).float().mean().item()
    accuracy = (((p_preds >= THRESH).sum() + (n_preds < THRESH).sum()).item()
                / (pos_test.shape[0] + neg_test.shape[0]))
    n_fp = 0
    for i in range(0, n_win_val, VAL_BATCH):
        chunk = torch.from_numpy(acav_val_windows[i:i+VAL_BATCH]).to(DEVICE)
        n_fp += (torch.sigmoid(model(chunk)).squeeze(-1) >= THRESH).sum().item()
    fp_per_hour = n_fp / max(val_listen_hours, 1e-6)
    history['val_recall'].append(recall)
    history['val_accuracy'].append(accuracy)
    history['val_fp_per_hour'].append(fp_per_hour)
    history['val_n_fp'].append(n_fp)
    save = False
    if len(history['val_n_fp']) >= 3:
        fp_p50 = np.percentile(history['val_n_fp'], 50)
        rc_p5  = np.percentile(history['val_recall'], 5)
        if n_fp <= fp_p50 and recall >= rc_p5:
            best_models.append((copy.deepcopy(model.state_dict()),
                                {'val_recall': recall, 'val_accuracy': accuracy,
                                 'val_fp_per_hour': fp_per_hour, 'val_n_fp': n_fp}))
            save = True
    print(f'  [{step_label}] recall={recall:.3f}  acc={accuracy:.3f}  fp/hr={fp_per_hour:.2f}  saved={"+" if save else "-"}', flush=True)
    model.train()
def run_stage(stage_idx, n_steps, lr, max_neg_w, val_window_frac=1.0):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    weight_schedule = np.linspace(1.0, max_neg_w, n_steps)
    val_start = int(n_steps * (1.0 - val_window_frac))
    val_steps = set(np.linspace(val_start, n_steps - 1, 20).astype(int))
    warmup = max(1, n_steps // 5)
    hold   = n_steps // 3
    accumulated = []
    print(f'\n=== Stage {stage_idx}: {n_steps} steps, lr={lr}, max_neg_w={max_neg_w} ===', flush=True)
    t0 = time.time()
    for step in range(n_steps):
        if step < warmup:
            lr_now = lr * (step + 1) / warmup
        elif step < warmup + hold:
            lr_now = lr
        else:
            decay_t = (step - warmup - hold) / max(1, n_steps - warmup - hold)
            lr_now = lr * 0.5 * (1.0 + math.cos(math.pi * min(1.0, decay_t)))
        for pg in optimizer.param_groups: pg['lr'] = lr_now
        x, y = build_batch()
        logits = model(x).squeeze(-1)
        preds = torch.sigmoid(logits)
        keep = ((y == 0) & (preds >= 0.001)) | ((y == 1) & (preds < 0.999))
        if keep.sum() == 0:
            if step in val_steps: validate(f'stage{stage_idx} step {step}/{n_steps}')
            continue
        kept_logits = logits[keep]
        kept_y = y[keep]
        neg_w = weight_schedule[step]
        w = torch.where(kept_y > 0.5,
                        torch.tensor(1.0, device=DEVICE),
                        torch.tensor(neg_w, device=DEVICE, dtype=torch.float32))
        accumulated.append((kept_logits, kept_y, w))
        if sum(t[0].shape[0] for t in accumulated) >= 128:
            cat_logits = torch.cat([t[0] for t in accumulated])
            cat_y = torch.cat([t[1] for t in accumulated])
            cat_w = torch.cat([t[2] for t in accumulated])
            loss = (loss_fn(cat_logits, cat_y) * cat_w).mean()
            optimizer.zero_grad(); loss.backward(); optimizer.step()
            history['loss'].append(loss.item())
            accumulated.clear()
        if step in val_steps:
            elapsed = (time.time() - t0) / 60
            validate(f'stage{stage_idx} step {step}/{n_steps} ({elapsed:.1f}m, lr={lr_now:.6f}, neg_w={neg_w:.0f})')
    print(f'  Stage {stage_idx} done in {(time.time()-t0)/60:.1f} min', flush=True)
QUICK_TEST = False # passe à False pour un vrai run
stage_floor = 50 if QUICK_TEST else 2000

stage1_steps = TOTAL_STEPS
stage2_steps = max(stage_floor, TOTAL_STEPS // 10)
stage3_steps = max(stage_floor, TOTAL_STEPS // 10)
max_neg_w_now = MAX_NEG_W
run_stage(1, stage1_steps, lr=1e-4, max_neg_w=max_neg_w_now, val_window_frac=0.25)
if (history['val_fp_per_hour'] and min(history['val_fp_per_hour']) > TARGET_FP_PER_HR):
    max_neg_w_now *= 2
    print(f'\n[adapt] stage1 best FP/hr > target → max_neg_w doubled to {max_neg_w_now}')
run_stage(2, stage2_steps, lr=1e-5, max_neg_w=max_neg_w_now, val_window_frac=1.0)
if (history['val_fp_per_hour'] and min(history['val_fp_per_hour']) > TARGET_FP_PER_HR):
    max_neg_w_now *= 2
    print(f'\n[adapt] stage2 best FP/hr > target → max_neg_w doubled to {max_neg_w_now}')
run_stage(3, stage3_steps, lr=1e-6, max_neg_w=max_neg_w_now, val_window_frac=1.0)
print(f'\n=== Training done. {len(best_models)} checkpoints saved. ===')
print(f'  best val_fp_per_hour: {min(history["val_fp_per_hour"]):.2f}')
print(f'  best val_recall:      {max(history["val_recall"]):.3f}')
print(f'  best val_accuracy:    {max(history["val_accuracy"]):.3f}')

# %% [markdown]
# ## 15. Ensemble best checkpoints + ONNX export + download

# %%
import copy, os
import numpy as np
import torch
if not best_models:
    print('  no saved checkpoints — using current model state')
    final_state = {k: v.clone() for k, v in model.state_dict().items()}
else:
    accs = [s['val_accuracy'] for _, s in best_models]
    rcs  = [s['val_recall']   for _, s in best_models]
    fps  = [s['val_fp_per_hour'] for _, s in best_models]
    acc_p90 = np.percentile(accs, 90)
    rc_p90  = np.percentile(rcs, 90)
    fp_p10  = np.percentile(fps, 10)
    print(f'  thresholds: acc≥{acc_p90:.3f}  recall≥{rc_p90:.3f}  fp/hr≤{fp_p10:.2f}')
    qualified = [(sd, sc) for sd, sc in best_models
                 if sc['val_accuracy'] >= acc_p90 and sc['val_recall'] >= rc_p90
                 and sc['val_fp_per_hour'] <= fp_p10]
    print(f'  qualified: {len(qualified)} of {len(best_models)} checkpoints')
    if not qualified:
        sorted_models = sorted(best_models, key=lambda t: (t[1]['val_fp_per_hour'], -t[1]['val_recall']))
        qualified = [sorted_models[0]]
        print('  no checkpoint qualified — fell back to single best')
    keys = qualified[0][0].keys()
    final_state = {k: torch.stack([sd[k].float() for sd, _ in qualified]).mean(dim=0) for k in keys}
    qa = np.mean([s['val_accuracy'] for _, s in qualified])
    qr = np.mean([s['val_recall'] for _, s in qualified])
    qf = np.mean([s['val_fp_per_hour'] for _, s in qualified])
    print(f'  ensemble averaged: mean acc={qa:.3f}, recall={qr:.3f}, fp/hr={qf:.2f}')
model.load_state_dict(final_state)
model.eval()
out_path = f"{cfg['feature_save_dir']}/{cfg['model_name']}.onnx"
os.makedirs(os.path.dirname(out_path), exist_ok=True)
class WakewordExportable(torch.nn.Module):
    def __init__(self, base): super().__init__(); self.base = base
    def forward(self, x): return torch.sigmoid(self.base(x))
export_model = WakewordExportable(model).to(DEVICE).eval()
dummy = torch.randn(1, 16, 96, device=DEVICE)
torch.onnx.export(export_model, dummy, out_path,
                  input_names=['onnx::Flatten_0'], output_names=['output'],
                  dynamic_axes={'onnx::Flatten_0': {0: 'batch'}, 'output': {0: 'batch'}},
                  opset_version=14, dynamo=False, external_data=False)
print(f'  ✓ wrote {out_path} ({os.path.getsize(out_path)/1e3:.0f} KB)')
import onnxruntime as ort
sess = ort.InferenceSession(out_path)
print(f'  input:  {sess.get_inputs()[0].name} {sess.get_inputs()[0].shape}')
print(f'  output: {sess.get_outputs()[0].name} {sess.get_outputs()[0].shape}')
with torch.no_grad():
    p_test_np = pos_test.cpu().numpy()
    p_scores = sess.run(None, {sess.get_inputs()[0].name: p_test_np})[0].flatten()
    print(f'  positive test set: mean={p_scores.mean():.3f}, recall@0.5={(p_scores>=0.5).mean():.3f}')
print(f'  ACAV val FP/hour at 0.5: {history["val_fp_per_hour"][-1]:.2f}')
from google.colab import files
files.download(out_path)
print(f'\nDONE. Wake word "{cfg["model_name"]}" trained.')
print('Drop the downloaded .onnx into your APK / on-device app at:')
print(f'  android/app/src/main/assets/wakewords/{cfg["model_name"]}.onnx  (or wherever your APK looks)')

# %%
import os, glob
FEAT = cfg['feature_save_dir']  # ou remets le chemin en dur si cfg n'est plus en mémoire
for f in glob.glob(f'{FEAT}/{cfg["model_name"]}*'):
    print(f, '—', os.path.getsize(f), 'bytes')

# %%
import onnxruntime as ort
import numpy as np
sess = ort.InferenceSession(out_path)  # ou le chemin exact de ton .onnx téléchargé si tu testes en local
dummy_input = np.random.randn(1, 16, 96).astype(np.float32)
result = sess.run(None, {sess.get_inputs()[0].name: dummy_input})
print(result)
